# %% [markdown]
# ##Linear Regression

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
file_path = '/content/drive/MyDrive/Airnode/Data/Real-Data/Real_Combine.csv'
df = pd.read_csv(file_path)

# %%
df.head()
# Out:
#       T    TM   Tm     SLP     H   VV    V    VM      PM 2.5
# 0   7.4   9.8  4.8  1017.6  93.0  0.5  4.3   9.4  219.720833
# 1   7.8  12.7  4.4  1018.5  87.0  0.6  4.4  11.1  182.187500
# 2   6.7  13.4  2.4  1019.4  82.0  0.6  4.8  11.1  154.037500
# 3   8.6  15.5  3.3  1018.7  72.0  0.8  8.1  20.6  223.208333
# 4  12.4  20.9  4.4  1017.3  61.0  1.3  8.7  22.2  200.645833

# %%
## Check for null values

sns.heatmap(df.isnull(),yticklabels=False,cbar=False,cmap='viridis')
# Out:
# <Axes: >

# %%
df=df.dropna()

# %%
X=df.iloc[:,:-1] ## independent features
y=df.iloc[:,-1] ## dependent features

# %%
## check null values
X.isnull()
# Out:
#          T     TM     Tm    SLP      H     VV      V     VM
# 0    False  False  False  False  False  False  False  False
# 1    False  False  False  False  False  False  False  False
# 2    False  False  False  False  False  False  False  False
# 3    False  False  False  False  False  False  False  False
# 4    False  False  False  False  False  False  False  False
# ..     ...    ...    ...    ...    ...    ...    ...    ...
# 726  False  False  False  False  False  False  False  False
# 727  False  False  False  False  False  False  False  False
# 728  False  False  False  False  False  False  False  False
# 729  False  False  False  False  False  False  False  False
# 730  False  False  False  False  False  False  False  False
#
# [730 rows x 8 columns]

# %%
y.isnull()
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 726    False
# 727    False
# 728    False
# 729    False
# 730    False
# Name: PM 2.5, Length: 730, dtype: bool

# %%
sns.pairplot(df)

# %%
df.corr()
# Out:
#                T        TM        Tm       SLP         H        VV         V  \
# T       1.000000  0.967276  0.958892 -0.884383 -0.518870  0.622637  0.326067
# TM      0.967276  1.000000  0.896699 -0.829254 -0.599629  0.598479  0.320116
# Tm      0.958892  0.896699  1.000000 -0.909514 -0.315305  0.560299  0.312904
# SLP    -0.884383 -0.829254 -0.909514  1.000000  0.274196 -0.491842 -0.346130
# H      -0.518870 -0.599629 -0.315305  0.274196  1.000000 -0.475279 -0.399079
# VV      0.622637  0.598479  0.560299 -0.491842 -0.475279  1.000000  0.402884
# V       0.326067  0.320116  0.312904 -0.346130 -0.399079  0.402884  1.000000
# VM      0.287138  0.299508  0.259431 -0.299830 -0.370981  0.347493  0.760777
# PM 2.5 -0.628336 -0.569381 -0.669059  0.615615  0.174658 -0.628621 -0.354799
#
#               VM    PM 2.5
# T       0.287138 -0.628336
# TM      0.299508 -0.569381
# Tm      0.259431 -0.669059
# SLP    -0.299830  0.615615
# H      -0.370981  0.174658
# VV      0.347493 -0.628621
# V       0.760777 -0.354799
# VM      1.000000 -0.283695
# PM 2.5 -0.283695  1.000000

# %% [markdown]
# ### Correlation Matrix with Heatmap

# %%
import seaborn as sns
#get correlations of each features in dataset
corrmat = df.corr()
top_corr_features = corrmat.index
plt.figure(figsize=(20,20))
#plot heat map
g=sns.heatmap(df[top_corr_features].corr(),annot=True,cmap="RdYlGn")

# %%
corrmat.index
# Out:
# Index(['T', 'TM', 'Tm', 'SLP', 'H', 'VV', 'V', 'VM', 'PM 2.5'], dtype='object')

# %% [markdown]
# ### Feature Importance

# %%
from sklearn.ensemble import ExtraTreesRegressor
import matplotlib.pyplot as plt
model = ExtraTreesRegressor()
model.fit(X,y)
# Out:
# ExtraTreesRegressor()

# %%
X.head()
# Out:
#       T    TM   Tm     SLP     H   VV    V    VM
# 0   7.4   9.8  4.8  1017.6  93.0  0.5  4.3   9.4
# 1   7.8  12.7  4.4  1018.5  87.0  0.6  4.4  11.1
# 2   6.7  13.4  2.4  1019.4  82.0  0.6  4.8  11.1
# 3   8.6  15.5  3.3  1018.7  72.0  0.8  8.1  20.6
# 4  12.4  20.9  4.4  1017.3  61.0  1.3  8.7  22.2

# %%
y.head()
# Out:
# 0    219.720833
# 1    182.187500
# 2    154.037500
# 3    223.208333
# 4    200.645833
# Name: PM 2.5, dtype: float64

# %%
print(model.feature_importances_)
# Out:
# [0.14050447 0.09038459 0.19740406 0.13522207 0.08152183 0.26535877
#  0.05138471 0.03821949]

# %%
feat_importances = pd.Series(model.feature_importances_, index=X.columns)
feat_importances.nlargest(5).plot(kind='barh')
plt.show()

# %% [markdown]
# # Linear Regression

# %%
sns.displot(y)

# %% [markdown]
# ### Train Test split

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=0)

# %%
from sklearn.linear_model import LinearRegression

# %%
regressor=LinearRegression()
regressor.fit(X_train,y_train)
# Out:
# LinearRegression()

# %%
regressor.coef_
# Out:
# array([ 2.63949039e+00,  5.19978529e-01, -7.59811846e+00,  4.93219944e-01,
#        -8.37064222e-01, -5.04301355e+01, -2.75417778e+00, -3.92662839e-02])

# %%
regressor.intercept_
# Out:
# -157.37425475061548

# %%
print("Coefficient of determination R^2 <-- on train set: {}".format(regressor.score(X_train, y_train)))
# Out:
# Coefficient of determination R^2 <-- on train set: 0.6007706404750854

# %%
print("Coefficient of determination R^2 <-- on test set: {}".format(regressor.score(X_test, y_test)))
# Out:
# Coefficient of determination R^2 <-- on test set: 0.5316188612878155

# %%
from sklearn.model_selection import cross_val_score
score=cross_val_score(regressor,X,y,cv=5)

# %%
score.mean()
# Out:
# 0.4672436225852336

# %% [markdown]
# #### Model Evaluation

# %%
coeff_df = pd.DataFrame(regressor.coef_,X.columns,columns=['Coefficient'])
coeff_df
# Out:
#      Coefficient
# T       2.639490
# TM      0.519979
# Tm     -7.598118
# SLP     0.493220
# H      -0.837064
# VV    -50.430135
# V      -2.754178
# VM     -0.039266

# %%
prediction=regressor.predict(X_test)

# %%
sns.displot(y_test-prediction)

# %%
plt.scatter(y_test,prediction)

# %%
from sklearn import metrics

# %%
print('MAE:', metrics.mean_absolute_error(y_test, prediction))
print('MSE:', metrics.mean_squared_error(y_test, prediction))
print('RMSE:', np.sqrt(metrics.mean_squared_error(y_test, prediction)))
# Out:
# MAE: 40.283355371329385
# MSE: 3057.664128674137
# RMSE: 55.29614931144968

# %%
import pickle

# %%
file = open('/content/drive/MyDrive/Airnode/regression_model.pkl', 'wb')

pickle.dump(regressor, file)

# %% [markdown]
# #Lasso Regression

# %%
from sklearn.model_selection import cross_val_score
from sklearn.linear_model import LinearRegression

# %%
lin_regressor=LinearRegression()
mse=cross_val_score(lin_regressor,X,y,scoring='neg_mean_squared_error',cv=5)
mean_mse=np.mean(mse)
print(mean_mse)
# Out:
# -3499.356187290205

# %% [markdown]
# ##Ridge Regression

# %%
from sklearn.linear_model import Ridge
from sklearn.model_selection import GridSearchCV

# %%
ridge=Ridge()
parameters={'alpha':[1e-15,1e-10,1e-8,1e-3,1e-2,1,5,10,20,30,35,40]}
ridge_regressor=GridSearchCV(ridge,parameters,scoring='neg_mean_squared_error',cv=5)
ridge_regressor.fit(X,y)
# Out:
# GridSearchCV(cv=5, estimator=Ridge(),
#              param_grid={'alpha': [1e-15, 1e-10, 1e-08, 0.001, 0.01, 1, 5, 10,
#                                    20, 30, 35, 40]},
#              scoring='neg_mean_squared_error')

# %%
print(ridge_regressor.best_params_)
print(ridge_regressor.best_score_)
# Out:
# {'alpha': 40}
# -3354.617157307126

# %% [markdown]
# ##Lasso Regression

# %%
from sklearn.linear_model import Lasso
from sklearn.model_selection import GridSearchCV

# %%
lasso=Lasso()
parameters={'alpha':[1e-15,1e-10,1e-8,1e-3,1e-2,1,5,10,20,30,35,40]}
lasso_regressor=GridSearchCV(lasso,parameters,scoring='neg_mean_squared_error',cv=5)

lasso_regressor.fit(X,y)
print(lasso_regressor.best_params_)
print(lasso_regressor.best_score_)
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/linear_model/_coordinate_descent.py:631: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 9.008e+05, tolerance: 4.247e+02
#   model = cd_fast.enet_coordinate_descent(
# /usr/local/lib/python3.10/dist-packages/sklearn/linear_model/_coordinate_descent.py:631: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 8.110e+05, tolerance: 3.871e+02
#   model = cd_fast.enet_coordinate_descent(
# /usr/local/lib/python3.10/dist-packages/sklearn/linear_model/_coordinate_descent.py:631: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 8.945e+05, tolerance: 4.110e+02
#   model = cd_fast.enet_coordinate_descent(
# /usr/local/lib/python3.10/dist-packages/sklearn/linear_model/_coordinate_descent.py:631: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 7.735e+05, tolerance: 3.696e+02
#   model = cd_fast.enet_coordinate_descent(
# /usr/local/lib/python3.10/dist-packages/sklearn/linear_model/_coordinate_descent.py:631: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 6.717e+05, tolerance: 3.898e+02
#   model = cd_fast.enet_coordinate_descent(
# /usr/local/lib/python3.10/dist-packages/sklearn/linear_model/_coordinate_descent.py:631: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 3.602e+05, tolerance: 4.247e+02
#   model = cd_fast.enet_coordinate_descent(
# /usr/local/lib/python3.10/dist-packages/sklearn/linear_model/_coordinate_descent.py:631: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 3.395e+04, tolerance: 3.871e+02
#   model = cd_fast.enet_coordinate_descent(
# /usr/local/lib/python3.10/dist-packages/sklearn/linear_model/_coordinate_descent.py:631: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 2.723e+05, tolerance: 4.110e+02
#   model = cd_fast.enet_coordinate_descent(
# /usr/local/lib/python3.10/dist-packages/sklearn/linear_model/_coordinate_descent.py:631: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 5.647e+05, tolerance: 3.696e+02
#   model = cd_fast.enet_coordinate_descent(
# /usr/local/lib/python3.10/dist-packages/sklearn/linear_model/_coordinate_descent.py:631: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 3.485e+05, tolerance: 3.898e+02
#   model = cd_fast.enet_coordinate_descent(
# /usr/local/lib/python3.10/dist-packages/sklearn/linear_model/_coordinate_descent.py:631: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 2.379e+03, tolerance: 3.696e+02
#   model = cd_fast.enet_coordinate_descent(
# /usr/local/lib/python3.10/dist-packages/sklearn/linear_model/_coordinate_descent.py:631: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 4.232e+02, tolerance: 3.898e+02
#   model = cd_fast.enet_coordinate_descent(
# {'alpha': 5}
# -3356.4102569706833

# %% [markdown]
# ##Model Evaluation

# %%
prediction=lasso_regressor.predict(X_test)

# %%
sns.displot(y_test-prediction)

# %%
plt.scatter(y_test,prediction)

# %%
from sklearn import metrics

# %%
print('MAE:', metrics.mean_absolute_error(y_test, prediction))
print('MSE:', metrics.mean_squared_error(y_test, prediction))
print('RMSE:', np.sqrt(metrics.mean_squared_error(y_test, prediction)))
# Out:
# MAE: 40.15696946997222
# MSE: 3103.265102660339
# RMSE: 55.70695739905689

# %%
import pickle

# %%
file = open('/content/drive/MyDrive/Airnode/lasso_regression_model.pkl', 'wb')

pickle.dump(lasso_regressor, file)

# %% [markdown]
# #Decision Tree Regressor

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=0)

# %%
from sklearn.tree import DecisionTreeRegressor

# %%
dtree=DecisionTreeRegressor(criterion="squared_error")

# %%
dtree.fit(X_train,y_train)
# Out:
# DecisionTreeRegressor()

# %%
print("Coefficient of determination R^2 <-- on train set: {}".format(dtree.score(X_train, y_train)))
# Out:
# Coefficient of determination R^2 <-- on train set: 1.0

# %%
print("Coefficient of determination R^2 <-- on test set: {}".format(dtree.score(X_test, y_test)))
# Out:
# Coefficient of determination R^2 <-- on test set: 0.3649541829368417

# %%
from sklearn.model_selection import cross_val_score
score=cross_val_score(dtree,X,y,cv=5)

# %%
score.mean()
# Out:
# 0.05671751695826781

# %% [markdown]
# ##Tree Visualization

# %%
from IPython.display import Image
from six import StringIO
from sklearn.tree import export_graphviz
import pydotplus

# %%
features = list(df.columns[:-1])
features
# Out:
# ['T', 'TM', 'Tm', 'SLP', 'H', 'VV', 'V', 'VM']

# %%
dot_data = StringIO()
export_graphviz(dtree, out_file=dot_data,feature_names=features,filled=True,rounded=True)

graph = pydotplus.graph_from_dot_data(dot_data.getvalue())
Image(graph.create_png())
# Out:
# ---------------------------------------------------------------------------
# ParseException                            Traceback (most recent call last)
# /usr/local/lib/python3.10/dist-packages/pyparsing/core.py in _parseCache(self, instring, loc, doActions, callPreParse)
#     920                 try:
# --> 921                     value = self._parseNoCache(instring, loc, doActions, callPreParse)
#     922                 except ParseBaseException as pe:
#
# /usr/local/lib/python3.10/dist-packages/pyparsing/core.py in _parseNoCache(self, instring, loc, doActions, callPreParse)
#     816                 try:
# --> 817                     loc, tokens = self.parseImpl(instring, pre_loc, doActions)
#     818                 except IndexError:
#
# /usr/local/lib/python3.10/dist-packages/pyparsing/core.py in parseImpl(self, instring, loc, doActions)
#    4374         if self.expr is not None:
# -> 4375             return self.expr._parse(instring, loc, doActions, callPreParse=False)
#    4376         else:
#
# /usr/local/lib/python3.10/dist-packages/pyparsing/core.py in _parseCache(self, instring, loc, doActions, callPreParse)
#     943                             pass
# --> 944                     raise value
#     945
#
# ParseException: Expected '//', found ';'  (at char 90502), (line:1692, col:12)
#
# During handling of the above exception, another exception occurred:
#
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-60-1978b4285d97> in <cell line: 4>()
#       2 export_graphviz(dtree, out_file=dot_data,feature_names=features,filled=True,rounded=True)
#       3
# ----> 4 graph = pydotplus.graph_from_dot_data(dot_data.getvalue())
#       5 Image(graph.create_png())
#
# /usr/local/lib/python3.10/dist-packages/pydotplus/graphviz.py in graph_from_dot_data(data)
#     300     """
#     301
# --> 302     return parser.parse_dot_data(data)
#     303
#     304
#
# /usr/local/lib/python3.10/dist-packages/pydotplus/parser.py in parse_dot_data(data)
#     556             graphparser.parseWithTabs()
#     557
# --> 558         tokens = graphparser.parseString(data)
#     559
#     560         if len(tokens) == 1:
#
# /usr/local/lib/python3.10/dist-packages/pyparsing/core.py in parse_string(self, instring, parse_all, parseAll)
#    1129             instring = instring.expandtabs()
#    1130         try:
# -> 1131             loc, tokens = self._parse(instring, 0)
#    1132             if parseAll:
#    1133                 loc = self.preParse(instring, loc)
#
# /usr/local/lib/python3.10/dist-packages/pyparsing/core.py in _parseCache(self, instring, loc, doActions, callPreParse)
#     919                 ParserElement.packrat_cache_stats[MISS] += 1
#     920                 try:
# --> 921                     value = self._parseNoCache(instring, loc, doActions, callPreParse)
#     922                 except ParseBaseException as pe:
#     923                     # cache a copy of the exception, without the traceback
#
# /usr/local/lib/python3.10/dist-packages/pyparsing/core.py in _parseNoCache(self, instring, loc, doActions, callPreParse)
#     815             if self.mayIndexError or pre_loc >= len_instring:
#     816                 try:
# --> 817                     loc, tokens = self.parseImpl(instring, pre_loc, doActions)
#     818                 except IndexError:
#     819                     raise ParseException(instring, len_instring, self.errmsg, self)
#
# /usr/local/lib/python3.10/dist-packages/pyparsing/core.py in parseImpl(self, instring, loc, doActions)
#    4788         if check_ender:
#    4789             try_not_ender(instring, loc)
# -> 4790         loc, tokens = self_expr_parse(instring, loc, doActions)
#    4791         try:
#    4792             hasIgnoreExprs = not not self.ignoreExprs
#
# /usr/local/lib/python3.10/dist-packages/pyparsing/core.py in _parseCache(self, instring, loc, doActions, callPreParse)
#     919                 ParserElement.packrat_cache_stats[MISS] += 1
#     920                 try:
# --> 921                     value = self._parseNoCache(instring, loc, doActions, callPreParse)
#     922                 except ParseBaseException as pe:
#     923                     # cache a copy of the exception, without the traceback
#
# /usr/local/lib/python3.10/dist-packages/pyparsing/core.py in _parseNoCache(self, instring, loc, doActions, callPreParse)
#     815             if self.mayIndexError or pre_loc >= len_instring:
#     816                 try:
# --> 817                     loc, tokens = self.parseImpl(instring, pre_loc, doActions)
#     818                 except IndexError:
#     819                     raise ParseException(instring, len_instring, self.errmsg, self)
#
# /usr/local/lib/python3.10/dist-packages/pyparsing/core.py in parseImpl(self, instring, loc, doActions)
#    3884                     )
#    3885             else:
# -> 3886                 loc, exprtokens = e._parse(instring, loc, doActions)
#    3887             if exprtokens or exprtokens.haskeys():
#    3888                 resultlist += exprtokens
#
# /usr/local/lib/python3.10/dist-packages/pyparsing/core.py in _parseCache(self, instring, loc, doActions, callPreParse)
#     919                 ParserElement.packrat_cache_stats[MISS] += 1
#     920                 try:
# --> 921                     value = self._parseNoCache(instring, loc, doActions, callPreParse)
#     922                 except ParseBaseException as pe:
#     923                     # cache a copy of the exception, without the traceback
#
# /usr/local/lib/python3.10/dist-packages/pyparsing/core.py in _parseNoCache(self, instring, loc, doActions, callPreParse)
#     815             if self.mayIndexError or pre_loc >= len_instring:
#     816                 try:
# --> 817                     loc, tokens = self.parseImpl(instring, pre_loc, doActions)
#     818                 except IndexError:
#     819                     raise ParseException(instring, len_instring, self.errmsg, self)
#
# /usr/local/lib/python3.10/dist-packages/pyparsing/core.py in parseImpl(self, instring, loc, doActions)
#    4373     def parseImpl(self, instring, loc, doActions=True):
#    4374         if self.expr is not None:
# -> 4375             return self.expr._parse(instring, loc, doActions, callPreParse=False)
#    4376         else:
#    4377             raise ParseException(instring, loc, "No expression defined", self)
#
# /usr/local/lib/python3.10/dist-packages/pyparsing/core.py in _parseCache(self, instring, loc, doActions, callPreParse)
#     919                 ParserElement.packrat_cache_stats[MISS] += 1
#     920                 try:
# --> 921                     value = self._parseNoCache(instring, loc, doActions, callPreParse)
#     922                 except ParseBaseException as pe:
#     923                     # cache a copy of the exception, without the traceback
#
# /usr/local/lib/python3.10/dist-packages/pyparsing/core.py in _parseNoCache(self, instring, loc, doActions, callPreParse)
#     815             if self.mayIndexError or pre_loc >= len_instring:
#     816                 try:
# --> 817                     loc, tokens = self.parseImpl(instring, pre_loc, doActions)
#     818                 except IndexError:
#     819                     raise ParseException(instring, len_instring, self.errmsg, self)
#
# /usr/local/lib/python3.10/dist-packages/pyparsing/core.py in parseImpl(self, instring, loc, doActions)
#    3884                     )
#    3885             else:
# -> 3886                 loc, exprtokens = e._parse(instring, loc, doActions)
#    3887             if exprtokens or exprtokens.haskeys():
#    3888                 resultlist += exprtokens
#
# /usr/local/lib/python3.10/dist-packages/pyparsing/core.py in _parseCache(self, instring, loc, doActions, callPreParse)
#     919                 ParserElement.packrat_cache_stats[MISS] += 1
#     920                 try:
# --> 921                     value = self._parseNoCache(instring, loc, doActions, callPreParse)
#     922                 except ParseBaseException as pe:
#     923                     # cache a copy of the exception, without the traceback
#
# /usr/local/lib/python3.10/dist-packages/pyparsing/core.py in _parseNoCache(self, instring, loc, doActions, callPreParse)
#     815             if self.mayIndexError or pre_loc >= len_instring:
#     816                 try:
# --> 817                     loc, tokens = self.parseImpl(instring, pre_loc, doActions)
#     818                 except IndexError:
#     819                     raise ParseException(instring, len_instring, self.errmsg, self)
#
# /usr/local/lib/python3.10/dist-packages/pyparsing/core.py in parseImpl(self, instring, loc, doActions)
#    4957         self_expr = self.expr
#    4958         try:
# -> 4959             loc, tokens = self_expr._parse(instring, loc, doActions, callPreParse=False)
#    4960         except (ParseException, IndexError):
#    4961             default_value = self.defaultValue
#
# /usr/local/lib/python3.10/dist-packages/pyparsing/core.py in _parseCache(self, instring, loc, doActions, callPreParse)
#     919                 ParserElement.packrat_cache_stats[MISS] += 1
#     920                 try:
# --> 921                     value = self._parseNoCache(instring, loc, doActions, callPreParse)
#     922                 except ParseBaseException as pe:
#     923                     # cache a copy of the exception, without the traceback
#
# /usr/local/lib/python3.10/dist-packages/pyparsing/core.py in _parseNoCache(self, instring, loc, doActions, callPreParse)
#     815             if self.mayIndexError or pre_loc >= len_instring:
#     816                 try:
# --> 817                     loc, tokens = self.parseImpl(instring, pre_loc, doActions)
#     818                 except IndexError:
#     819                     raise ParseException(instring, len_instring, self.errmsg, self)
#
# /usr/local/lib/python3.10/dist-packages/pyparsing/core.py in parseImpl(self, instring, loc, doActions)
#    5224             )
#    5225         if not ParserElement._left_recursion_enabled:
# -> 5226             return super().parseImpl(instring, loc, doActions)
#    5227         # ## Bounded Recursion algorithm ##
#    5228         # Recursion only needs to be processed at ``Forward`` elements, since they are
#
# /usr/local/lib/python3.10/dist-packages/pyparsing/core.py in parseImpl(self, instring, loc, doActions)
#    4373     def parseImpl(self, instring, loc, doActions=True):
#    4374         if self.expr is not None:
# -> 4375             return self.expr._parse(instring, loc, doActions, callPreParse=False)
#    4376         else:
#    4377             raise ParseException(instring, loc, "No expression defined", self)
#
# /usr/local/lib/python3.10/dist-packages/pyparsing/core.py in _parseCache(self, instring, loc, doActions, callPreParse)
#     919                 ParserElement.packrat_cache_stats[MISS] += 1
#     920                 try:
# --> 921                     value = self._parseNoCache(instring, loc, doActions, callPreParse)
#     922                 except ParseBaseException as pe:
#     923                     # cache a copy of the exception, without the traceback
#
# /usr/local/lib/python3.10/dist-packages/pyparsing/core.py in _parseNoCache(self, instring, loc, doActions, callPreParse)
#     815             if self.mayIndexError or pre_loc >= len_instring:
#     816                 try:
# --> 817                     loc, tokens = self.parseImpl(instring, pre_loc, doActions)
#     818                 except IndexError:
#     819                     raise ParseException(instring, len_instring, self.errmsg, self)
#
# /usr/local/lib/python3.10/dist-packages/pyparsing/core.py in parseImpl(self, instring, loc, doActions)
#    4798                 else:
#    4799                     preloc = loc
# -> 4800                 loc, tmptokens = self_expr_parse(instring, preloc, doActions)
#    4801                 if tmptokens or tmptokens.haskeys():
#    4802                     tokens += tmptokens
#
# /usr/local/lib/python3.10/dist-packages/pyparsing/core.py in _parseCache(self, instring, loc, doActions, callPreParse)
#     919                 ParserElement.packrat_cache_stats[MISS] += 1
#     920                 try:
# --> 921                     value = self._parseNoCache(instring, loc, doActions, callPreParse)
#     922                 except ParseBaseException as pe:
#     923                     # cache a copy of the exception, without the traceback
#
# /usr/local/lib/python3.10/dist-packages/pyparsing/core.py in _parseNoCache(self, instring, loc, doActions, callPreParse)
#     815             if self.mayIndexError or pre_loc >= len_instring:
#     816                 try:
# --> 817                     loc, tokens = self.parseImpl(instring, pre_loc, doActions)
#     818                 except IndexError:
#     819                     raise ParseException(instring, len_instring, self.errmsg, self)
#
# /usr/local/lib/python3.10/dist-packages/pyparsing/core.py in parseImpl(self, instring, loc, doActions)
#    3862         # pass False as callPreParse arg to _parse for first element, since we already
#    3863         # pre-parsed the string as part of our And pre-parsing
# -> 3864         loc, resultlist = self.exprs[0]._parse(
#    3865             instring, loc, doActions, callPreParse=False
#    3866         )
#
# /usr/local/lib/python3.10/dist-packages/pyparsing/core.py in _parseCache(self, instring, loc, doActions, callPreParse)
#     919                 ParserElement.packrat_cache_stats[MISS] += 1
#     920                 try:
# --> 921                     value = self._parseNoCache(instring, loc, doActions, callPreParse)
#     922                 except ParseBaseException as pe:
#     923                     # cache a copy of the exception, without the traceback
#
# /usr/local/lib/python3.10/dist-packages/pyparsing/core.py in _parseNoCache(self, instring, loc, doActions, callPreParse)
#     815             if self.mayIndexError or pre_loc >= len_instring:
#     816                 try:
# --> 817                     loc, tokens = self.parseImpl(instring, pre_loc, doActions)
#     818                 except IndexError:
#     819                     raise ParseException(instring, len_instring, self.errmsg, self)
#
# /usr/local/lib/python3.10/dist-packages/pyparsing/core.py in parseImpl(self, instring, loc, doActions)
#    4112         for e in self.exprs:
#    4113             try:
# -> 4114                 return e._parse(
#    4115                     instring,
#    4116                     loc,
#
# /usr/local/lib/python3.10/dist-packages/pyparsing/core.py in _parseCache(self, instring, loc, doActions, callPreParse)
#     919                 ParserElement.packrat_cache_stats[MISS] += 1
#     920                 try:
# --> 921                     value = self._parseNoCache(instring, loc, doActions, callPreParse)
#     922                 except ParseBaseException as pe:
#     923                     # cache a copy of the exception, without the traceback
#
# /usr/local/lib/python3.10/dist-packages/pyparsing/core.py in _parseNoCache(self, instring, loc, doActions, callPreParse)
#     815             if self.mayIndexError or pre_loc >= len_instring:
#     816                 try:
# --> 817                     loc, tokens = self.parseImpl(instring, pre_loc, doActions)
#     818                 except IndexError:
#     819                     raise ParseException(instring, len_instring, self.errmsg, self)
#
# /usr/local/lib/python3.10/dist-packages/pyparsing/core.py in parseImpl(self, instring, loc, doActions)
#    3884                     )
#    3885             else:
# -> 3886                 loc, exprtokens = e._parse(instring, loc, doActions)
#    3887             if exprtokens or exprtokens.haskeys():
#    3888                 resultlist += exprtokens
#
# /usr/local/lib/python3.10/dist-packages/pyparsing/core.py in _parseCache(self, instring, loc, doActions, callPreParse)
#     919                 ParserElement.packrat_cache_stats[MISS] += 1
#     920                 try:
# --> 921                     value = self._parseNoCache(instring, loc, doActions, callPreParse)
#     922                 except ParseBaseException as pe:
#     923                     # cache a copy of the exception, without the traceback
#
# /usr/local/lib/python3.10/dist-packages/pyparsing/core.py in _parseNoCache(self, instring, loc, doActions, callPreParse)
#     815             if self.mayIndexError or pre_loc >= len_instring:
#     816                 try:
# --> 817                     loc, tokens = self.parseImpl(instring, pre_loc, doActions)
#     818                 except IndexError:
#     819                     raise ParseException(instring, len_instring, self.errmsg, self)
#
# /usr/local/lib/python3.10/dist-packages/pyparsing/core.py in parseImpl(self, instring, loc, doActions)
#    4788         if check_ender:
#    4789             try_not_ender(instring, loc)
# -> 4790         loc, tokens = self_expr_parse(instring, loc, doActions)
#    4791         try:
#    4792             hasIgnoreExprs = not not self.ignoreExprs
#
# /usr/local/lib/python3.10/dist-packages/pyparsing/core.py in _parseCache(self, instring, loc, doActions, callPreParse)
#     919                 ParserElement.packrat_cache_stats[MISS] += 1
#     920                 try:
# --> 921                     value = self._parseNoCache(instring, loc, doActions, callPreParse)
#     922                 except ParseBaseException as pe:
#     923                     # cache a copy of the exception, without the traceback
#
# /usr/local/lib/python3.10/dist-packages/pyparsing/core.py in _parseNoCache(self, instring, loc, doActions, callPreParse)
#     815             if self.mayIndexError or pre_loc >= len_instring:
#     816                 try:
# --> 817                     loc, tokens = self.parseImpl(instring, pre_loc, doActions)
#     818                 except IndexError:
#     819                     raise ParseException(instring, len_instring, self.errmsg, self)
#
# /usr/local/lib/python3.10/dist-packages/pyparsing/core.py in parseImpl(self, instring, loc, doActions)
#    3884                     )
#    3885             else:
# -> 3886                 loc, exprtokens = e._parse(instring, loc, doActions)
#    3887             if exprtokens or exprtokens.haskeys():
#    3888                 resultlist += exprtokens
#
# /usr/local/lib/python3.10/dist-packages/pyparsing/core.py in _parseCache(self, instring, loc, doActions, callPreParse)
#     919                 ParserElement.packrat_cache_stats[MISS] += 1
#     920                 try:
# --> 921                     value = self._parseNoCache(instring, loc, doActions, callPreParse)
#     922                 except ParseBaseException as pe:
#     923                     # cache a copy of the exception, without the traceback
#
# /usr/local/lib/python3.10/dist-packages/pyparsing/core.py in _parseNoCache(self, instring, loc, doActions, callPreParse)
#     815             if self.mayIndexError or pre_loc >= len_instring:
#     816                 try:
# --> 817                     loc, tokens = self.parseImpl(instring, pre_loc, doActions)
#     818                 except IndexError:
#     819                     raise ParseException(instring, len_instring, self.errmsg, self)
#
# /usr/local/lib/python3.10/dist-packages/pyparsing/core.py in parseImpl(self, instring, loc, doActions)
#    5224             )
#    5225         if not ParserElement._left_recursion_enabled:
# -> 5226             return super().parseImpl(instring, loc, doActions)
#    5227         # ## Bounded Recursion algorithm ##
#    5228         # Recursion only needs to be processed at ``Forward`` elements, since they are
#
# /usr/local/lib/python3.10/dist-packages/pyparsing/core.py in parseImpl(self, instring, loc, doActions)
#    4373     def parseImpl(self, instring, loc, doActions=True):
#    4374         if self.expr is not None:
# -> 4375             return self.expr._parse(instring, loc, doActions, callPreParse=False)
#    4376         else:
#    4377             raise ParseException(instring, loc, "No expression defined", self)
#
# /usr/local/lib/python3.10/dist-packages/pyparsing/core.py in _parseCache(self, instring, loc, doActions, callPreParse)
#     919                 ParserElement.packrat_cache_stats[MISS] += 1
#     920                 try:
# --> 921                     value = self._parseNoCache(instring, loc, doActions, callPreParse)
#     922                 except ParseBaseException as pe:
#     923                     # cache a copy of the exception, without the traceback
#
# /usr/local/lib/python3.10/dist-packages/pyparsing/core.py in _parseNoCache(self, instring, loc, doActions, callPreParse)
#     815             if self.mayIndexError or pre_loc >= len_instring:
#     816                 try:
# --> 817                     loc, tokens = self.parseImpl(instring, pre_loc, doActions)
#     818                 except IndexError:
#     819                     raise ParseException(instring, len_instring, self.errmsg, self)
#
# /usr/local/lib/python3.10/dist-packages/pyparsing/core.py in parseImpl(self, instring, loc, doActions)
#    4373     def parseImpl(self, instring, loc, doActions=True):
#    4374         if self.expr is not None:
# -> 4375             return self.expr._parse(instring, loc, doActions, callPreParse=False)
#    4376         else:
#    4377             raise ParseException(instring, loc, "No expression defined", self)
#
# /usr/local/lib/python3.10/dist-packages/pyparsing/core.py in _parseCache(self, instring, loc, doActions, callPreParse)
#     919                 ParserElement.packrat_cache_stats[MISS] += 1
#     920                 try:
# --> 921                     value = self._parseNoCache(instring, loc, doActions, callPreParse)
#     922                 except ParseBaseException as pe:
#     923                     # cache a copy of the exception, without the traceback
#
# /usr/local/lib/python3.10/dist-packages/pyparsing/core.py in _parseNoCache(self, instring, loc, doActions, callPreParse)
#     815             if self.mayIndexError or pre_loc >= len_instring:
#     816                 try:
# --> 817                     loc, tokens = self.parseImpl(instring, pre_loc, doActions)
#     818                 except IndexError:
#     819                     raise ParseException(instring, len_instring, self.errmsg, self)
#
# /usr/local/lib/python3.10/dist-packages/pyparsing/core.py in parseImpl(self, instring, loc, doActions)
#    4112         for e in self.exprs:
#    4113             try:
# -> 4114                 return e._parse(
#    4115                     instring,
#    4116                     loc,
#
# /usr/local/lib/python3.10/dist-packages/pyparsing/core.py in _parseCache(self, instring, loc, doActions, callPreParse)
#     919                 ParserElement.packrat_cache_stats[MISS] += 1
#     920                 try:
# --> 921                     value = self._parseNoCache(instring, loc, doActions, callPreParse)
#     922                 except ParseBaseException as pe:
#     923                     # cache a copy of the exception, without the traceback
#
# /usr/local/lib/python3.10/dist-packages/pyparsing/core.py in _parseNoCache(self, instring, loc, doActions, callPreParse)
#     815             if self.mayIndexError or pre_loc >= len_instring:
#     816                 try:
# --> 817                     loc, tokens = self.parseImpl(instring, pre_loc, doActions)
#     818                 except IndexError:
#     819                     raise ParseException(instring, len_instring, self.errmsg, self)
#
# /usr/local/lib/python3.10/dist-packages/pyparsing/core.py in parseImpl(self, instring, loc, doActions)
#    3884                     )
#    3885             else:
# -> 3886                 loc, exprtokens = e._parse(instring, loc, doActions)
#    3887             if exprtokens or exprtokens.haskeys():
#    3888                 resultlist += exprtokens
#
# /usr/local/lib/python3.10/dist-packages/pyparsing/core.py in _parseCache(self, instring, loc, doActions, callPreParse)
#     919                 ParserElement.packrat_cache_stats[MISS] += 1
#     920                 try:
# --> 921                     value = self._parseNoCache(instring, loc, doActions, callPreParse)
#     922                 except ParseBaseException as pe:
#     923                     # cache a copy of the exception, without the traceback
#
# /usr/local/lib/python3.10/dist-packages/pyparsing/core.py in _parseNoCache(self, instring, loc, doActions, callPreParse)
#     815             if self.mayIndexError or pre_loc >= len_instring:
#     816                 try:
# --> 817                     loc, tokens = self.parseImpl(instring, pre_loc, doActions)
#     818                 except IndexError:
#     819                     raise ParseException(instring, len_instring, self.errmsg, self)
#
# /usr/local/lib/python3.10/dist-packages/pyparsing/core.py in parseImpl(self, instring, loc, doActions)
#    4957         self_expr = self.expr
#    4958         try:
# -> 4959             loc, tokens = self_expr._parse(instring, loc, doActions, callPreParse=False)
#    4960         except (ParseException, IndexError):
#    4961             default_value = self.defaultValue
#
# /usr/local/lib/python3.10/dist-packages/pyparsing/core.py in _parseCache(self, instring, loc, doActions, callPreParse)
#     919                 ParserElement.packrat_cache_stats[MISS] += 1
#     920                 try:
# --> 921                     value = self._parseNoCache(instring, loc, doActions, callPreParse)
#     922                 except ParseBaseException as pe:
#     923                     # cache a copy of the exception, without the traceback
#
# /usr/local/lib/python3.10/dist-packages/pyparsing/core.py in _parseNoCache(self, instring, loc, doActions, callPreParse)
#     815             if self.mayIndexError or pre_loc >= len_instring:
#     816                 try:
# --> 817                     loc, tokens = self.parseImpl(instring, pre_loc, doActions)
#     818                 except IndexError:
#     819                     raise ParseException(instring, len_instring, self.errmsg, self)
#
# /usr/local/lib/python3.10/dist-packages/pyparsing/core.py in parseImpl(self, instring, loc, doActions)
#    4112         for e in self.exprs:
#    4113             try:
# -> 4114                 return e._parse(
#    4115                     instring,
#    4116                     loc,
#
# /usr/local/lib/python3.10/dist-packages/pyparsing/core.py in _parseCache(self, instring, loc, doActions, callPreParse)
#     919                 ParserElement.packrat_cache_stats[MISS] += 1
#     920                 try:
# --> 921                     value = self._parseNoCache(instring, loc, doActions, callPreParse)
#     922                 except ParseBaseException as pe:
#     923                     # cache a copy of the exception, without the traceback
#
# /usr/local/lib/python3.10/dist-packages/pyparsing/core.py in _parseNoCache(self, instring, loc, doActions, callPreParse)
#     815             if self.mayIndexError or pre_loc >= len_instring:
#     816                 try:
# --> 817                     loc, tokens = self.parseImpl(instring, pre_loc, doActions)
#     818                 except IndexError:
#     819                     raise ParseException(instring, len_instring, self.errmsg, self)
#
# /usr/local/lib/python3.10/dist-packages/pyparsing/core.py in parseImpl(self, instring, loc, doActions)
#    4373     def parseImpl(self, instring, loc, doActions=True):
#    4374         if self.expr is not None:
# -> 4375             return self.expr._parse(instring, loc, doActions, callPreParse=False)
#    4376         else:
#    4377             raise ParseException(instring, loc, "No expression defined", self)
#
# /usr/local/lib/python3.10/dist-packages/pyparsing/core.py in _parseCache(self, instring, loc, doActions, callPreParse)
#     919                 ParserElement.packrat_cache_stats[MISS] += 1
#     920                 try:
# --> 921                     value = self._parseNoCache(instring, loc, doActions, callPreParse)
#     922                 except ParseBaseException as pe:
#     923                     # cache a copy of the exception, without the traceback
#
# /usr/local/lib/python3.10/dist-packages/pyparsing/core.py in _parseNoCache(self, instring, loc, doActions, callPreParse)
#     815             if self.mayIndexError or pre_loc >= len_instring:
#     816                 try:
# --> 817                     loc, tokens = self.parseImpl(instring, pre_loc, doActions)
#     818                 except IndexError:
#     819                     raise ParseException(instring, len_instring, self.errmsg, self)
#
# /usr/local/lib/python3.10/dist-packages/pyparsing/core.py in parseImpl(self, instring, loc, doActions)
#    3862         # pass False as callPreParse arg to _parse for first element, since we already
#    3863         # pre-parsed the string as part of our And pre-parsing
# -> 3864         loc, resultlist = self.exprs[0]._parse(
#    3865             instring, loc, doActions, callPreParse=False
#    3866         )
#
# /usr/local/lib/python3.10/dist-packages/pyparsing/core.py in _parseCache(self, instring, loc, doActions, callPreParse)
#     919                 ParserElement.packrat_cache_stats[MISS] += 1
#     920                 try:
# --> 921                     value = self._parseNoCache(instring, loc, doActions, callPreParse)
#     922                 except ParseBaseException as pe:
#     923                     # cache a copy of the exception, without the traceback
#
# /usr/local/lib/python3.10/dist-packages/pyparsing/core.py in _parseNoCache(self, instring, loc, doActions, callPreParse)
#     815             if self.mayIndexError or pre_loc >= len_instring:
#     816                 try:
# --> 817                     loc, tokens = self.parseImpl(instring, pre_loc, doActions)
#     818                 except IndexError:
#     819                     raise ParseException(instring, len_instring, self.errmsg, self)
#
# /usr/local/lib/python3.10/dist-packages/pyparsing/core.py in parseImpl(self, instring, loc, doActions)
#    4112         for e in self.exprs:
#    4113             try:
# -> 4114                 return e._parse(
#    4115                     instring,
#    4116                     loc,
#
# /usr/local/lib/python3.10/dist-packages/pyparsing/core.py in _parseCache(self, instring, loc, doActions, callPreParse)
#     919                 ParserElement.packrat_cache_stats[MISS] += 1
#     920                 try:
# --> 921                     value = self._parseNoCache(instring, loc, doActions, callPreParse)
#     922                 except ParseBaseException as pe:
#     923                     # cache a copy of the exception, without the traceback
#
# /usr/local/lib/python3.10/dist-packages/pyparsing/core.py in _parseNoCache(self, instring, loc, doActions, callPreParse)
#     809         else:
#     810             if callPreParse and self.callPreparse:
# --> 811                 pre_loc = self.preParse(instring, loc)
#     812             else:
#     813                 pre_loc = loc
#
# /usr/local/lib/python3.10/dist-packages/pyparsing/core.py in preParse(self, instring, loc)
#     757     def preParse(self, instring, loc):
#     758         if self.ignoreExprs:
# --> 759             loc = self._skipIgnorables(instring, loc)
#     760
#     761         if self.skipWhitespace:
#
# /usr/local/lib/python3.10/dist-packages/pyparsing/core.py in _skipIgnorables(self, instring, loc)
#     749                 try:
#     750                     while 1:
# --> 751                         loc, dummy = e._parse(instring, loc)
#     752                         exprsFound = True
#     753                 except ParseException:
#
# /usr/local/lib/python3.10/dist-packages/pyparsing/core.py in _parseCache(self, instring, loc, doActions, callPreParse)
#     919                 ParserElement.packrat_cache_stats[MISS] += 1
#     920                 try:
# --> 921                     value = self._parseNoCache(instring, loc, doActions, callPreParse)
#     922                 except ParseBaseException as pe:
#     923                     # cache a copy of the exception, without the traceback
#
# /usr/local/lib/python3.10/dist-packages/pyparsing/core.py in _parseNoCache(self, instring, loc, doActions, callPreParse)
#     815             if self.mayIndexError or pre_loc >= len_instring:
#     816                 try:
# --> 817                     loc, tokens = self.parseImpl(instring, pre_loc, doActions)
#     818                 except IndexError:
#     819                     raise ParseException(instring, len_instring, self.errmsg, self)
#
# /usr/local/lib/python3.10/dist-packages/pyparsing/core.py in parseImpl(self, instring, loc, doActions)
#    4373     def parseImpl(self, instring, loc, doActions=True):
#    4374         if self.expr is not None:
# -> 4375             return self.expr._parse(instring, loc, doActions, callPreParse=False)
#    4376         else:
#    4377             raise ParseException(instring, loc, "No expression defined", self)
#
# /usr/local/lib/python3.10/dist-packages/pyparsing/core.py in _parseCache(self, instring, loc, doActions, callPreParse)
#     919                 ParserElement.packrat_cache_stats[MISS] += 1
#     920                 try:
# --> 921                     value = self._parseNoCache(instring, loc, doActions, callPreParse)
#     922                 except ParseBaseException as pe:
#     923                     # cache a copy of the exception, without the traceback
#
# /usr/local/lib/python3.10/dist-packages/pyparsing/core.py in _parseNoCache(self, instring, loc, doActions, callPreParse)
#     815             if self.mayIndexError or pre_loc >= len_instring:
#     816                 try:
# --> 817                     loc, tokens = self.parseImpl(instring, pre_loc, doActions)
#     818                 except IndexError:
#     819                     raise ParseException(instring, len_instring, self.errmsg, self)
#
# /usr/local/lib/python3.10/dist-packages/pyparsing/core.py in parseImpl(self, instring, loc, doActions)
#    4112         for e in self.exprs:
#    4113             try:
# -> 4114                 return e._parse(
#    4115                     instring,
#    4116                     loc,
#
# /usr/local/lib/python3.10/dist-packages/pyparsing/core.py in _parseCache(self, instring, loc, doActions, callPreParse)
#     922                 except ParseBaseException as pe:
#     923                     # cache a copy of the exception, without the traceback
# --> 924                     cache.set(lookup, pe.__class__(*pe.args))
#     925                     raise
#     926                 else:
#
# /usr/local/lib/python3.10/dist-packages/pyparsing/util.py in set_(_, key, value)
#     112             cache[key] = value
#     113             while len(cache) > size:
# --> 114                 cache.popitem(last=False)
#     115
#     116         def clear(_):
#
# KeyboardInterrupt:

# %% [markdown]
# ##Model Evaluation

# %%
prediction=dtree.predict(X_test)

# %%
sns.displot(y_test-prediction)

# %%
plt.scatter(y_test,prediction)

# %% [markdown]
# ##Hyperparameter Tuning DEcision Tree Regressor

# %%
DecisionTreeRegressor()
# Out:
# DecisionTreeRegressor()

# %%
## Hyper Parameter Optimization

params={
 "splitter"    : ["best","random"] ,
 "max_depth"        : [ 3, 4, 5, 6, 8, 10, 12, 15],
 "min_samples_leaf" : [ 1,2,3,4,5 ],
"min_weight_fraction_leaf":[0.1,0.2,0.3,0.4],
 "max_features" : ["auto","log2","sqrt",None ],
    "max_leaf_nodes":[None,10,20,30,40,50,60,70]

}

# %%
## Hyperparameter optimization using GridSearchCV
from sklearn.model_selection import GridSearchCV

# %%
random_search=GridSearchCV(dtree,param_grid=params,scoring='neg_mean_squared_error',n_jobs=-1,cv=10,verbose=3)

# %%
def timer(start_time=None):
    if not start_time:
        start_time = datetime.now()
        return start_time
    elif start_time:
        thour, temp_sec = divmod((datetime.now() - start_time).total_seconds(), 3600)
        tmin, tsec = divmod(temp_sec, 60)
        print('\n Time taken: %i hours %i minutes and %s seconds.' % (thour, tmin, round(tsec, 2)))

# %%
from datetime import datetime

start_time = timer(None)
random_search.fit(X,y)
timer(start_time)
# Out:
# Fitting 10 folds for each of 10240 candidates, totalling 102400 fits
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-109-2c7c7c9be64d> in <cell line: 4>()
#       2
#       3 start_time = timer(None)
# ----> 4 random_search.fit(X,y)
#       5 timer(start_time)
#
# /usr/local/lib/python3.10/dist-packages/sklearn/model_selection/_search.py in fit(self, X, y, groups, **fit_params)
#     872                 return results
#     873
# --> 874             self._run_search(evaluate_candidates)
#     875
#     876             # multimetric is determined here because in the case of a callable
#
# /usr/local/lib/python3.10/dist-packages/sklearn/model_selection/_search.py in _run_search(self, evaluate_candidates)
#    1386     def _run_search(self, evaluate_candidates):
#    1387         """Search all candidates in param_grid"""
# -> 1388         evaluate_candidates(ParameterGrid(self.param_grid))
#    1389
#    1390
#
# /usr/local/lib/python3.10/dist-packages/sklearn/model_selection/_search.py in evaluate_candidates(candidate_params, cv, more_results)
#     819                     )
#     820
# --> 821                 out = parallel(
#     822                     delayed(_fit_and_score)(
#     823                         clone(base_estimator),
#
# /usr/local/lib/python3.10/dist-packages/sklearn/utils/parallel.py in __call__(self, iterable)
#      61             for delayed_func, args, kwargs in iterable
#      62         )
# ---> 63         return super().__call__(iterable_with_config)
#      64
#      65
#
# /usr/local/lib/python3.10/dist-packages/joblib/parallel.py in __call__(self, iterable)
#    1096
#    1097             with self._backend.retrieval_context():
# -> 1098                 self.retrieve()
#    1099             # Make sure that we get a last message telling us we are done
#    1100             elapsed_time = time.time() - self._start_time
#
# /usr/local/lib/python3.10/dist-packages/joblib/parallel.py in retrieve(self)
#     973             try:
#     974                 if getattr(self._backend, 'supports_timeout', False):
# --> 975                     self._output.extend(job.get(timeout=self.timeout))
#     976                 else:
#     977                     self._output.extend(job.get())
#
# /usr/local/lib/python3.10/dist-packages/joblib/_parallel_backends.py in wrap_future_result(future, timeout)
#     565         AsyncResults.get from multiprocessing."""
#     566         try:
# --> 567             return future.result(timeout=timeout)
#     568         except CfTimeoutError as e:
#     569             raise TimeoutError from e
#
# /usr/lib/python3.10/concurrent/futures/_base.py in result(self, timeout)
#     451                     return self.__get_result()
#     452
# --> 453                 self._condition.wait(timeout)
#     454
#     455                 if self._state in [CANCELLED, CANCELLED_AND_NOTIFIED]:
#
# /usr/lib/python3.10/threading.py in wait(self, timeout)
#     318         try:    # restore state no matter what (e.g., KeyboardInterrupt)
#     319             if timeout is None:
# --> 320                 waiter.acquire()
#     321                 gotit = True
#     322             else:
#
# KeyboardInterrupt:

# %%
random_search.best_params_

# %%
random_search.best_score_

# %%
predictions=random_search.predict(X_test)

# %%
sns.displot(y_test-predictions)

# %%
print('MAE:', metrics.mean_absolute_error(y_test, predictions))
print('MSE:', metrics.mean_squared_error(y_test, predictions))
print('RMSE:', np.sqrt(metrics.mean_squared_error(y_test, predictions)))

# %% [markdown]
# ##Regression Evaluation Metrics

# %%
from sklearn import metrics

# %%
print('MAE:', metrics.mean_absolute_error(y_test, prediction))
print('MSE:', metrics.mean_squared_error(y_test, prediction))
print('RMSE:', np.sqrt(metrics.mean_squared_error(y_test, prediction)))

# %%
import pickle

# %%
file = open('/content/drive/MyDrive/Airnode/decision_regression_model.pkl', 'wb')

pickle.dump(random_search, file)

# %% [markdown]
# #Random Forest Regressor

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=0)

# %%
from sklearn.ensemble import RandomForestRegressor

# %%
regressor=RandomForestRegressor()
regressor.fit(X_train,y_train)
# Out:
# RandomForestRegressor()

# %%
print("Coefficient of determination R^2 <-- on train set: {}".format(regressor.score(X_train, y_train)))
# Out:
# Coefficient of determination R^2 <-- on train set: 0.9490906265241439

# %%
print("Coefficient of determination R^2 <-- on train set: {}".format(regressor.score(X_test, y_test)))
# Out:
# Coefficient of determination R^2 <-- on train set: 0.6375384288000268

# %%
from sklearn.model_selection import cross_val_score
score=cross_val_score(regressor,X,y,cv=5)

# %%
score.mean()
# Out:
# 0.49716763871454805

# %% [markdown]
# ##Model Evaluation

# %%
prediction=regressor.predict(X_test)

# %%
sns.displot(y_test-prediction)

# %%
plt.scatter(y_test,prediction)

# %% [markdown]
# ##Hyperparameter Tuning

# %%
RandomForestRegressor()
# Out:
# RandomForestRegressor()

# %%
from sklearn.model_selection import RandomizedSearchCV

# %%
n_estimators = [int(x) for x in np.linspace(start = 100, stop = 1200, num = 12)]
print(n_estimators)
# Out:
# [100, 200, 300, 400, 500, 600, 700, 800, 900, 1000, 1100, 1200]

# %%
 #Randomized Search CV

# Number of trees in random forest
n_estimators = [int(x) for x in np.linspace(start = 100, stop = 1200, num = 12)]
# Number of features to consider at every split
max_features = ['auto', 'sqrt']
# Maximum number of levels in tree
max_depth = [int(x) for x in np.linspace(5, 30, num = 6)]
# max_depth.append(None)
# Minimum number of samples required to split a node
min_samples_split = [2, 5, 10, 15, 100]
# Minimum number of samples required at each leaf node
min_samples_leaf = [1, 2, 5, 10]
# Method of selecting samples for training each tree
# bootstrap = [True, False]

# %%
random_grid = {'n_estimators': n_estimators,
               'max_features': max_features,
               'max_depth': max_depth,
               'min_samples_split': min_samples_split,
               'min_samples_leaf': min_samples_leaf}

print(random_grid)
# Out:
# {'n_estimators': [100, 200, 300, 400, 500, 600, 700, 800, 900, 1000, 1100, 1200], 'max_features': ['auto', 'sqrt'], 'max_depth': [5, 10, 15, 20, 25, 30], 'min_samples_split': [2, 5, 10, 15, 100], 'min_samples_leaf': [1, 2, 5, 10]}

# %%
rf = RandomForestRegressor()

# %%
rf_random = RandomizedSearchCV(estimator = rf, param_distributions = random_grid,scoring='neg_mean_squared_error', n_iter = 100, cv = 5, verbose=2, random_state=42, n_jobs = 1)

# %%
rf_random.fit(X_train,y_train)
# Out:
# Fitting 5 folds for each of 100 candidates, totalling 500 fits
# [CV] END max_depth=5, max_features=sqrt, min_samples_leaf=10, min_samples_split=100, n_estimators=400; total time=   0.6s
# [CV] END max_depth=5, max_features=sqrt, min_samples_leaf=10, min_samples_split=100, n_estimators=400; total time=   0.6s
# [CV] END max_depth=5, max_features=sqrt, min_samples_leaf=10, min_samples_split=100, n_estimators=400; total time=   0.6s
# [CV] END max_depth=5, max_features=sqrt, min_samples_leaf=10, min_samples_split=100, n_estimators=400; total time=   0.6s
# [CV] END max_depth=5, max_features=sqrt, min_samples_leaf=10, min_samples_split=100, n_estimators=400; total time=   0.6s
# /usr/local/lib/python3.10/dist-packages/sklearn/ensemble/_forest.py:413: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features=1.0` or remove this parameter as it is also the default value for RandomForestRegressors and ExtraTreesRegressors.
#   warn(
# [CV] END max_depth=20, max_features=auto, min_samples_leaf=1, min_samples_split=5, n_estimators=200; total time=   0.6s
# /usr/local/lib/python3.10/dist-packages/sklearn/ensemble/_forest.py:413: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features=1.0` or remove this parameter as it is also the default value for RandomForestRegressors and ExtraTreesRegressors.
#   warn(
# [CV] END max_depth=20, max_features=auto, min_samples_leaf=1, min_samples_split=5, n_estimators=200; total time=   0.9s
# /usr/local/lib/python3.10/dist-packages/sklearn/ensemble/_forest.py:413: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features=1.0` or remove this parameter as it is also the default value for RandomForestRegressors and ExtraTreesRegressors.
#   warn(
# [CV] END max_depth=20, max_features=auto, min_samples_leaf=1, min_samples_split=5, n_estimators=200; total time=   1.0s
# /usr/local/lib/python3.10/dist-packages/sklearn/ensemble/_forest.py:413: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features=1.0` or remove this parameter as it is also the default value for RandomForestRegressors and ExtraTreesRegressors.
#   warn(
# [CV] END max_depth=20, max_features=auto, min_samples_leaf=1, min_samples_split=5, n_estimators=200; total time=   0.9s
# /usr/local/lib/python3.10/dist-packages/sklearn/ensemble/_forest.py:413: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features=1.0` or remove this parameter as it is also the default value for RandomForestRegressors and ExtraTreesRegressors.
#   warn(
# [CV] END max_depth=20, max_features=auto, min_samples_leaf=1, min_samples_split=5, n_estimators=200; total time=   1.7s
# [CV] END max_depth=25, max_features=sqrt, min_samples_leaf=10, min_samples_split=15, n_estimators=200; total time=   0.7s
# [CV] END max_depth=25, max_features=sqrt, min_samples_leaf=10, min_samples_split=15, n_estimators=200; total time=   0.6s
# [CV] END max_depth=25, max_features=sqrt, min_samples_leaf=10, min_samples_split=15, n_estimators=200; total time=   0.7s
# [CV] END max_depth=25, max_features=sqrt, min_samples_leaf=10, min_samples_split=15, n_estimators=200; total time=   0.4s
# [CV] END max_depth=25, max_features=sqrt, min_samples_leaf=10, min_samples_split=15, n_estimators=200; total time=   0.4s
# /usr/local/lib/python3.10/dist-packages/sklearn/ensemble/_forest.py:413: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features=1.0` or remove this parameter as it is also the default value for RandomForestRegressors and ExtraTreesRegressors.
#   warn(
# [CV] END max_depth=20, max_features=auto, min_samples_leaf=5, min_samples_split=15, n_estimators=600; total time=   1.5s
# /usr/local/lib/python3.10/dist-packages/sklearn/ensemble/_forest.py:413: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features=1.0` or remove this parameter as it is also the default value for RandomForestRegressors and ExtraTreesRegressors.
#   warn(
# [CV] END max_depth=20, max_features=auto, min_samples_leaf=5, min_samples_split=15, n_estimators=600; total time=   1.4s
# /usr/local/lib/python3.10/dist-packages/sklearn/ensemble/_forest.py:413: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features=1.0` or remove this parameter as it is also the default value for RandomForestRegressors and ExtraTreesRegressors.
#   warn(
# [CV] END max_depth=20, max_features=auto, min_samples_leaf=5, min_samples_split=15, n_estimators=600; total time=   1.5s
# /usr/local/lib/python3.10/dist-packages/sklearn/ensemble/_forest.py:413: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features=1.0` or remove this parameter as it is also the default value for RandomForestRegressors and ExtraTreesRegressors.
#   warn(
# [CV] END max_depth=20, max_features=auto, min_samples_leaf=5, min_samples_split=15, n_estimators=600; total time=   1.4s
# /usr/local/lib/python3.10/dist-packages/sklearn/ensemble/_forest.py:413: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features=1.0` or remove this parameter as it is also the default value for RandomForestRegressors and ExtraTreesRegressors.
#   warn(
# [CV] END max_depth=20, max_features=auto, min_samples_leaf=5, min_samples_split=15, n_estimators=600; total time=   1.6s
# /usr/local/lib/python3.10/dist-packages/sklearn/ensemble/_forest.py:413: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features=1.0` or remove this parameter as it is also the default value for RandomForestRegressors and ExtraTreesRegressors.
#   warn(
# [CV] END max_depth=15, max_features=auto, min_samples_leaf=5, min_samples_split=5, n_estimators=300; total time=   1.2s
# /usr/local/lib/python3.10/dist-packages/sklearn/ensemble/_forest.py:413: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features=1.0` or remove this parameter as it is also the default value for RandomForestRegressors and ExtraTreesRegressors.
#   warn(
# [CV] END max_depth=15, max_features=auto, min_samples_leaf=5, min_samples_split=5, n_estimators=300; total time=   1.3s
# /usr/local/lib/python3.10/dist-packages/sklearn/ensemble/_forest.py:413: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features=1.0` or remove this parameter as it is also the default value for RandomForestRegressors and ExtraTreesRegressors.
#   warn(
# [CV] END max_depth=15, max_features=auto, min_samples_leaf=5, min_samples_split=5, n_estimators=300; total time=   1.3s
# /usr/local/lib/python3.10/dist-packages/sklearn/ensemble/_forest.py:413: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features=1.0` or remove this parameter as it is also the default value for RandomForestRegressors and ExtraTreesRegressors.
#   warn(
# [CV] END max_depth=15, max_features=auto, min_samples_leaf=5, min_samples_split=5, n_estimators=300; total time=   1.0s
# /usr/local/lib/python3.10/dist-packages/sklearn/ensemble/_forest.py:413: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features=1.0` or remove this parameter as it is also the default value for RandomForestRegressors and ExtraTreesRegressors.
#   warn(
# [CV] END max_depth=15, max_features=auto, min_samples_leaf=5, min_samples_split=5, n_estimators=300; total time=   0.8s
# [CV] END max_depth=15, max_features=sqrt, min_samples_leaf=1, min_samples_split=100, n_estimators=800; total time=   1.3s
# [CV] END max_depth=15, max_features=sqrt, min_samples_leaf=1, min_samples_split=100, n_estimators=800; total time=   1.3s
# [CV] END max_depth=15, max_features=sqrt, min_samples_leaf=1, min_samples_split=100, n_estimators=800; total time=   1.3s
# [CV] END max_depth=15, max_features=sqrt, min_samples_leaf=1, min_samples_split=100, n_estimators=800; total time=   1.3s
# [CV] END max_depth=15, max_features=sqrt, min_samples_leaf=1, min_samples_split=100, n_estimators=800; total time=   1.2s
# [CV] END max_depth=15, max_features=auto, min_samples_leaf=5, min_samples_split=100, n_estimators=100; total time=   0.2s
# /usr/local/lib/python3.10/dist-packages/sklearn/ensemble/_forest.py:413: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features=1.0` or remove this parameter as it is also the default value for RandomForestRegressors and ExtraTreesRegressors.
#   warn(
# [CV] END max_depth=15, max_features=auto, min_samples_leaf=5, min_samples_split=100, n_estimators=100; total time=   0.2s
# /usr/local/lib/python3.10/dist-packages/sklearn/ensemble/_forest.py:413: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features=1.0` or remove this parameter as it is also the default value for RandomForestRegressors and ExtraTreesRegressors.
#   warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/ensemble/_forest.py:413: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features=1.0` or remove this parameter as it is also the default value for RandomForestRegressors and ExtraTreesRegressors.
#   warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/ensemble/_forest.py:413: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features=1.0` or remove this parameter as it is also the default value for RandomForestRegressors and ExtraTreesRegressors.
#   warn(
# [CV] END max_depth=15, max_features=auto, min_samples_leaf=5, min_samples_split=100, n_estimators=100; total time=   0.2s
# [CV] END max_depth=15, max_features=auto, min_samples_leaf=5, min_samples_split=100, n_estimators=100; total time=   0.2s
# [CV] END max_depth=15, max_features=auto, min_samples_leaf=5, min_samples_split=100, n_estimators=100; total time=   0.2s
# /usr/local/lib/python3.10/dist-packages/sklearn/ensemble/_forest.py:413: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features=1.0` or remove this parameter as it is also the default value for RandomForestRegressors and ExtraTreesRegressors.
#   warn(
# [CV] END max_depth=25, max_features=sqrt, min_samples_leaf=2, min_samples_split=10, n_estimators=900; total time=   1.6s
# [CV] END max_depth=25, max_features=sqrt, min_samples_leaf=2, min_samples_split=10, n_estimators=900; total time=   2.6s
# [CV] END max_depth=25, max_features=sqrt, min_samples_leaf=2, min_samples_split=10, n_estimators=900; total time=   2.3s
# [CV] END max_depth=25, max_features=sqrt, min_samples_leaf=2, min_samples_split=10, n_estimators=900; total time=   1.6s
# [CV] END max_depth=25, max_features=sqrt, min_samples_leaf=2, min_samples_split=10, n_estimators=900; total time=   1.6s
# [CV] END max_depth=10, max_features=sqrt, min_samples_leaf=10, min_samples_split=15, n_estimators=1000; total time=   1.6s
# [CV] END max_depth=10, max_features=sqrt, min_samples_leaf=10, min_samples_split=15, n_estimators=1000; total time=   1.6s
# [CV] END max_depth=10, max_features=sqrt, min_samples_leaf=10, min_samples_split=15, n_estimators=1000; total time=   1.7s
# [CV] END max_depth=10, max_features=sqrt, min_samples_leaf=10, min_samples_split=15, n_estimators=1000; total time=   1.7s
# [CV] END max_depth=10, max_features=sqrt, min_samples_leaf=10, min_samples_split=15, n_estimators=1000; total time=   2.7s
# [CV] END max_depth=20, max_features=sqrt, min_samples_leaf=5, min_samples_split=2, n_estimators=100; total time=   0.3s
# [CV] END max_depth=20, max_features=sqrt, min_samples_leaf=5, min_samples_split=2, n_estimators=100; total time=   0.3s
# [CV] END max_depth=20, max_features=sqrt, min_samples_leaf=5, min_samples_split=2, n_estimators=100; total time=   0.3s
# [CV] END max_depth=20, max_features=sqrt, min_samples_leaf=5, min_samples_split=2, n_estimators=100; total time=   0.3s
# [CV] END max_depth=20, max_features=sqrt, min_samples_leaf=5, min_samples_split=2, n_estimators=100; total time=   0.3s
# [CV] END max_depth=30, max_features=sqrt, min_samples_leaf=5, min_samples_split=5, n_estimators=300; total time=   0.6s
# [CV] END max_depth=30, max_features=sqrt, min_samples_leaf=5, min_samples_split=5, n_estimators=300; total time=   0.5s
# [CV] END max_depth=30, max_features=sqrt, min_samples_leaf=5, min_samples_split=5, n_estimators=300; total time=   0.5s
# [CV] END max_depth=30, max_features=sqrt, min_samples_leaf=5, min_samples_split=5, n_estimators=300; total time=   0.5s
# [CV] END max_depth=30, max_features=sqrt, min_samples_leaf=5, min_samples_split=5, n_estimators=300; total time=   0.6s
# [CV] END max_depth=30, max_features=sqrt, min_samples_leaf=2, min_samples_split=10, n_estimators=400; total time=   0.7s
# [CV] END max_depth=30, max_features=sqrt, min_samples_leaf=2, min_samples_split=10, n_estimators=400; total time=   0.7s
# [CV] END max_depth=30, max_features=sqrt, min_samples_leaf=2, min_samples_split=10, n_estimators=400; total time=   0.7s
# [CV] END max_depth=30, max_features=sqrt, min_samples_leaf=2, min_samples_split=10, n_estimators=400; total time=   0.7s
# [CV] END max_depth=30, max_features=sqrt, min_samples_leaf=2, min_samples_split=10, n_estimators=400; total time=   0.7s
# [CV] END max_depth=5, max_features=sqrt, min_samples_leaf=5, min_samples_split=2, n_estimators=900; total time=   1.5s
# [CV] END max_depth=5, max_features=sqrt, min_samples_leaf=5, min_samples_split=2, n_estimators=900; total time=   1.5s
# [CV] END max_depth=5, max_features=sqrt, min_samples_leaf=5, min_samples_split=2, n_estimators=900; total time=   1.9s
# [CV] END max_depth=5, max_features=sqrt, min_samples_leaf=5, min_samples_split=2, n_estimators=900; total time=   2.3s
# [CV] END max_depth=5, max_features=sqrt, min_samples_leaf=5, min_samples_split=2, n_estimators=900; total time=   1.9s
# [CV] END max_depth=20, max_features=sqrt, min_samples_leaf=2, min_samples_split=5, n_estimators=900; total time=   1.6s
# [CV] END max_depth=20, max_features=sqrt, min_samples_leaf=2, min_samples_split=5, n_estimators=900; total time=   1.7s
# [CV] END max_depth=20, max_features=sqrt, min_samples_leaf=2, min_samples_split=5, n_estimators=900; total time=   1.6s
# [CV] END max_depth=20, max_features=sqrt, min_samples_leaf=2, min_samples_split=5, n_estimators=900; total time=   1.6s
# [CV] END max_depth=20, max_features=sqrt, min_samples_leaf=2, min_samples_split=5, n_estimators=900; total time=   1.6s
# [CV] END max_depth=10, max_features=sqrt, min_samples_leaf=2, min_samples_split=15, n_estimators=200; total time=   0.3s
# [CV] END max_depth=10, max_features=sqrt, min_samples_leaf=2, min_samples_split=15, n_estimators=200; total time=   0.3s
# [CV] END max_depth=10, max_features=sqrt, min_samples_leaf=2, min_samples_split=15, n_estimators=200; total time=   0.4s
# [CV] END max_depth=10, max_features=sqrt, min_samples_leaf=2, min_samples_split=15, n_estimators=200; total time=   0.4s
# [CV] END max_depth=10, max_features=sqrt, min_samples_leaf=2, min_samples_split=15, n_estimators=200; total time=   0.5s
# [CV] END max_depth=10, max_features=sqrt, min_samples_leaf=2, min_samples_split=2, n_estimators=200; total time=   0.6s
# [CV] END max_depth=10, max_features=sqrt, min_samples_leaf=2, min_samples_split=2, n_estimators=200; total time=   0.6s
# [CV] END max_depth=10, max_features=sqrt, min_samples_leaf=2, min_samples_split=2, n_estimators=200; total time=   0.6s
# [CV] END max_depth=10, max_features=sqrt, min_samples_leaf=2, min_samples_split=2, n_estimators=200; total time=   0.6s
# [CV] END max_depth=10, max_features=sqrt, min_samples_leaf=2, min_samples_split=2, n_estimators=200; total time=   0.6s
# /usr/local/lib/python3.10/dist-packages/sklearn/ensemble/_forest.py:413: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features=1.0` or remove this parameter as it is also the default value for RandomForestRegressors and ExtraTreesRegressors.
#   warn(
# [CV] END max_depth=10, max_features=auto, min_samples_leaf=1, min_samples_split=5, n_estimators=700; total time=   2.2s
# /usr/local/lib/python3.10/dist-packages/sklearn/ensemble/_forest.py:413: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features=1.0` or remove this parameter as it is also the default value for RandomForestRegressors and ExtraTreesRegressors.
#   warn(
# [CV] END max_depth=10, max_features=auto, min_samples_leaf=1, min_samples_split=5, n_estimators=700; total time=   2.0s
# /usr/local/lib/python3.10/dist-packages/sklearn/ensemble/_forest.py:413: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features=1.0` or remove this parameter as it is also the default value for RandomForestRegressors and ExtraTreesRegressors.
#   warn(
# [CV] END max_depth=10, max_features=auto, min_samples_leaf=1, min_samples_split=5, n_estimators=700; total time=   1.9s
# /usr/local/lib/python3.10/dist-packages/sklearn/ensemble/_forest.py:413: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features=1.0` or remove this parameter as it is also the default value for RandomForestRegressors and ExtraTreesRegressors.
#   warn(
# [CV] END max_depth=10, max_features=auto, min_samples_leaf=1, min_samples_split=5, n_estimators=700; total time=   2.0s
# /usr/local/lib/python3.10/dist-packages/sklearn/ensemble/_forest.py:413: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features=1.0` or remove this parameter as it is also the default value for RandomForestRegressors and ExtraTreesRegressors.
#   warn(
# [CV] END max_depth=10, max_features=auto, min_samples_leaf=1, min_samples_split=5, n_estimators=700; total time=   2.0s
# /usr/local/lib/python3.10/dist-packages/sklearn/ensemble/_forest.py:413: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features=1.0` or remove this parameter as it is also the default value for RandomForestRegressors and ExtraTreesRegressors.
#   warn(
# [CV] END max_depth=5, max_features=auto, min_samples_leaf=10, min_samples_split=100, n_estimators=1200; total time=   3.2s
# /usr/local/lib/python3.10/dist-packages/sklearn/ensemble/_forest.py:413: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features=1.0` or remove this parameter as it is also the default value for RandomForestRegressors and ExtraTreesRegressors.
#   warn(
# [CV] END max_depth=5, max_features=auto, min_samples_leaf=10, min_samples_split=100, n_estimators=1200; total time=   2.9s
# /usr/local/lib/python3.10/dist-packages/sklearn/ensemble/_forest.py:413: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features=1.0` or remove this parameter as it is also the default value for RandomForestRegressors and ExtraTreesRegressors.
#   warn(
# [CV] END max_depth=5, max_features=auto, min_samples_leaf=10, min_samples_split=100, n_estimators=1200; total time=   2.3s
# /usr/local/lib/python3.10/dist-packages/sklearn/ensemble/_forest.py:413: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features=1.0` or remove this parameter as it is also the default value for RandomForestRegressors and ExtraTreesRegressors.
#   warn(
# [CV] END max_depth=5, max_features=auto, min_samples_leaf=10, min_samples_split=100, n_estimators=1200; total time=   2.2s
# /usr/local/lib/python3.10/dist-packages/sklearn/ensemble/_forest.py:413: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features=1.0` or remove this parameter as it is also the default value for RandomForestRegressors and ExtraTreesRegressors.
#   warn(
# [CV] END max_depth=5, max_features=auto, min_samples_leaf=10, min_samples_split=100, n_estimators=1200; total time=   2.2s
# [CV] END max_depth=5, max_features=sqrt, min_samples_leaf=2, min_samples_split=10, n_estimators=800; total time=   1.3s
# [CV] END max_depth=5, max_features=sqrt, min_samples_leaf=2, min_samples_split=10, n_estimators=800; total time=   1.5s
# [CV] END max_depth=5, max_features=sqrt, min_samples_leaf=2, min_samples_split=10, n_estimators=800; total time=   2.8s
# [CV] END max_depth=5, max_features=sqrt, min_samples_leaf=2, min_samples_split=10, n_estimators=800; total time=   1.7s
# [CV] END max_depth=5, max_features=sqrt, min_samples_leaf=2, min_samples_split=10, n_estimators=800; total time=   1.3s
# [CV] END max_depth=10, max_features=sqrt, min_samples_leaf=2, min_samples_split=100, n_estimators=1100; total time=   1.7s
# [CV] END max_depth=10, max_features=sqrt, min_samples_leaf=2, min_samples_split=100, n_estimators=1100; total time=   1.7s
# [CV] END max_depth=10, max_features=sqrt, min_samples_leaf=2, min_samples_split=100, n_estimators=1100; total time=   1.7s
# [CV] END max_depth=10, max_features=sqrt, min_samples_leaf=2, min_samples_split=100, n_estimators=1100; total time=   1.7s
# [CV] END max_depth=10, max_features=sqrt, min_samples_leaf=2, min_samples_split=100, n_estimators=1100; total time=   2.0s
# [CV] END max_depth=10, max_features=sqrt, min_samples_leaf=10, min_samples_split=100, n_estimators=500; total time=   1.3s
# [CV] END max_depth=10, max_features=sqrt, min_samples_leaf=10, min_samples_split=100, n_estimators=500; total time=   1.2s
# [CV] END max_depth=10, max_features=sqrt, min_samples_leaf=10, min_samples_split=100, n_estimators=500; total time=   1.2s
# [CV] END max_depth=10, max_features=sqrt, min_samples_leaf=10, min_samples_split=100, n_estimators=500; total time=   0.8s
# [CV] END max_depth=10, max_features=sqrt, min_samples_leaf=10, min_samples_split=100, n_estimators=500; total time=   0.8s
# [CV] END max_depth=15, max_features=sqrt, min_samples_leaf=1, min_samples_split=5, n_estimators=1000; total time=   1.9s
# [CV] END max_depth=15, max_features=sqrt, min_samples_leaf=1, min_samples_split=5, n_estimators=1000; total time=   2.0s
# [CV] END max_depth=15, max_features=sqrt, min_samples_leaf=1, min_samples_split=5, n_estimators=1000; total time=   1.9s
# [CV] END max_depth=15, max_features=sqrt, min_samples_leaf=1, min_samples_split=5, n_estimators=1000; total time=   1.9s
# [CV] END max_depth=15, max_features=sqrt, min_samples_leaf=1, min_samples_split=5, n_estimators=1000; total time=   2.7s
# [CV] END max_depth=15, max_features=sqrt, min_samples_leaf=2, min_samples_split=2, n_estimators=1000; total time=   3.0s
# [CV] END max_depth=15, max_features=sqrt, min_samples_leaf=2, min_samples_split=2, n_estimators=1000; total time=   1.8s
# [CV] END max_depth=15, max_features=sqrt, min_samples_leaf=2, min_samples_split=2, n_estimators=1000; total time=   1.8s
# [CV] END max_depth=15, max_features=sqrt, min_samples_leaf=2, min_samples_split=2, n_estimators=1000; total time=   1.8s
# [CV] END max_depth=15, max_features=sqrt, min_samples_leaf=2, min_samples_split=2, n_estimators=1000; total time=   1.9s
# [CV] END max_depth=25, max_features=sqrt, min_samples_leaf=10, min_samples_split=10, n_estimators=1200; total time=   2.1s
# [CV] END max_depth=25, max_features=sqrt, min_samples_leaf=10, min_samples_split=10, n_estimators=1200; total time=   3.0s
# [CV] END max_depth=25, max_features=sqrt, min_samples_leaf=10, min_samples_split=10, n_estimators=1200; total time=   2.7s
# [CV] END max_depth=25, max_features=sqrt, min_samples_leaf=10, min_samples_split=10, n_estimators=1200; total time=   2.0s
# [CV] END max_depth=25, max_features=sqrt, min_samples_leaf=10, min_samples_split=10, n_estimators=1200; total time=   2.0s
# [CV] END max_depth=20, max_features=sqrt, min_samples_leaf=2, min_samples_split=15, n_estimators=300; total time=   0.5s
# [CV] END max_depth=20, max_features=sqrt, min_samples_leaf=2, min_samples_split=15, n_estimators=300; total time=   0.6s
# [CV] END max_depth=20, max_features=sqrt, min_samples_leaf=2, min_samples_split=15, n_estimators=300; total time=   0.6s
# [CV] END max_depth=20, max_features=sqrt, min_samples_leaf=2, min_samples_split=15, n_estimators=300; total time=   0.5s
# [CV] END max_depth=20, max_features=sqrt, min_samples_leaf=2, min_samples_split=15, n_estimators=300; total time=   0.6s
# /usr/local/lib/python3.10/dist-packages/sklearn/ensemble/_forest.py:413: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features=1.0` or remove this parameter as it is also the default value for RandomForestRegressors and ExtraTreesRegressors.
#   warn(
# [CV] END max_depth=20, max_features=auto, min_samples_leaf=2, min_samples_split=5, n_estimators=600; total time=   1.7s
# /usr/local/lib/python3.10/dist-packages/sklearn/ensemble/_forest.py:413: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features=1.0` or remove this parameter as it is also the default value for RandomForestRegressors and ExtraTreesRegressors.
#   warn(
# [CV] END max_depth=20, max_features=auto, min_samples_leaf=2, min_samples_split=5, n_estimators=600; total time=   2.2s
# /usr/local/lib/python3.10/dist-packages/sklearn/ensemble/_forest.py:413: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features=1.0` or remove this parameter as it is also the default value for RandomForestRegressors and ExtraTreesRegressors.
#   warn(
# [CV] END max_depth=20, max_features=auto, min_samples_leaf=2, min_samples_split=5, n_estimators=600; total time=   2.7s
# /usr/local/lib/python3.10/dist-packages/sklearn/ensemble/_forest.py:413: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features=1.0` or remove this parameter as it is also the default value for RandomForestRegressors and ExtraTreesRegressors.
#   warn(
# [CV] END max_depth=20, max_features=auto, min_samples_leaf=2, min_samples_split=5, n_estimators=600; total time=   1.8s
# /usr/local/lib/python3.10/dist-packages/sklearn/ensemble/_forest.py:413: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features=1.0` or remove this parameter as it is also the default value for RandomForestRegressors and ExtraTreesRegressors.
#   warn(
# [CV] END max_depth=20, max_features=auto, min_samples_leaf=2, min_samples_split=5, n_estimators=600; total time=   1.7s
# /usr/local/lib/python3.10/dist-packages/sklearn/ensemble/_forest.py:413: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features=1.0` or remove this parameter as it is also the default value for RandomForestRegressors and ExtraTreesRegressors.
#   warn(
# [CV] END max_depth=25, max_features=auto, min_samples_leaf=2, min_samples_split=5, n_estimators=1100; total time=   3.0s
# /usr/local/lib/python3.10/dist-packages/sklearn/ensemble/_forest.py:413: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features=1.0` or remove this parameter as it is also the default value for RandomForestRegressors and ExtraTreesRegressors.
#   warn(
# [CV] END max_depth=25, max_features=auto, min_samples_leaf=2, min_samples_split=5, n_estimators=1100; total time=   3.2s
# /usr/local/lib/python3.10/dist-packages/sklearn/ensemble/_forest.py:413: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features=1.0` or remove this parameter as it is also the default value for RandomForestRegressors and ExtraTreesRegressors.
#   warn(
# [CV] END max_depth=25, max_features=auto, min_samples_leaf=2, min_samples_split=5, n_estimators=1100; total time=   4.7s
# /usr/local/lib/python3.10/dist-packages/sklearn/ensemble/_forest.py:413: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features=1.0` or remove this parameter as it is also the default value for RandomForestRegressors and ExtraTreesRegressors.
#   warn(
# [CV] END max_depth=25, max_features=auto, min_samples_leaf=2, min_samples_split=5, n_estimators=1100; total time=   3.3s
# /usr/local/lib/python3.10/dist-packages/sklearn/ensemble/_forest.py:413: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features=1.0` or remove this parameter as it is also the default value for RandomForestRegressors and ExtraTreesRegressors.
#   warn(
# [CV] END max_depth=25, max_features=auto, min_samples_leaf=2, min_samples_split=5, n_estimators=1100; total time=   3.0s
# /usr/local/lib/python3.10/dist-packages/sklearn/ensemble/_forest.py:413: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features=1.0` or remove this parameter as it is also the default value for RandomForestRegressors and ExtraTreesRegressors.
#   warn(
# [CV] END max_depth=15, max_features=auto, min_samples_leaf=1, min_samples_split=100, n_estimators=300; total time=   0.6s
# /usr/local/lib/python3.10/dist-packages/sklearn/ensemble/_forest.py:413: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features=1.0` or remove this parameter as it is also the default value for RandomForestRegressors and ExtraTreesRegressors.
#   warn(
# [CV] END max_depth=15, max_features=auto, min_samples_leaf=1, min_samples_split=100, n_estimators=300; total time=   0.6s
# /usr/local/lib/python3.10/dist-packages/sklearn/ensemble/_forest.py:413: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features=1.0` or remove this parameter as it is also the default value for RandomForestRegressors and ExtraTreesRegressors.
#   warn(
# [CV] END max_depth=15, max_features=auto, min_samples_leaf=1, min_samples_split=100, n_estimators=300; total time=   0.6s
# /usr/local/lib/python3.10/dist-packages/sklearn/ensemble/_forest.py:413: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features=1.0` or remove this parameter as it is also the default value for RandomForestRegressors and ExtraTreesRegressors.
#   warn(
# [CV] END max_depth=15, max_features=auto, min_samples_leaf=1, min_samples_split=100, n_estimators=300; total time=   0.6s
# /usr/local/lib/python3.10/dist-packages/sklearn/ensemble/_forest.py:413: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features=1.0` or remove this parameter as it is also the default value for RandomForestRegressors and ExtraTreesRegressors.
#   warn(
# [CV] END max_depth=15, max_features=auto, min_samples_leaf=1, min_samples_split=100, n_estimators=300; total time=   0.6s
# [CV] END max_depth=20, max_features=sqrt, min_samples_leaf=2, min_samples_split=5, n_estimators=100; total time=   0.2s
# [CV] END max_depth=20, max_features=sqrt, min_samples_leaf=2, min_samples_split=5, n_estimators=100; total time=   0.2s
# [CV] END max_depth=20, max_features=sqrt, min_samples_leaf=2, min_samples_split=5, n_estimators=100; total time=   0.2s
# [CV] END max_depth=20, max_features=sqrt, min_samples_leaf=2, min_samples_split=5, n_estimators=100; total time=   0.2s
# [CV] END max_depth=20, max_features=sqrt, min_samples_leaf=2, min_samples_split=5, n_estimators=100; total time=   0.2s
# [CV] END max_depth=20, max_features=sqrt, min_samples_leaf=10, min_samples_split=100, n_estimators=700; total time=   1.5s
# [CV] END max_depth=20, max_features=sqrt, min_samples_leaf=10, min_samples_split=100, n_estimators=700; total time=   1.8s
# [CV] END max_depth=20, max_features=sqrt, min_samples_leaf=10, min_samples_split=100, n_estimators=700; total time=   1.8s
# [CV] END max_depth=20, max_features=sqrt, min_samples_leaf=10, min_samples_split=100, n_estimators=700; total time=   1.8s
# [CV] END max_depth=20, max_features=sqrt, min_samples_leaf=10, min_samples_split=100, n_estimators=700; total time=   1.8s
# [CV] END max_depth=15, max_features=sqrt, min_samples_leaf=10, min_samples_split=100, n_estimators=200; total time=   0.5s
# [CV] END max_depth=15, max_features=sqrt, min_samples_leaf=10, min_samples_split=100, n_estimators=200; total time=   0.3s
# [CV] END max_depth=15, max_features=sqrt, min_samples_leaf=10, min_samples_split=100, n_estimators=200; total time=   0.3s
# [CV] END max_depth=15, max_features=sqrt, min_samples_leaf=10, min_samples_split=100, n_estimators=200; total time=   0.3s
# [CV] END max_depth=15, max_features=sqrt, min_samples_leaf=10, min_samples_split=100, n_estimators=200; total time=   0.3s
# /usr/local/lib/python3.10/dist-packages/sklearn/ensemble/_forest.py:413: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features=1.0` or remove this parameter as it is also the default value for RandomForestRegressors and ExtraTreesRegressors.
#   warn(
# [CV] END max_depth=20, max_features=auto, min_samples_leaf=5, min_samples_split=2, n_estimators=500; total time=   1.2s
# /usr/local/lib/python3.10/dist-packages/sklearn/ensemble/_forest.py:413: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features=1.0` or remove this parameter as it is also the default value for RandomForestRegressors and ExtraTreesRegressors.
#   warn(
# [CV] END max_depth=20, max_features=auto, min_samples_leaf=5, min_samples_split=2, n_estimators=500; total time=   1.2s
# /usr/local/lib/python3.10/dist-packages/sklearn/ensemble/_forest.py:413: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features=1.0` or remove this parameter as it is also the default value for RandomForestRegressors and ExtraTreesRegressors.
#   warn(
# [CV] END max_depth=20, max_features=auto, min_samples_leaf=5, min_samples_split=2, n_estimators=500; total time=   1.2s
# /usr/local/lib/python3.10/dist-packages/sklearn/ensemble/_forest.py:413: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features=1.0` or remove this parameter as it is also the default value for RandomForestRegressors and ExtraTreesRegressors.
#   warn(
# [CV] END max_depth=20, max_features=auto, min_samples_leaf=5, min_samples_split=2, n_estimators=500; total time=   1.2s
# /usr/local/lib/python3.10/dist-packages/sklearn/ensemble/_forest.py:413: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features=1.0` or remove this parameter as it is also the default value for RandomForestRegressors and ExtraTreesRegressors.
#   warn(
# [CV] END max_depth=20, max_features=auto, min_samples_leaf=5, min_samples_split=2, n_estimators=500; total time=   1.2s
# [CV] END max_depth=25, max_features=sqrt, min_samples_leaf=10, min_samples_split=10, n_estimators=900; total time=   1.5s
# [CV] END max_depth=25, max_features=sqrt, min_samples_leaf=10, min_samples_split=10, n_estimators=900; total time=   1.8s
# [CV] END max_depth=25, max_features=sqrt, min_samples_leaf=10, min_samples_split=10, n_estimators=900; total time=   2.3s
# [CV] END max_depth=25, max_features=sqrt, min_samples_leaf=10, min_samples_split=10, n_estimators=900; total time=   1.9s
# [CV] END max_depth=25, max_features=sqrt, min_samples_leaf=10, min_samples_split=10, n_estimators=900; total time=   1.4s
# /usr/local/lib/python3.10/dist-packages/sklearn/ensemble/_forest.py:413: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features=1.0` or remove this parameter as it is also the default value for RandomForestRegressors and ExtraTreesRegressors.
#   warn(
# [CV] END max_depth=30, max_features=auto, min_samples_leaf=5, min_samples_split=15, n_estimators=1200; total time=   2.8s
# /usr/local/lib/python3.10/dist-packages/sklearn/ensemble/_forest.py:413: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features=1.0` or remove this parameter as it is also the default value for RandomForestRegressors and ExtraTreesRegressors.
#   warn(
# [CV] END max_depth=30, max_features=auto, min_samples_leaf=5, min_samples_split=15, n_estimators=1200; total time=   2.8s
# /usr/local/lib/python3.10/dist-packages/sklearn/ensemble/_forest.py:413: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features=1.0` or remove this parameter as it is also the default value for RandomForestRegressors and ExtraTreesRegressors.
#   warn(
# [CV] END max_depth=30, max_features=auto, min_samples_leaf=5, min_samples_split=15, n_estimators=1200; total time=   3.3s
# /usr/local/lib/python3.10/dist-packages/sklearn/ensemble/_forest.py:413: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features=1.0` or remove this parameter as it is also the default value for RandomForestRegressors and ExtraTreesRegressors.
#   warn(
# [CV] END max_depth=30, max_features=auto, min_samples_leaf=5, min_samples_split=15, n_estimators=1200; total time=   4.2s
# /usr/local/lib/python3.10/dist-packages/sklearn/ensemble/_forest.py:413: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features=1.0` or remove this parameter as it is also the default value for RandomForestRegressors and ExtraTreesRegressors.
#   warn(
# [CV] END max_depth=30, max_features=auto, min_samples_leaf=5, min_samples_split=15, n_estimators=1200; total time=   3.0s
# /usr/local/lib/python3.10/dist-packages/sklearn/ensemble/_forest.py:413: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features=1.0` or remove this parameter as it is also the default value for RandomForestRegressors and ExtraTreesRegressors.
#   warn(
# [CV] END max_depth=25, max_features=auto, min_samples_leaf=1, min_samples_split=10, n_estimators=900; total time=   2.6s
# /usr/local/lib/python3.10/dist-packages/sklearn/ensemble/_forest.py:413: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features=1.0` or remove this parameter as it is also the default value for RandomForestRegressors and ExtraTreesRegressors.
#   warn(
# [CV] END max_depth=25, max_features=auto, min_samples_leaf=1, min_samples_split=10, n_estimators=900; total time=   2.5s
# /usr/local/lib/python3.10/dist-packages/sklearn/ensemble/_forest.py:413: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features=1.0` or remove this parameter as it is also the default value for RandomForestRegressors and ExtraTreesRegressors.
#   warn(
# [CV] END max_depth=25, max_features=auto, min_samples_leaf=1, min_samples_split=10, n_estimators=900; total time=   3.5s
# /usr/local/lib/python3.10/dist-packages/sklearn/ensemble/_forest.py:413: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features=1.0` or remove this parameter as it is also the default value for RandomForestRegressors and ExtraTreesRegressors.
#   warn(
# [CV] END max_depth=25, max_features=auto, min_samples_leaf=1, min_samples_split=10, n_estimators=900; total time=   3.4s
# /usr/local/lib/python3.10/dist-packages/sklearn/ensemble/_forest.py:413: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features=1.0` or remove this parameter as it is also the default value for RandomForestRegressors and ExtraTreesRegressors.
#   warn(
# [CV] END max_depth=25, max_features=auto, min_samples_leaf=1, min_samples_split=10, n_estimators=900; total time=   2.5s
# [CV] END max_depth=10, max_features=sqrt, min_samples_leaf=5, min_samples_split=5, n_estimators=600; total time=   1.1s
# [CV] END max_depth=10, max_features=sqrt, min_samples_leaf=5, min_samples_split=5, n_estimators=600; total time=   1.0s
# [CV] END max_depth=10, max_features=sqrt, min_samples_leaf=5, min_samples_split=5, n_estimators=600; total time=   1.0s
# [CV] END max_depth=10, max_features=sqrt, min_samples_leaf=5, min_samples_split=5, n_estimators=600; total time=   1.0s
# [CV] END max_depth=10, max_features=sqrt, min_samples_leaf=5, min_samples_split=5, n_estimators=600; total time=   1.0s
# [CV] END max_depth=25, max_features=sqrt, min_samples_leaf=5, min_samples_split=5, n_estimators=800; total time=   1.3s
# [CV] END max_depth=25, max_features=sqrt, min_samples_leaf=5, min_samples_split=5, n_estimators=800; total time=   2.1s
# [CV] END max_depth=25, max_features=sqrt, min_samples_leaf=5, min_samples_split=5, n_estimators=800; total time=   2.1s
# [CV] END max_depth=25, max_features=sqrt, min_samples_leaf=5, min_samples_split=5, n_estimators=800; total time=   1.6s
# [CV] END max_depth=25, max_features=sqrt, min_samples_leaf=5, min_samples_split=5, n_estimators=800; total time=   1.3s
# /usr/local/lib/python3.10/dist-packages/sklearn/ensemble/_forest.py:413: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features=1.0` or remove this parameter as it is also the default value for RandomForestRegressors and ExtraTreesRegressors.
#   warn(
# [CV] END max_depth=5, max_features=auto, min_samples_leaf=5, min_samples_split=2, n_estimators=500; total time=   1.1s
# /usr/local/lib/python3.10/dist-packages/sklearn/ensemble/_forest.py:413: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features=1.0` or remove this parameter as it is also the default value for RandomForestRegressors and ExtraTreesRegressors.
#   warn(
# [CV] END max_depth=5, max_features=auto, min_samples_leaf=5, min_samples_split=2, n_estimators=500; total time=   1.1s
# /usr/local/lib/python3.10/dist-packages/sklearn/ensemble/_forest.py:413: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features=1.0` or remove this parameter as it is also the default value for RandomForestRegressors and ExtraTreesRegressors.
#   warn(
# [CV] END max_depth=5, max_features=auto, min_samples_leaf=5, min_samples_split=2, n_estimators=500; total time=   1.1s
# /usr/local/lib/python3.10/dist-packages/sklearn/ensemble/_forest.py:413: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features=1.0` or remove this parameter as it is also the default value for RandomForestRegressors and ExtraTreesRegressors.
#   warn(
# [CV] END max_depth=5, max_features=auto, min_samples_leaf=5, min_samples_split=2, n_estimators=500; total time=   1.1s
# /usr/local/lib/python3.10/dist-packages/sklearn/ensemble/_forest.py:413: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features=1.0` or remove this parameter as it is also the default value for RandomForestRegressors and ExtraTreesRegressors.
#   warn(
# [CV] END max_depth=5, max_features=auto, min_samples_leaf=5, min_samples_split=2, n_estimators=500; total time=   1.1s
# [CV] END max_depth=25, max_features=sqrt, min_samples_leaf=2, min_samples_split=100, n_estimators=800; total time=   1.2s
# [CV] END max_depth=25, max_features=sqrt, min_samples_leaf=2, min_samples_split=100, n_estimators=800; total time=   1.5s
# [CV] END max_depth=25, max_features=sqrt, min_samples_leaf=2, min_samples_split=100, n_estimators=800; total time=   1.9s
# [CV] END max_depth=25, max_features=sqrt, min_samples_leaf=2, min_samples_split=100, n_estimators=800; total time=   1.9s
# [CV] END max_depth=25, max_features=sqrt, min_samples_leaf=2, min_samples_split=100, n_estimators=800; total time=   1.2s
# [CV] END max_depth=30, max_features=sqrt, min_samples_leaf=5, min_samples_split=2, n_estimators=1200; total time=   2.0s
# [CV] END max_depth=30, max_features=sqrt, min_samples_leaf=5, min_samples_split=2, n_estimators=1200; total time=   2.0s
# [CV] END max_depth=30, max_features=sqrt, min_samples_leaf=5, min_samples_split=2, n_estimators=1200; total time=   2.1s
# [CV] END max_depth=30, max_features=sqrt, min_samples_leaf=5, min_samples_split=2, n_estimators=1200; total time=   2.0s
# [CV] END max_depth=30, max_features=sqrt, min_samples_leaf=5, min_samples_split=2, n_estimators=1200; total time=   2.8s
# [CV] END max_depth=30, max_features=sqrt, min_samples_leaf=1, min_samples_split=10, n_estimators=600; total time=   1.9s
# [CV] END max_depth=30, max_features=sqrt, min_samples_leaf=1, min_samples_split=10, n_estimators=600; total time=   1.2s
# [CV] END max_depth=30, max_features=sqrt, min_samples_leaf=1, min_samples_split=10, n_estimators=600; total time=   1.1s
# [CV] END max_depth=30, max_features=sqrt, min_samples_leaf=1, min_samples_split=10, n_estimators=600; total time=   1.1s
# [CV] END max_depth=30, max_features=sqrt, min_samples_leaf=1, min_samples_split=10, n_estimators=600; total time=   1.1s
# /usr/local/lib/python3.10/dist-packages/sklearn/ensemble/_forest.py:413: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features=1.0` or remove this parameter as it is also the default value for RandomForestRegressors and ExtraTreesRegressors.
#   warn(
# [CV] END max_depth=20, max_features=auto, min_samples_leaf=1, min_samples_split=10, n_estimators=900; total time=   2.5s
# ...
#   warn(
# [CV] END max_depth=5, max_features=auto, min_samples_leaf=5, min_samples_split=100, n_estimators=1100; total time=   2.0s
# [CV] END max_depth=10, max_features=sqrt, min_samples_leaf=1, min_samples_split=2, n_estimators=800; total time=   1.5s
# [CV] END max_depth=10, max_features=sqrt, min_samples_leaf=1, min_samples_split=2, n_estimators=800; total time=   1.5s
# [CV] END max_depth=10, max_features=sqrt, min_samples_leaf=1, min_samples_split=2, n_estimators=800; total time=   1.6s
# [CV] END max_depth=10, max_features=sqrt, min_samples_leaf=1, min_samples_split=2, n_estimators=800; total time=   2.3s
# [CV] END max_depth=10, max_features=sqrt, min_samples_leaf=1, min_samples_split=2, n_estimators=800; total time=   2.1s
# [CV] END max_depth=25, max_features=sqrt, min_samples_leaf=5, min_samples_split=2, n_estimators=700; total time=   1.1s
# [CV] END max_depth=25, max_features=sqrt, min_samples_leaf=5, min_samples_split=2, n_estimators=700; total time=   1.1s
# [CV] END max_depth=25, max_features=sqrt, min_samples_leaf=5, min_samples_split=2, n_estimators=700; total time=   1.2s
# [CV] END max_depth=25, max_features=sqrt, min_samples_leaf=5, min_samples_split=2, n_estimators=700; total time=   1.2s
# [CV] END max_depth=25, max_features=sqrt, min_samples_leaf=5, min_samples_split=2, n_estimators=700; total time=   1.2s
# [CV] END max_depth=5, max_features=sqrt, min_samples_leaf=2, min_samples_split=10, n_estimators=100; total time=   0.2s
# [CV] END max_depth=5, max_features=sqrt, min_samples_leaf=2, min_samples_split=10, n_estimators=100; total time=   0.2s
# [CV] END max_depth=5, max_features=sqrt, min_samples_leaf=2, min_samples_split=10, n_estimators=100; total time=   0.2s
# [CV] END max_depth=5, max_features=sqrt, min_samples_leaf=2, min_samples_split=10, n_estimators=100; total time=   0.2s
# [CV] END max_depth=5, max_features=sqrt, min_samples_leaf=2, min_samples_split=10, n_estimators=100; total time=   0.2s
# [CV] END max_depth=10, max_features=sqrt, min_samples_leaf=1, min_samples_split=15, n_estimators=1000; total time=   1.7s
# [CV] END max_depth=10, max_features=sqrt, min_samples_leaf=1, min_samples_split=15, n_estimators=1000; total time=   1.8s
# [CV] END max_depth=10, max_features=sqrt, min_samples_leaf=1, min_samples_split=15, n_estimators=1000; total time=   2.6s
# [CV] END max_depth=10, max_features=sqrt, min_samples_leaf=1, min_samples_split=15, n_estimators=1000; total time=   2.2s
# [CV] END max_depth=10, max_features=sqrt, min_samples_leaf=1, min_samples_split=15, n_estimators=1000; total time=   1.7s
# /usr/local/lib/python3.10/dist-packages/sklearn/ensemble/_forest.py:413: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features=1.0` or remove this parameter as it is also the default value for RandomForestRegressors and ExtraTreesRegressors.
#   warn(
# [CV] END max_depth=20, max_features=auto, min_samples_leaf=1, min_samples_split=10, n_estimators=500; total time=   1.2s
# /usr/local/lib/python3.10/dist-packages/sklearn/ensemble/_forest.py:413: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features=1.0` or remove this parameter as it is also the default value for RandomForestRegressors and ExtraTreesRegressors.
#   warn(
# [CV] END max_depth=20, max_features=auto, min_samples_leaf=1, min_samples_split=10, n_estimators=500; total time=   1.3s
# /usr/local/lib/python3.10/dist-packages/sklearn/ensemble/_forest.py:413: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features=1.0` or remove this parameter as it is also the default value for RandomForestRegressors and ExtraTreesRegressors.
#   warn(
# [CV] END max_depth=20, max_features=auto, min_samples_leaf=1, min_samples_split=10, n_estimators=500; total time=   1.3s
# /usr/local/lib/python3.10/dist-packages/sklearn/ensemble/_forest.py:413: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features=1.0` or remove this parameter as it is also the default value for RandomForestRegressors and ExtraTreesRegressors.
#   warn(
# [CV] END max_depth=20, max_features=auto, min_samples_leaf=1, min_samples_split=10, n_estimators=500; total time=   1.3s
# /usr/local/lib/python3.10/dist-packages/sklearn/ensemble/_forest.py:413: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features=1.0` or remove this parameter as it is also the default value for RandomForestRegressors and ExtraTreesRegressors.
#   warn(
# [CV] END max_depth=20, max_features=auto, min_samples_leaf=1, min_samples_split=10, n_estimators=500; total time=   1.3s
# [CV] END max_depth=20, max_features=sqrt, min_samples_leaf=1, min_samples_split=15, n_estimators=200; total time=   0.3s
# [CV] END max_depth=20, max_features=sqrt, min_samples_leaf=1, min_samples_split=15, n_estimators=200; total time=   0.3s
# [CV] END max_depth=20, max_features=sqrt, min_samples_leaf=1, min_samples_split=15, n_estimators=200; total time=   0.3s
# [CV] END max_depth=20, max_features=sqrt, min_samples_leaf=1, min_samples_split=15, n_estimators=200; total time=   0.3s
# [CV] END max_depth=20, max_features=sqrt, min_samples_leaf=1, min_samples_split=15, n_estimators=200; total time=   0.5s
# /usr/local/lib/python3.10/dist-packages/sklearn/ensemble/_forest.py:413: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features=1.0` or remove this parameter as it is also the default value for RandomForestRegressors and ExtraTreesRegressors.
#   warn(
# [CV] END max_depth=10, max_features=auto, min_samples_leaf=10, min_samples_split=10, n_estimators=1200; total time=   3.8s
# /usr/local/lib/python3.10/dist-packages/sklearn/ensemble/_forest.py:413: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features=1.0` or remove this parameter as it is also the default value for RandomForestRegressors and ExtraTreesRegressors.
#   warn(
# [CV] END max_depth=10, max_features=auto, min_samples_leaf=10, min_samples_split=10, n_estimators=1200; total time=   2.6s
# /usr/local/lib/python3.10/dist-packages/sklearn/ensemble/_forest.py:413: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features=1.0` or remove this parameter as it is also the default value for RandomForestRegressors and ExtraTreesRegressors.
#   warn(
# [CV] END max_depth=10, max_features=auto, min_samples_leaf=10, min_samples_split=10, n_estimators=1200; total time=   2.6s
# /usr/local/lib/python3.10/dist-packages/sklearn/ensemble/_forest.py:413: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features=1.0` or remove this parameter as it is also the default value for RandomForestRegressors and ExtraTreesRegressors.
#   warn(
# [CV] END max_depth=10, max_features=auto, min_samples_leaf=10, min_samples_split=10, n_estimators=1200; total time=   2.5s
# /usr/local/lib/python3.10/dist-packages/sklearn/ensemble/_forest.py:413: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features=1.0` or remove this parameter as it is also the default value for RandomForestRegressors and ExtraTreesRegressors.
#   warn(
# [CV] END max_depth=10, max_features=auto, min_samples_leaf=10, min_samples_split=10, n_estimators=1200; total time=   2.6s
# /usr/local/lib/python3.10/dist-packages/sklearn/ensemble/_forest.py:413: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features=1.0` or remove this parameter as it is also the default value for RandomForestRegressors and ExtraTreesRegressors.
#   warn(
# [CV] END max_depth=30, max_features=auto, min_samples_leaf=1, min_samples_split=5, n_estimators=500; total time=   2.1s
# /usr/local/lib/python3.10/dist-packages/sklearn/ensemble/_forest.py:413: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features=1.0` or remove this parameter as it is also the default value for RandomForestRegressors and ExtraTreesRegressors.
#   warn(
# [CV] END max_depth=30, max_features=auto, min_samples_leaf=1, min_samples_split=5, n_estimators=500; total time=   2.1s
# /usr/local/lib/python3.10/dist-packages/sklearn/ensemble/_forest.py:413: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features=1.0` or remove this parameter as it is also the default value for RandomForestRegressors and ExtraTreesRegressors.
#   warn(
# [CV] END max_depth=30, max_features=auto, min_samples_leaf=1, min_samples_split=5, n_estimators=500; total time=   1.6s
# /usr/local/lib/python3.10/dist-packages/sklearn/ensemble/_forest.py:413: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features=1.0` or remove this parameter as it is also the default value for RandomForestRegressors and ExtraTreesRegressors.
#   warn(
# [CV] END max_depth=30, max_features=auto, min_samples_leaf=1, min_samples_split=5, n_estimators=500; total time=   1.4s
# /usr/local/lib/python3.10/dist-packages/sklearn/ensemble/_forest.py:413: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features=1.0` or remove this parameter as it is also the default value for RandomForestRegressors and ExtraTreesRegressors.
#   warn(
# [CV] END max_depth=30, max_features=auto, min_samples_leaf=1, min_samples_split=5, n_estimators=500; total time=   1.4s
# [CV] END max_depth=20, max_features=sqrt, min_samples_leaf=10, min_samples_split=100, n_estimators=1100; total time=   1.6s
# [CV] END max_depth=20, max_features=sqrt, min_samples_leaf=10, min_samples_split=100, n_estimators=1100; total time=   1.6s
# [CV] END max_depth=20, max_features=sqrt, min_samples_leaf=10, min_samples_split=100, n_estimators=1100; total time=   1.6s
# [CV] END max_depth=20, max_features=sqrt, min_samples_leaf=10, min_samples_split=100, n_estimators=1100; total time=   1.8s
# [CV] END max_depth=20, max_features=sqrt, min_samples_leaf=10, min_samples_split=100, n_estimators=1100; total time=   2.5s
# /usr/local/lib/python3.10/dist-packages/sklearn/ensemble/_forest.py:413: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features=1.0` or remove this parameter as it is also the default value for RandomForestRegressors and ExtraTreesRegressors.
#   warn(
# [CV] END max_depth=10, max_features=auto, min_samples_leaf=2, min_samples_split=5, n_estimators=300; total time=   1.2s
# /usr/local/lib/python3.10/dist-packages/sklearn/ensemble/_forest.py:413: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features=1.0` or remove this parameter as it is also the default value for RandomForestRegressors and ExtraTreesRegressors.
#   warn(
# [CV] END max_depth=10, max_features=auto, min_samples_leaf=2, min_samples_split=5, n_estimators=300; total time=   0.9s
# /usr/local/lib/python3.10/dist-packages/sklearn/ensemble/_forest.py:413: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features=1.0` or remove this parameter as it is also the default value for RandomForestRegressors and ExtraTreesRegressors.
#   warn(
# [CV] END max_depth=10, max_features=auto, min_samples_leaf=2, min_samples_split=5, n_estimators=300; total time=   0.8s
# /usr/local/lib/python3.10/dist-packages/sklearn/ensemble/_forest.py:413: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features=1.0` or remove this parameter as it is also the default value for RandomForestRegressors and ExtraTreesRegressors.
#   warn(
# [CV] END max_depth=10, max_features=auto, min_samples_leaf=2, min_samples_split=5, n_estimators=300; total time=   0.8s
# /usr/local/lib/python3.10/dist-packages/sklearn/ensemble/_forest.py:413: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features=1.0` or remove this parameter as it is also the default value for RandomForestRegressors and ExtraTreesRegressors.
#   warn(
# [CV] END max_depth=10, max_features=auto, min_samples_leaf=2, min_samples_split=5, n_estimators=300; total time=   0.8s
# [CV] END max_depth=15, max_features=sqrt, min_samples_leaf=1, min_samples_split=2, n_estimators=500; total time=   0.9s
# [CV] END max_depth=15, max_features=sqrt, min_samples_leaf=1, min_samples_split=2, n_estimators=500; total time=   1.0s
# [CV] END max_depth=15, max_features=sqrt, min_samples_leaf=1, min_samples_split=2, n_estimators=500; total time=   1.0s
# [CV] END max_depth=15, max_features=sqrt, min_samples_leaf=1, min_samples_split=2, n_estimators=500; total time=   1.0s
# [CV] END max_depth=15, max_features=sqrt, min_samples_leaf=1, min_samples_split=2, n_estimators=500; total time=   1.0s
# [CV] END max_depth=20, max_features=sqrt, min_samples_leaf=2, min_samples_split=2, n_estimators=500; total time=   0.9s
# [CV] END max_depth=20, max_features=sqrt, min_samples_leaf=2, min_samples_split=2, n_estimators=500; total time=   0.9s
# [CV] END max_depth=20, max_features=sqrt, min_samples_leaf=2, min_samples_split=2, n_estimators=500; total time=   1.1s
# [CV] END max_depth=20, max_features=sqrt, min_samples_leaf=2, min_samples_split=2, n_estimators=500; total time=   1.4s
# [CV] END max_depth=20, max_features=sqrt, min_samples_leaf=2, min_samples_split=2, n_estimators=500; total time=   1.4s
# [CV] END max_depth=20, max_features=sqrt, min_samples_leaf=1, min_samples_split=10, n_estimators=700; total time=   1.7s
# [CV] END max_depth=20, max_features=sqrt, min_samples_leaf=1, min_samples_split=10, n_estimators=700; total time=   1.2s
# [CV] END max_depth=20, max_features=sqrt, min_samples_leaf=1, min_samples_split=10, n_estimators=700; total time=   1.2s
# [CV] END max_depth=20, max_features=sqrt, min_samples_leaf=1, min_samples_split=10, n_estimators=700; total time=   1.2s
# [CV] END max_depth=20, max_features=sqrt, min_samples_leaf=1, min_samples_split=10, n_estimators=700; total time=   1.2s
# RandomizedSearchCV(cv=5, estimator=RandomForestRegressor(), n_iter=100,
#                    n_jobs=1,
#                    param_distributions={'max_depth': [5, 10, 15, 20, 25, 30],
#                                         'max_features': ['auto', 'sqrt'],
#                                         'min_samples_leaf': [1, 2, 5, 10],
#                                         'min_samples_split': [2, 5, 10, 15,
#                                                               100],
#                                         'n_estimators': [100, 200, 300, 400,
#                                                          500, 600, 700, 800,
#                                                          900, 1000, 1100,
#                                                          1200]},
#                    random_state=42, scoring='neg_mean_squared_error',
#                    verbose=2)

# %%
rf_random.best_params_
# Out:
# {'n_estimators': 100,
#  'min_samples_split': 5,
#  'min_samples_leaf': 2,
#  'max_features': 'sqrt',
#  'max_depth': 20}

# %%
rf_random.best_score_
# Out:
# -2565.3667799315394

# %%
predictions=rf_random.predict(X_test)

# %%
sns.displot(y_test-predictions)

# %%
plt.scatter(y_test,prediction)

# %%
print('MAE:', metrics.mean_absolute_error(y_test, predictions))
print('MSE:', metrics.mean_squared_error(y_test, predictions))
print('RMSE:', np.sqrt(metrics.mean_squared_error(y_test, predictions)))
# Out:
# MAE: 36.322848680921226
# MSE: 2599.6131822081948
# RMSE: 50.98640193432161

# %% [markdown]
# ##Regression Evaluation Metrics

# %%
from sklearn import metrics

# %%
print('MAE:', metrics.mean_absolute_error(y_test, prediction))
print('MSE:', metrics.mean_squared_error(y_test, prediction))
print('RMSE:', np.sqrt(metrics.mean_squared_error(y_test, prediction)))
# Out:
# MAE: 35.6498071368608
# MSE: 2543.3530376550766
# RMSE: 50.431667012454355

# %%
import pickle

# %%
file = open('/content/drive/MyDrive/Airnode/random_forest_regression_model.pkl', 'wb')

pickle.dump(rf_random, file)

# %% [markdown]
# #Xgboost Regressor

# %%
import xgboost as xgb

# %%
regressor=xgb.XGBRegressor()
regressor.fit(X_train,y_train)
# Out:
# XGBRegressor(base_score=None, booster=None, callbacks=None,
#              colsample_bylevel=None, colsample_bynode=None,
#              colsample_bytree=None, early_stopping_rounds=None,
#              enable_categorical=False, eval_metric=None, feature_types=None,
#              gamma=None, gpu_id=None, grow_policy=None, importance_type=None,
#              interaction_constraints=None, learning_rate=None, max_bin=None,
#              max_cat_threshold=None, max_cat_to_onehot=None,
#              max_delta_step=None, max_depth=None, max_leaves=None,
#              min_child_weight=None, missing=nan, monotone_constraints=None,
#              n_estimators=100, n_jobs=None, num_parallel_tree=None,
#              predictor=None, random_state=None, ...)

# %%
print("Coefficient of determination R^2 <-- on train set: {}".format(regressor.score(X_train, y_train)))
# Out:
# Coefficient of determination R^2 <-- on train set: 0.9997842299242427

# %%
print("Coefficient of determination R^2 <-- on train set: {}".format(regressor.score(X_test, y_test)))
# Out:
# Coefficient of determination R^2 <-- on train set: 0.6104024046485017

# %%
from sklearn.model_selection import cross_val_score
score=cross_val_score(regressor,X,y,cv=5)

# %%
score.mean()
# Out:
# 0.4545628713565546

# %% [markdown]
# ##Model Evaluation

# %%
prediction=regressor.predict(X_test)

# %%
sns.displot(y_test-prediction)

# %%
plt.scatter(y_test,prediction)

# %% [markdown]
# ##Hyperparameter Tuning

# %%
xgb.XGBRegressor()
# Out:
# XGBRegressor(base_score=None, booster=None, callbacks=None,
#              colsample_bylevel=None, colsample_bynode=None,
#              colsample_bytree=None, early_stopping_rounds=None,
#              enable_categorical=False, eval_metric=None, feature_types=None,
#              gamma=None, gpu_id=None, grow_policy=None, importance_type=None,
#              interaction_constraints=None, learning_rate=None, max_bin=None,
#              max_cat_threshold=None, max_cat_to_onehot=None,
#              max_delta_step=None, max_depth=None, max_leaves=None,
#              min_child_weight=None, missing=nan, monotone_constraints=None,
#              n_estimators=100, n_jobs=None, num_parallel_tree=None,
#              predictor=None, random_state=None, ...)

# %%
from sklearn.model_selection import RandomizedSearchCV

# %%
n_estimators = [int(x) for x in np.linspace(start = 100, stop = 1200, num = 12)]
print(n_estimators)
# Out:
# [100, 200, 300, 400, 500, 600, 700, 800, 900, 1000, 1100, 1200]

# %%
 #Randomized Search CV

# Number of trees in random forest
n_estimators = [int(x) for x in np.linspace(start = 100, stop = 1200, num = 12)]
# Various learning rate parameters
learning_rate = ['0.05','0.1', '0.2','0.3','0.5','0.6']
# Maximum number of levels in tree
max_depth = [int(x) for x in np.linspace(5, 30, num = 6)]
# max_depth.append(None)
#Subssample parameter values
subsample=[0.7,0.6,0.8]
# Minimum child weight parameters
min_child_weight=[3,4,5,6,7]

# %%
random_grid = {'n_estimators': n_estimators,
               'learning_rate': learning_rate,
               'max_depth': max_depth,
               'subsample': subsample,
               'min_child_weight': min_child_weight}

print(random_grid)
# Out:
# {'n_estimators': [100, 200, 300, 400, 500, 600, 700, 800, 900, 1000, 1100, 1200], 'learning_rate': ['0.05', '0.1', '0.2', '0.3', '0.5', '0.6'], 'max_depth': [5, 10, 15, 20, 25, 30], 'subsample': [0.7, 0.6, 0.8], 'min_child_weight': [3, 4, 5, 6, 7]}

# %%
regressor=xgb.XGBRegressor()

# %%
xg_random = RandomizedSearchCV(estimator = regressor, param_distributions = random_grid,scoring='neg_mean_squared_error', n_iter = 100, cv = 5, verbose=2, random_state=42, n_jobs = 1)

# %%
xg_random.fit(X_train,y_train)
# Out:
# Fitting 5 folds for each of 100 candidates, totalling 500 fits
# [CV] END learning_rate=0.3, max_depth=10, min_child_weight=6, n_estimators=1100, subsample=0.7; total time=   2.9s
# [CV] END learning_rate=0.3, max_depth=10, min_child_weight=6, n_estimators=1100, subsample=0.7; total time=   1.7s
# [CV] END learning_rate=0.3, max_depth=10, min_child_weight=6, n_estimators=1100, subsample=0.7; total time=   0.7s
# [CV] END learning_rate=0.3, max_depth=10, min_child_weight=6, n_estimators=1100, subsample=0.7; total time=   0.9s
# [CV] END learning_rate=0.3, max_depth=10, min_child_weight=6, n_estimators=1100, subsample=0.7; total time=   3.7s
# [CV] END learning_rate=0.3, max_depth=20, min_child_weight=6, n_estimators=600, subsample=0.7; total time=   0.8s
# [CV] END learning_rate=0.3, max_depth=20, min_child_weight=6, n_estimators=600, subsample=0.7; total time=   0.8s
# [CV] END learning_rate=0.3, max_depth=20, min_child_weight=6, n_estimators=600, subsample=0.7; total time=   0.8s
# [CV] END learning_rate=0.3, max_depth=20, min_child_weight=6, n_estimators=600, subsample=0.7; total time=   0.7s
# [CV] END learning_rate=0.3, max_depth=20, min_child_weight=6, n_estimators=600, subsample=0.7; total time=   0.7s
# [CV] END learning_rate=0.1, max_depth=30, min_child_weight=7, n_estimators=300, subsample=0.6; total time=   0.4s
# [CV] END learning_rate=0.1, max_depth=30, min_child_weight=7, n_estimators=300, subsample=0.6; total time=   0.3s
# [CV] END learning_rate=0.1, max_depth=30, min_child_weight=7, n_estimators=300, subsample=0.6; total time=   0.3s
# [CV] END learning_rate=0.1, max_depth=30, min_child_weight=7, n_estimators=300, subsample=0.6; total time=   0.4s
# [CV] END learning_rate=0.1, max_depth=30, min_child_weight=7, n_estimators=300, subsample=0.6; total time=   0.3s
# [CV] END learning_rate=0.05, max_depth=10, min_child_weight=7, n_estimators=1000, subsample=0.7; total time=   1.1s
# [CV] END learning_rate=0.05, max_depth=10, min_child_weight=7, n_estimators=1000, subsample=0.7; total time=   2.2s
# [CV] END learning_rate=0.05, max_depth=10, min_child_weight=7, n_estimators=1000, subsample=0.7; total time=   6.0s
# [CV] END learning_rate=0.05, max_depth=10, min_child_weight=7, n_estimators=1000, subsample=0.7; total time=   3.5s
# [CV] END learning_rate=0.05, max_depth=10, min_child_weight=7, n_estimators=1000, subsample=0.7; total time=   1.2s
# [CV] END learning_rate=0.3, max_depth=10, min_child_weight=3, n_estimators=100, subsample=0.8; total time=   0.2s
# [CV] END learning_rate=0.3, max_depth=10, min_child_weight=3, n_estimators=100, subsample=0.8; total time=   0.1s
# [CV] END learning_rate=0.3, max_depth=10, min_child_weight=3, n_estimators=100, subsample=0.8; total time=   0.1s
# [CV] END learning_rate=0.3, max_depth=10, min_child_weight=3, n_estimators=100, subsample=0.8; total time=   0.2s
# [CV] END learning_rate=0.3, max_depth=10, min_child_weight=3, n_estimators=100, subsample=0.8; total time=   0.1s
# [CV] END learning_rate=0.3, max_depth=5, min_child_weight=6, n_estimators=500, subsample=0.6; total time=   0.4s
# [CV] END learning_rate=0.3, max_depth=5, min_child_weight=6, n_estimators=500, subsample=0.6; total time=   0.4s
# [CV] END learning_rate=0.3, max_depth=5, min_child_weight=6, n_estimators=500, subsample=0.6; total time=   0.3s
# [CV] END learning_rate=0.3, max_depth=5, min_child_weight=6, n_estimators=500, subsample=0.6; total time=   0.4s
# [CV] END learning_rate=0.3, max_depth=5, min_child_weight=6, n_estimators=500, subsample=0.6; total time=   0.3s
# [CV] END learning_rate=0.2, max_depth=25, min_child_weight=7, n_estimators=100, subsample=0.6; total time=   0.1s
# [CV] END learning_rate=0.2, max_depth=25, min_child_weight=7, n_estimators=100, subsample=0.6; total time=   0.1s
# [CV] END learning_rate=0.2, max_depth=25, min_child_weight=7, n_estimators=100, subsample=0.6; total time=   0.1s
# [CV] END learning_rate=0.2, max_depth=25, min_child_weight=7, n_estimators=100, subsample=0.6; total time=   0.1s
# [CV] END learning_rate=0.2, max_depth=25, min_child_weight=7, n_estimators=100, subsample=0.6; total time=   0.1s
# [CV] END learning_rate=0.1, max_depth=10, min_child_weight=5, n_estimators=900, subsample=0.6; total time=   1.0s
# [CV] END learning_rate=0.1, max_depth=10, min_child_weight=5, n_estimators=900, subsample=0.6; total time=   7.8s
# [CV] END learning_rate=0.1, max_depth=10, min_child_weight=5, n_estimators=900, subsample=0.6; total time=   2.8s
# [CV] END learning_rate=0.1, max_depth=10, min_child_weight=5, n_estimators=900, subsample=0.6; total time=   1.9s
# [CV] END learning_rate=0.1, max_depth=10, min_child_weight=5, n_estimators=900, subsample=0.6; total time=   0.9s
# [CV] END learning_rate=0.3, max_depth=15, min_child_weight=6, n_estimators=500, subsample=0.7; total time=   1.4s
# [CV] END learning_rate=0.3, max_depth=15, min_child_weight=6, n_estimators=500, subsample=0.7; total time=   3.9s
# [CV] END learning_rate=0.3, max_depth=15, min_child_weight=6, n_estimators=500, subsample=0.7; total time=   2.1s
# [CV] END learning_rate=0.3, max_depth=15, min_child_weight=6, n_estimators=500, subsample=0.7; total time=   1.3s
# [CV] END learning_rate=0.3, max_depth=15, min_child_weight=6, n_estimators=500, subsample=0.7; total time=  12.3s
# [CV] END learning_rate=0.2, max_depth=5, min_child_weight=5, n_estimators=1000, subsample=0.7; total time=   1.5s
# [CV] END learning_rate=0.2, max_depth=5, min_child_weight=5, n_estimators=1000, subsample=0.7; total time=   3.0s
# [CV] END learning_rate=0.2, max_depth=5, min_child_weight=5, n_estimators=1000, subsample=0.7; total time=   7.0s
# [CV] END learning_rate=0.2, max_depth=5, min_child_weight=5, n_estimators=1000, subsample=0.7; total time=   3.8s
# [CV] END learning_rate=0.2, max_depth=5, min_child_weight=5, n_estimators=1000, subsample=0.7; total time=   2.5s
# [CV] END learning_rate=0.3, max_depth=15, min_child_weight=5, n_estimators=800, subsample=0.7; total time=   0.7s
# [CV] END learning_rate=0.3, max_depth=15, min_child_weight=5, n_estimators=800, subsample=0.7; total time=   1.0s
# [CV] END learning_rate=0.3, max_depth=15, min_child_weight=5, n_estimators=800, subsample=0.7; total time=   0.7s
# [CV] END learning_rate=0.3, max_depth=15, min_child_weight=5, n_estimators=800, subsample=0.7; total time=   0.7s
# [CV] END learning_rate=0.3, max_depth=15, min_child_weight=5, n_estimators=800, subsample=0.7; total time=   0.7s
# [CV] END learning_rate=0.05, max_depth=30, min_child_weight=7, n_estimators=200, subsample=0.7; total time=   2.7s
# [CV] END learning_rate=0.05, max_depth=30, min_child_weight=7, n_estimators=200, subsample=0.7; total time=   1.9s
# [CV] END learning_rate=0.05, max_depth=30, min_child_weight=7, n_estimators=200, subsample=0.7; total time=   0.8s
# [CV] END learning_rate=0.05, max_depth=30, min_child_weight=7, n_estimators=200, subsample=0.7; total time=   0.7s
# [CV] END learning_rate=0.05, max_depth=30, min_child_weight=7, n_estimators=200, subsample=0.7; total time=   0.3s
# [CV] END learning_rate=0.05, max_depth=15, min_child_weight=3, n_estimators=800, subsample=0.7; total time=   1.3s
# [CV] END learning_rate=0.05, max_depth=15, min_child_weight=3, n_estimators=800, subsample=0.7; total time=   2.1s
# [CV] END learning_rate=0.05, max_depth=15, min_child_weight=3, n_estimators=800, subsample=0.7; total time=   4.2s
# [CV] END learning_rate=0.05, max_depth=15, min_child_weight=3, n_estimators=800, subsample=0.7; total time=   5.7s
# [CV] END learning_rate=0.05, max_depth=15, min_child_weight=3, n_estimators=800, subsample=0.7; total time=   4.0s
# [CV] END learning_rate=0.05, max_depth=30, min_child_weight=4, n_estimators=800, subsample=0.7; total time=   3.4s
# [CV] END learning_rate=0.05, max_depth=30, min_child_weight=4, n_estimators=800, subsample=0.7; total time=   7.8s
# [CV] END learning_rate=0.05, max_depth=30, min_child_weight=4, n_estimators=800, subsample=0.7; total time=   5.2s
# [CV] END learning_rate=0.05, max_depth=30, min_child_weight=4, n_estimators=800, subsample=0.7; total time=   6.0s
# [CV] END learning_rate=0.05, max_depth=30, min_child_weight=4, n_estimators=800, subsample=0.7; total time=   4.5s
# [CV] END learning_rate=0.5, max_depth=30, min_child_weight=7, n_estimators=1100, subsample=0.7; total time=   0.7s
# [CV] END learning_rate=0.5, max_depth=30, min_child_weight=7, n_estimators=1100, subsample=0.7; total time=   0.8s
# [CV] END learning_rate=0.5, max_depth=30, min_child_weight=7, n_estimators=1100, subsample=0.7; total time=   0.7s
# [CV] END learning_rate=0.5, max_depth=30, min_child_weight=7, n_estimators=1100, subsample=0.7; total time=   0.6s
# [CV] END learning_rate=0.5, max_depth=30, min_child_weight=7, n_estimators=1100, subsample=0.7; total time=   0.7s
# [CV] END learning_rate=0.3, max_depth=25, min_child_weight=5, n_estimators=800, subsample=0.6; total time=   1.0s
# [CV] END learning_rate=0.3, max_depth=25, min_child_weight=5, n_estimators=800, subsample=0.6; total time=   0.8s
# [CV] END learning_rate=0.3, max_depth=25, min_child_weight=5, n_estimators=800, subsample=0.6; total time=   4.1s
# [CV] END learning_rate=0.3, max_depth=25, min_child_weight=5, n_estimators=800, subsample=0.6; total time=   0.7s
# [CV] END learning_rate=0.3, max_depth=25, min_child_weight=5, n_estimators=800, subsample=0.6; total time=   0.8s
# [CV] END learning_rate=0.1, max_depth=15, min_child_weight=7, n_estimators=600, subsample=0.6; total time=   0.7s
# [CV] END learning_rate=0.1, max_depth=15, min_child_weight=7, n_estimators=600, subsample=0.6; total time=   0.7s
# [CV] END learning_rate=0.1, max_depth=15, min_child_weight=7, n_estimators=600, subsample=0.6; total time=   0.7s
# [CV] END learning_rate=0.1, max_depth=15, min_child_weight=7, n_estimators=600, subsample=0.6; total time=   1.0s
# [CV] END learning_rate=0.1, max_depth=15, min_child_weight=7, n_estimators=600, subsample=0.6; total time=   1.7s
# [CV] END learning_rate=0.3, max_depth=30, min_child_weight=4, n_estimators=500, subsample=0.8; total time=   1.8s
# [CV] END learning_rate=0.3, max_depth=30, min_child_weight=4, n_estimators=500, subsample=0.8; total time=   0.6s
# [CV] END learning_rate=0.3, max_depth=30, min_child_weight=4, n_estimators=500, subsample=0.8; total time=   0.7s
# [CV] END learning_rate=0.3, max_depth=30, min_child_weight=4, n_estimators=500, subsample=0.8; total time=   3.7s
# [CV] END learning_rate=0.3, max_depth=30, min_child_weight=4, n_estimators=500, subsample=0.8; total time=   0.6s
# [CV] END learning_rate=0.3, max_depth=10, min_child_weight=3, n_estimators=500, subsample=0.8; total time=   0.3s
# [CV] END learning_rate=0.3, max_depth=10, min_child_weight=3, n_estimators=500, subsample=0.8; total time=   0.4s
# [CV] END learning_rate=0.3, max_depth=10, min_child_weight=3, n_estimators=500, subsample=0.8; total time=   0.4s
# [CV] END learning_rate=0.3, max_depth=10, min_child_weight=3, n_estimators=500, subsample=0.8; total time=   0.3s
# [CV] END learning_rate=0.3, max_depth=10, min_child_weight=3, n_estimators=500, subsample=0.8; total time=   0.4s
# [CV] END learning_rate=0.5, max_depth=30, min_child_weight=6, n_estimators=300, subsample=0.6; total time=   0.4s
# [CV] END learning_rate=0.5, max_depth=30, min_child_weight=6, n_estimators=300, subsample=0.6; total time=   0.4s
# [CV] END learning_rate=0.5, max_depth=30, min_child_weight=6, n_estimators=300, subsample=0.6; total time=   0.4s
# [CV] END learning_rate=0.5, max_depth=30, min_child_weight=6, n_estimators=300, subsample=0.6; total time=   0.4s
# [CV] END learning_rate=0.5, max_depth=30, min_child_weight=6, n_estimators=300, subsample=0.6; total time=   0.4s
# [CV] END learning_rate=0.5, max_depth=30, min_child_weight=7, n_estimators=700, subsample=0.8; total time=   0.6s
# [CV] END learning_rate=0.5, max_depth=30, min_child_weight=7, n_estimators=700, subsample=0.8; total time=   0.6s
# [CV] END learning_rate=0.5, max_depth=30, min_child_weight=7, n_estimators=700, subsample=0.8; total time=   0.6s
# [CV] END learning_rate=0.5, max_depth=30, min_child_weight=7, n_estimators=700, subsample=0.8; total time=   0.5s
# [CV] END learning_rate=0.5, max_depth=30, min_child_weight=7, n_estimators=700, subsample=0.8; total time=   0.5s
# [CV] END learning_rate=0.6, max_depth=20, min_child_weight=3, n_estimators=1100, subsample=0.8; total time=   0.6s
# [CV] END learning_rate=0.6, max_depth=20, min_child_weight=3, n_estimators=1100, subsample=0.8; total time=   0.5s
# [CV] END learning_rate=0.6, max_depth=20, min_child_weight=3, n_estimators=1100, subsample=0.8; total time=   0.4s
# [CV] END learning_rate=0.6, max_depth=20, min_child_weight=3, n_estimators=1100, subsample=0.8; total time=   0.5s
# [CV] END learning_rate=0.6, max_depth=20, min_child_weight=3, n_estimators=1100, subsample=0.8; total time=   0.6s
# [CV] END learning_rate=0.2, max_depth=10, min_child_weight=5, n_estimators=1200, subsample=0.6; total time=   4.0s
# [CV] END learning_rate=0.2, max_depth=10, min_child_weight=5, n_estimators=1200, subsample=0.6; total time=   0.9s
# [CV] END learning_rate=0.2, max_depth=10, min_child_weight=5, n_estimators=1200, subsample=0.6; total time=   0.9s
# [CV] END learning_rate=0.2, max_depth=10, min_child_weight=5, n_estimators=1200, subsample=0.6; total time=   0.9s
# [CV] END learning_rate=0.2, max_depth=10, min_child_weight=5, n_estimators=1200, subsample=0.6; total time=   1.0s
# [CV] END learning_rate=0.1, max_depth=30, min_child_weight=3, n_estimators=800, subsample=0.6; total time=   2.5s
# [CV] END learning_rate=0.1, max_depth=30, min_child_weight=3, n_estimators=800, subsample=0.6; total time=   1.3s
# [CV] END learning_rate=0.1, max_depth=30, min_child_weight=3, n_estimators=800, subsample=0.6; total time=   1.3s
# [CV] END learning_rate=0.1, max_depth=30, min_child_weight=3, n_estimators=800, subsample=0.6; total time=   2.4s
# [CV] END learning_rate=0.1, max_depth=30, min_child_weight=3, n_estimators=800, subsample=0.6; total time=   3.0s
# [CV] END learning_rate=0.5, max_depth=30, min_child_weight=4, n_estimators=400, subsample=0.7; total time=   0.4s
# [CV] END learning_rate=0.5, max_depth=30, min_child_weight=4, n_estimators=400, subsample=0.7; total time=   0.3s
# [CV] END learning_rate=0.5, max_depth=30, min_child_weight=4, n_estimators=400, subsample=0.7; total time=   0.4s
# [CV] END learning_rate=0.5, max_depth=30, min_child_weight=4, n_estimators=400, subsample=0.7; total time=   0.4s
# [CV] END learning_rate=0.5, max_depth=30, min_child_weight=4, n_estimators=400, subsample=0.7; total time=   0.3s
# [CV] END learning_rate=0.1, max_depth=30, min_child_weight=4, n_estimators=300, subsample=0.8; total time=   0.5s
# [CV] END learning_rate=0.1, max_depth=30, min_child_weight=4, n_estimators=300, subsample=0.8; total time=   0.5s
# [CV] END learning_rate=0.1, max_depth=30, min_child_weight=4, n_estimators=300, subsample=0.8; total time=   0.6s
# [CV] END learning_rate=0.1, max_depth=30, min_child_weight=4, n_estimators=300, subsample=0.8; total time=   0.5s
# [CV] END learning_rate=0.1, max_depth=30, min_child_weight=4, n_estimators=300, subsample=0.8; total time=   0.5s
# [CV] END learning_rate=0.3, max_depth=20, min_child_weight=7, n_estimators=300, subsample=0.6; total time=   0.4s
# [CV] END learning_rate=0.3, max_depth=20, min_child_weight=7, n_estimators=300, subsample=0.6; total time=   0.4s
# [CV] END learning_rate=0.3, max_depth=20, min_child_weight=7, n_estimators=300, subsample=0.6; total time=   0.4s
# [CV] END learning_rate=0.3, max_depth=20, min_child_weight=7, n_estimators=300, subsample=0.6; total time=   0.4s
# [CV] END learning_rate=0.3, max_depth=20, min_child_weight=7, n_estimators=300, subsample=0.6; total time=   0.4s
# [CV] END learning_rate=0.3, max_depth=30, min_child_weight=3, n_estimators=1200, subsample=0.6; total time=   0.9s
# [CV] END learning_rate=0.3, max_depth=30, min_child_weight=3, n_estimators=1200, subsample=0.6; total time=   0.9s
# [CV] END learning_rate=0.3, max_depth=30, min_child_weight=3, n_estimators=1200, subsample=0.6; total time=   3.8s
# [CV] END learning_rate=0.3, max_depth=30, min_child_weight=3, n_estimators=1200, subsample=0.6; total time=   0.8s
# [CV] END learning_rate=0.3, max_depth=30, min_child_weight=3, n_estimators=1200, subsample=0.6; total time=   0.8s
# [CV] END learning_rate=0.1, max_depth=5, min_child_weight=4, n_estimators=1200, subsample=0.7; total time=   0.8s
# [CV] END learning_rate=0.1, max_depth=5, min_child_weight=4, n_estimators=1200, subsample=0.7; total time=   0.8s
# [CV] END learning_rate=0.1, max_depth=5, min_child_weight=4, n_estimators=1200, subsample=0.7; total time=   0.8s
# [CV] END learning_rate=0.1, max_depth=5, min_child_weight=4, n_estimators=1200, subsample=0.7; total time=   0.8s
# [CV] END learning_rate=0.1, max_depth=5, min_child_weight=4, n_estimators=1200, subsample=0.7; total time=   0.8s
# [CV] END learning_rate=0.5, max_depth=20, min_child_weight=6, n_estimators=100, subsample=0.8; total time=   0.2s
# [CV] END learning_rate=0.5, max_depth=20, min_child_weight=6, n_estimators=100, subsample=0.8; total time=   0.2s
# [CV] END learning_rate=0.5, max_depth=20, min_child_weight=6, n_estimators=100, subsample=0.8; total time=   0.2s
# [CV] END learning_rate=0.5, max_depth=20, min_child_weight=6, n_estimators=100, subsample=0.8; total time=   0.2s
# [CV] END learning_rate=0.5, max_depth=20, min_child_weight=6, n_estimators=100, subsample=0.8; total time=   0.2s
# [CV] END learning_rate=0.6, max_depth=25, min_child_weight=7, n_estimators=800, subsample=0.7; total time=   0.6s
# [CV] END learning_rate=0.6, max_depth=25, min_child_weight=7, n_estimators=800, subsample=0.7; total time=   0.6s
# [CV] END learning_rate=0.6, max_depth=25, min_child_weight=7, n_estimators=800, subsample=0.7; total time=   0.6s
# [CV] END learning_rate=0.6, max_depth=25, min_child_weight=7, n_estimators=800, subsample=0.7; total time=   0.6s
# [CV] END learning_rate=0.6, max_depth=25, min_child_weight=7, n_estimators=800, subsample=0.7; total time=   0.6s
# [CV] END learning_rate=0.1, max_depth=10, min_child_weight=5, n_estimators=200, subsample=0.7; total time=   0.2s
# [CV] END learning_rate=0.1, max_depth=10, min_child_weight=5, n_estimators=200, subsample=0.7; total time=   0.2s
# [CV] END learning_rate=0.1, max_depth=10, min_child_weight=5, n_estimators=200, subsample=0.7; total time=   0.3s
# [CV] END learning_rate=0.1, max_depth=10, min_child_weight=5, n_estimators=200, subsample=0.7; total time=   3.1s
# [CV] END learning_rate=0.1, max_depth=10, min_child_weight=5, n_estimators=200, subsample=0.7; total time=   0.3s
# [CV] END learning_rate=0.05, max_depth=30, min_child_weight=7, n_estimators=200, subsample=0.8; total time=   0.3s
# [CV] END learning_rate=0.05, max_depth=30, min_child_weight=7, n_estimators=200, subsample=0.8; total time=   0.3s
# [CV] END learning_rate=0.05, max_depth=30, min_child_weight=7, n_estimators=200, subsample=0.8; total time=   0.3s
# [CV] END learning_rate=0.05, max_depth=30, min_child_weight=7, n_estimators=200, subsample=0.8; total time=   0.3s
# [CV] END learning_rate=0.05, max_depth=30, min_child_weight=7, n_estimators=200, subsample=0.8; total time=   0.3s
# [CV] END learning_rate=0.1, max_depth=5, min_child_weight=6, n_estimators=1200, subsample=0.7; total time=   0.8s
# [CV] END learning_rate=0.1, max_depth=5, min_child_weight=6, n_estimators=1200, subsample=0.7; total time=   0.8s
# [CV] END learning_rate=0.1, max_depth=5, min_child_weight=6, n_estimators=1200, subsample=0.7; total time=   0.8s
# [CV] END learning_rate=0.1, max_depth=5, min_child_weight=6, n_estimators=1200, subsample=0.7; total time=   0.8s
# [CV] END learning_rate=0.1, max_depth=5, min_child_weight=6, n_estimators=1200, subsample=0.7; total time=   0.8s
# [CV] END learning_rate=0.05, max_depth=15, min_child_weight=6, n_estimators=100, subsample=0.6; total time=   0.1s
# [CV] END learning_rate=0.05, max_depth=15, min_child_weight=6, n_estimators=100, subsample=0.6; total time=   0.1s
# [CV] END learning_rate=0.05, max_depth=15, min_child_weight=6, n_estimators=100, subsample=0.6; total time=   0.1s
# [CV] END learning_rate=0.05, max_depth=15, min_child_weight=6, n_estimators=100, subsample=0.6; total time=   0.1s
# [CV] END learning_rate=0.05, max_depth=15, min_child_weight=6, n_estimators=100, subsample=0.6; total time=   0.1s
# [CV] END learning_rate=0.1, max_depth=15, min_child_weight=7, n_estimators=1000, subsample=0.6; total time=   1.1s
# [CV] END learning_rate=0.1, max_depth=15, min_child_weight=7, n_estimators=1000, subsample=0.6; total time=   1.1s
# [CV] END learning_rate=0.1, max_depth=15, min_child_weight=7, n_estimators=1000, subsample=0.6; total time=   1.2s
# [CV] END learning_rate=0.1, max_depth=15, min_child_weight=7, n_estimators=1000, subsample=0.6; total time=   4.2s
# [CV] END learning_rate=0.1, max_depth=15, min_child_weight=7, n_estimators=1000, subsample=0.6; total time=   1.1s
# [CV] END learning_rate=0.6, max_depth=5, min_child_weight=7, n_estimators=400, subsample=0.7; total time=   0.3s
# [CV] END learning_rate=0.6, max_depth=5, min_child_weight=7, n_estimators=400, subsample=0.7; total time=   0.3s
# [CV] END learning_rate=0.6, max_depth=5, min_child_weight=7, n_estimators=400, subsample=0.7; total time=   0.3s
# [CV] END learning_rate=0.6, max_depth=5, min_child_weight=7, n_estimators=400, subsample=0.7; total time=   0.3s
# [CV] END learning_rate=0.6, max_depth=5, min_child_weight=7, n_estimators=400, subsample=0.7; total time=   0.3s
# [CV] END learning_rate=0.3, max_depth=15, min_child_weight=7, n_estimators=900, subsample=0.8; total time=   0.8s
# [CV] END learning_rate=0.3, max_depth=15, min_child_weight=7, n_estimators=900, subsample=0.8; total time=   0.8s
# [CV] END learning_rate=0.3, max_depth=15, min_child_weight=7, n_estimators=900, subsample=0.8; total time=   0.9s
# [CV] END learning_rate=0.3, max_depth=15, min_child_weight=7, n_estimators=900, subsample=0.8; total time=   0.7s
# [CV] END learning_rate=0.3, max_depth=15, min_child_weight=7, n_estimators=900, subsample=0.8; total time=   0.8s
# [CV] END learning_rate=0.3, max_depth=5, min_child_weight=5, n_estimators=300, subsample=0.6; total time=   0.2s
# [CV] END learning_rate=0.3, max_depth=5, min_child_weight=5, n_estimators=300, subsample=0.6; total time=   0.2s
# [CV] END learning_rate=0.3, max_depth=5, min_child_weight=5, n_estimators=300, subsample=0.6; total time=   0.2s
# [CV] END learning_rate=0.3, max_depth=5, min_child_weight=5, n_estimators=300, subsample=0.6; total time=   0.2s
# [CV] END learning_rate=0.3, max_depth=5, min_child_weight=5, n_estimators=300, subsample=0.6; total time=   0.2s
# [CV] END learning_rate=0.6, max_depth=10, min_child_weight=7, n_estimators=900, subsample=0.7; total time=   0.5s
# [CV] END learning_rate=0.6, max_depth=10, min_child_weight=7, n_estimators=900, subsample=0.7; total time=   0.5s
# [CV] END learning_rate=0.6, max_depth=10, min_child_weight=7, n_estimators=900, subsample=0.7; total time=   0.5s
# [CV] END learning_rate=0.6, max_depth=10, min_child_weight=7, n_estimators=900, subsample=0.7; total time=   0.5s
# [CV] END learning_rate=0.6, max_depth=10, min_child_weight=7, n_estimators=900, subsample=0.7; total time=   3.7s
# [CV] END learning_rate=0.3, max_depth=20, min_child_weight=7, n_estimators=500, subsample=0.8; total time=   0.7s
# [CV] END learning_rate=0.3, max_depth=20, min_child_weight=7, n_estimators=500, subsample=0.8; total time=   0.7s
# [CV] END learning_rate=0.3, max_depth=20, min_child_weight=7, n_estimators=500, subsample=0.8; total time=   0.7s
# [CV] END learning_rate=0.3, max_depth=20, min_child_weight=7, n_estimators=500, subsample=0.8; total time=   0.7s
# [CV] END learning_rate=0.3, max_depth=20, min_child_weight=7, n_estimators=500, subsample=0.8; total time=   0.6s
# [CV] END learning_rate=0.3, max_depth=5, min_child_weight=7, n_estimators=1000, subsample=0.8; total time=   0.6s
# [CV] END learning_rate=0.3, max_depth=5, min_child_weight=7, n_estimators=1000, subsample=0.8; total time=   0.6s
# [CV] END learning_rate=0.3, max_depth=5, min_child_weight=7, n_estimators=1000, subsample=0.8; total time=   0.6s
# [CV] END learning_rate=0.3, max_depth=5, min_child_weight=7, n_estimators=1000, subsample=0.8; total time=   0.6s
# [CV] END learning_rate=0.3, max_depth=5, min_child_weight=7, n_estimators=1000, subsample=0.8; total time=   0.6s
# [CV] END learning_rate=0.05, max_depth=5, min_child_weight=3, n_estimators=1100, subsample=0.6; total time=   0.7s
# [CV] END learning_rate=0.05, max_depth=5, min_child_weight=3, n_estimators=1100, subsample=0.6; total time=   0.7s
# [CV] END learning_rate=0.05, max_depth=5, min_child_weight=3, n_estimators=1100, subsample=0.6; total time=   0.7s
# [CV] END learning_rate=0.05, max_depth=5, min_child_weight=3, n_estimators=1100, subsample=0.6; total time=   0.7s
# [CV] END learning_rate=0.05, max_depth=5, min_child_weight=3, n_estimators=1100, subsample=0.6; total time=   2.3s
# [CV] END learning_rate=0.05, max_depth=30, min_child_weight=3, n_estimators=1100, subsample=0.8; total time=   3.3s
# [CV] END learning_rate=0.05, max_depth=30, min_child_weight=3, n_estimators=1100, subsample=0.8; total time=   1.8s
# [CV] END learning_rate=0.05, max_depth=30, min_child_weight=3, n_estimators=1100, subsample=0.8; total time=   2.0s
# [CV] END learning_rate=0.05, max_depth=30, min_child_weight=3, n_estimators=1100, subsample=0.8; total time=   1.8s
# [CV] END learning_rate=0.05, max_depth=30, min_child_weight=3, n_estimators=1100, subsample=0.8; total time=   2.1s
# [CV] END learning_rate=0.2, max_depth=30, min_child_weight=5, n_estimators=1200, subsample=0.6; total time=   4.1s
# [CV] END learning_rate=0.2, max_depth=30, min_child_weight=5, n_estimators=1200, subsample=0.6; total time=   1.0s
# [CV] END learning_rate=0.2, max_depth=30, min_child_weight=5, n_estimators=1200, subsample=0.6; total time=   1.1s
# [CV] END learning_rate=0.2, max_depth=30, min_child_weight=5, n_estimators=1200, subsample=0.6; total time=   1.2s
# [CV] END learning_rate=0.2, max_depth=30, min_child_weight=5, n_estimators=1200, subsample=0.6; total time=   1.3s
# [CV] END learning_rate=0.2, max_depth=10, min_child_weight=5, n_estimators=1200, subsample=0.8; total time=   0.7s
# [CV] END learning_rate=0.2, max_depth=10, min_child_weight=5, n_estimators=1200, subsample=0.8; total time=   0.8s
# [CV] END learning_rate=0.2, max_depth=10, min_child_weight=5, n_estimators=1200, subsample=0.8; total time=   0.8s
# [CV] END learning_rate=0.2, max_depth=10, min_child_weight=5, n_estimators=1200, subsample=0.8; total time=   0.7s
# [CV] END learning_rate=0.2, max_depth=10, min_child_weight=5, n_estimators=1200, subsample=0.8; total time=   0.8s
# [CV] END learning_rate=0.6, max_depth=10, min_child_weight=4, n_estimators=900, subsample=0.6; total time=   0.5s
# [CV] END learning_rate=0.6, max_depth=10, min_child_weight=4, n_estimators=900, subsample=0.6; total time=   0.4s
# [CV] END learning_rate=0.6, max_depth=10, min_child_weight=4, n_estimators=900, subsample=0.6; total time=   0.6s
# [CV] END learning_rate=0.6, max_depth=10, min_child_weight=4, n_estimators=900, subsample=0.6; total time=   3.4s
# [CV] END learning_rate=0.6, max_depth=10, min_child_weight=4, n_estimators=900, subsample=0.6; total time=   0.4s
# [CV] END learning_rate=0.1, max_depth=20, min_child_weight=6, n_estimators=1100, subsample=0.8; total time=   1.6s
# [CV] END learning_rate=0.1, max_depth=20, min_child_weight=6, n_estimators=1100, subsample=0.8; total time=   1.6s
# [CV] END learning_rate=0.1, max_depth=20, min_child_weight=6, n_estimators=1100, subsample=0.8; total time=   1.7s
# [CV] END learning_rate=0.1, max_depth=20, min_child_weight=6, n_estimators=1100, subsample=0.8; total time=   1.4s
# [CV] END learning_rate=0.1, max_depth=20, min_child_weight=6, n_estimators=1100, subsample=0.8; total time=   1.4s
# [CV] END learning_rate=0.05, max_depth=10, min_child_weight=7, n_estimators=800, subsample=0.6; total time=   0.8s
# [CV] END learning_rate=0.05, max_depth=10, min_child_weight=7, n_estimators=800, subsample=0.6; total time=   0.7s
# [CV] END learning_rate=0.05, max_depth=10, min_child_weight=7, n_estimators=800, subsample=0.6; total time=   3.8s
# [CV] END learning_rate=0.05, max_depth=10, min_child_weight=7, n_estimators=800, subsample=0.6; total time=   0.7s
# [CV] END learning_rate=0.05, max_depth=10, min_child_weight=7, n_estimators=800, subsample=0.6; total time=   0.7s
# [CV] END learning_rate=0.5, max_depth=20, min_child_weight=6, n_estimators=1200, subsample=0.8; total time=   0.6s
# [CV] END learning_rate=0.5, max_depth=20, min_child_weight=6, n_estimators=1200, subsample=0.8; total time=   0.6s
# [CV] END learning_rate=0.5, max_depth=20, min_child_weight=6, n_estimators=1200, subsample=0.8; total time=   0.6s
# [CV] END learning_rate=0.5, max_depth=20, min_child_weight=6, n_estimators=1200, subsample=0.8; total time=   0.6s
# [CV] END learning_rate=0.5, max_depth=20, min_child_weight=6, n_estimators=1200, subsample=0.8; total time=   0.6s
# [CV] END learning_rate=0.1, max_depth=15, min_child_weight=7, n_estimators=900, subsample=0.7; total time=   1.1s
# [CV] END learning_rate=0.1, max_depth=15, min_child_weight=7, n_estimators=900, subsample=0.7; total time=   1.1s
# [CV] END learning_rate=0.1, max_depth=15, min_child_weight=7, n_estimators=900, subsample=0.7; total time=   1.1s
# [CV] END learning_rate=0.1, max_depth=15, min_child_weight=7, n_estimators=900, subsample=0.7; total time=   1.1s
# [CV] END learning_rate=0.1, max_depth=15, min_child_weight=7, n_estimators=900, subsample=0.7; total time=   4.1s
# [CV] END learning_rate=0.6, max_depth=30, min_child_weight=7, n_estimators=100, subsample=0.7; total time=   0.1s
# [CV] END learning_rate=0.6, max_depth=30, min_child_weight=7, n_estimators=100, subsample=0.7; total time=   0.1s
# [CV] END learning_rate=0.6, max_depth=30, min_child_weight=7, n_estimators=100, subsample=0.7; total time=   0.2s
# [CV] END learning_rate=0.6, max_depth=30, min_child_weight=7, n_estimators=100, subsample=0.7; total time=   0.1s
# [CV] END learning_rate=0.6, max_depth=30, min_child_weight=7, n_estimators=100, subsample=0.7; total time=   0.1s
# [CV] END learning_rate=0.05, max_depth=5, min_child_weight=6, n_estimators=900, subsample=0.7; total time=   0.6s
# [CV] END learning_rate=0.05, max_depth=5, min_child_weight=6, n_estimators=900, subsample=0.7; total time=   0.6s
# [CV] END learning_rate=0.05, max_depth=5, min_child_weight=6, n_estimators=900, subsample=0.7; total time=   0.6s
# [CV] END learning_rate=0.05, max_depth=5, min_child_weight=6, n_estimators=900, subsample=0.7; total time=   0.6s
# [CV] END learning_rate=0.05, max_depth=5, min_child_weight=6, n_estimators=900, subsample=0.7; total time=   0.6s
# [CV] END learning_rate=0.5, max_depth=15, min_child_weight=3, n_estimators=1100, subsample=0.8; total time=   0.6s
# [CV] END learning_rate=0.5, max_depth=15, min_child_weight=3, n_estimators=1100, subsample=0.8; total time=   0.4s
# [CV] END learning_rate=0.5, max_depth=15, min_child_weight=3, n_estimators=1100, subsample=0.8; total time=   0.5s
# [CV] END learning_rate=0.5, max_depth=15, min_child_weight=3, n_estimators=1100, subsample=0.8; total time=   0.4s
# [CV] END learning_rate=0.5, max_depth=15, min_child_weight=3, n_estimators=1100, subsample=0.8; total time=   0.5s
# [CV] END learning_rate=0.3, max_depth=5, min_child_weight=5, n_estimators=1200, subsample=0.6; total time=   0.6s
# [CV] END learning_rate=0.3, max_depth=5, min_child_weight=5, n_estimators=1200, subsample=0.6; total time=   0.6s
# [CV] END learning_rate=0.3, max_depth=5, min_child_weight=5, n_estimators=1200, subsample=0.6; total time=   0.7s
# [CV] END learning_rate=0.3, max_depth=5, min_child_weight=5, n_estimators=1200, subsample=0.6; total time=   0.6s
# [CV] END learning_rate=0.3, max_depth=5, min_child_weight=5, n_estimators=1200, subsample=0.6; total time=   0.7s
# [CV] END learning_rate=0.5, max_depth=15, min_child_weight=6, n_estimators=100, subsample=0.8; total time=   0.1s
# [CV] END learning_rate=0.5, max_depth=15, min_child_weight=6, n_estimators=100, subsample=0.8; total time=   0.1s
# [CV] END learning_rate=0.5, max_depth=15, min_child_weight=6, n_estimators=100, subsample=0.8; total time=   0.2s
# [CV] END learning_rate=0.5, max_depth=15, min_child_weight=6, n_estimators=100, subsample=0.8; total time=   0.3s
# [CV] END learning_rate=0.5, max_depth=15, min_child_weight=6, n_estimators=100, subsample=0.8; total time=   0.7s
# [CV] END learning_rate=0.1, max_depth=20, min_child_weight=6, n_estimators=400, subsample=0.7; total time=   3.7s
# [CV] END learning_rate=0.1, max_depth=20, min_child_weight=6, n_estimators=400, subsample=0.7; total time=   2.8s
# [CV] END learning_rate=0.1, max_depth=20, min_child_weight=6, n_estimators=400, subsample=0.7; total time=   2.7s
# [CV] END learning_rate=0.1, max_depth=20, min_child_weight=6, n_estimators=400, subsample=0.7; total time=   0.5s
# [CV] END learning_rate=0.1, max_depth=20, min_child_weight=6, n_estimators=400, subsample=0.7; total time=   0.5s
# [CV] END learning_rate=0.3, max_depth=10, min_child_weight=7, n_estimators=800, subsample=0.7; total time=   0.8s
# [CV] END learning_rate=0.3, max_depth=10, min_child_weight=7, n_estimators=800, subsample=0.7; total time=   0.7s
# [CV] END learning_rate=0.3, max_depth=10, min_child_weight=7, n_estimators=800, subsample=0.7; total time=   0.6s
# [CV] END learning_rate=0.3, max_depth=10, min_child_weight=7, n_estimators=800, subsample=0.7; total time=   3.3s
# [CV] END learning_rate=0.3, max_depth=10, min_child_weight=7, n_estimators=800, subsample=0.7; total time=   1.0s
# [CV] END learning_rate=0.05, max_depth=15, min_child_weight=6, n_estimators=300, subsample=0.8; total time=   0.4s
# [CV] END learning_rate=0.05, max_depth=15, min_child_weight=6, n_estimators=300, subsample=0.8; total time=   0.4s
# [CV] END learning_rate=0.05, max_depth=15, min_child_weight=6, n_estimators=300, subsample=0.8; total time=   0.4s
# [CV] END learning_rate=0.05, max_depth=15, min_child_weight=6, n_estimators=300, subsample=0.8; total time=   0.4s
# [CV] END learning_rate=0.05, max_depth=15, min_child_weight=6, n_estimators=300, subsample=0.8; total time=   0.4s
# [CV] END learning_rate=0.3, max_depth=20, min_child_weight=5, n_estimators=300, subsample=0.7; total time=   0.5s
# [CV] END learning_rate=0.3, max_depth=20, min_child_weight=5, n_estimators=300, subsample=0.7; total time=   0.5s
# [CV] END learning_rate=0.3, max_depth=20, min_child_weight=5, n_estimators=300, subsample=0.7; total time=   0.5s
# [CV] END learning_rate=0.3, max_depth=20, min_child_weight=5, n_estimators=300, subsample=0.7; total time=   0.4s
# [CV] END learning_rate=0.3, max_depth=20, min_child_weight=5, n_estimators=300, subsample=0.7; total time=   0.5s
# [CV] END learning_rate=0.2, max_depth=25, min_child_weight=4, n_estimators=600, subsample=0.6; total time=   0.9s
# [CV] END learning_rate=0.2, max_depth=25, min_child_weight=4, n_estimators=600, subsample=0.6; total time=   0.9s
# [CV] END learning_rate=0.2, max_depth=25, min_child_weight=4, n_estimators=600, subsample=0.6; total time=   0.8s
# [CV] END learning_rate=0.2, max_depth=25, min_child_weight=4, n_estimators=600, subsample=0.6; total time=   0.8s
# [CV] END learning_rate=0.2, max_depth=25, min_child_weight=4, n_estimators=600, subsample=0.6; total time=   0.9s
# [CV] END learning_rate=0.5, max_depth=25, min_child_weight=3, n_estimators=200, subsample=0.7; total time=   0.3s
# [CV] END learning_rate=0.5, max_depth=25, min_child_weight=3, n_estimators=200, subsample=0.7; total time=   0.3s
# [CV] END learning_rate=0.5, max_depth=25, min_child_weight=3, n_estimators=200, subsample=0.7; total time=   2.8s
# [CV] END learning_rate=0.5, max_depth=25, min_child_weight=3, n_estimators=200, subsample=0.7; total time=   0.8s
# [CV] END learning_rate=0.5, max_depth=25, min_child_weight=3, n_estimators=200, subsample=0.7; total time=   0.3s
# [CV] END learning_rate=0.05, max_depth=20, min_child_weight=3, n_estimators=800, subsample=0.7; total time=   1.4s
# [CV] END learning_rate=0.05, max_depth=20, min_child_weight=3, n_estimators=800, subsample=0.7; total time=   1.4s
# [CV] END learning_rate=0.05, max_depth=20, min_child_weight=3, n_estimators=800, subsample=0.7; total time=   1.4s
# [CV] END learning_rate=0.05, max_depth=20, min_child_weight=3, n_estimators=800, subsample=0.7; total time=   1.3s
# [CV] END learning_rate=0.05, max_depth=20, min_child_weight=3, n_estimators=800, subsample=0.7; total time=   1.4s
# [CV] END learning_rate=0.05, max_depth=10, min_child_weight=4, n_estimators=800, subsample=0.8; total time=   1.0s
# [CV] END learning_rate=0.05, max_depth=10, min_child_weight=4, n_estimators=800, subsample=0.8; total time=   0.9s
# [CV] END learning_rate=0.05, max_depth=10, min_child_weight=4, n_estimators=800, subsample=0.8; total time=   2.4s
# [CV] END learning_rate=0.05, max_depth=10, min_child_weight=4, n_estimators=800, subsample=0.8; total time=   2.5s
# [CV] END learning_rate=0.05, max_depth=10, min_child_weight=4, n_estimators=800, subsample=0.8; total time=   1.0s
# [CV] END learning_rate=0.6, max_depth=5, min_child_weight=4, n_estimators=600, subsample=0.7; total time=   0.3s
# [CV] END learning_rate=0.6, max_depth=5, min_child_weight=4, n_estimators=600, subsample=0.7; total time=   0.3s
# [CV] END learning_rate=0.6, max_depth=5, min_child_weight=4, n_estimators=600, subsample=0.7; total time=   0.3s
# [CV] END learning_rate=0.6, max_depth=5, min_child_weight=4, n_estimators=600, subsample=0.7; total time=   0.3s
# [CV] END learning_rate=0.6, max_depth=5, min_child_weight=4, n_estimators=600, subsample=0.7; total time=   0.3s
# [CV] END learning_rate=0.6, max_depth=30, min_child_weight=5, n_estimators=900, subsample=0.6; total time=   0.5s
# [CV] END learning_rate=0.6, max_depth=30, min_child_weight=5, n_estimators=900, subsample=0.6; total time=   0.6s
# [CV] END learning_rate=0.6, max_depth=30, min_child_weight=5, n_estimators=900, subsample=0.6; total time=   0.5s
# [CV] END learning_rate=0.6, max_depth=30, min_child_weight=5, n_estimators=900, subsample=0.6; total time=   0.6s
# [CV] END learning_rate=0.6, max_depth=30, min_child_weight=5, n_estimators=900, subsample=0.6; total time=   0.7s
# [CV] END learning_rate=0.5, max_depth=10, min_child_weight=5, n_estimators=1100, subsample=0.7; total time=   0.5s
# [CV] END learning_rate=0.5, max_depth=10, min_child_weight=5, n_estimators=1100, subsample=0.7; total time=   0.5s
# [CV] END learning_rate=0.5, max_depth=10, min_child_weight=5, n_estimators=1100, subsample=0.7; total time=   0.5s
# [CV] END learning_rate=0.5, max_depth=10, min_child_weight=5, n_estimators=1100, subsample=0.7; total time=   0.5s
# [CV] END learning_rate=0.5, max_depth=10, min_child_weight=5, n_estimators=1100, subsample=0.7; total time=   0.5s
# [CV] END learning_rate=0.3, max_depth=5, min_child_weight=3, n_estimators=100, subsample=0.7; total time=   0.1s
# [CV] END learning_rate=0.3, max_depth=5, min_child_weight=3, n_estimators=100, subsample=0.7; total time=   0.1s
# [CV] END learning_rate=0.3, max_depth=5, min_child_weight=3, n_estimators=100, subsample=0.7; total time=   0.1s
# [CV] END learning_rate=0.3, max_depth=5, min_child_weight=3, n_estimators=100, subsample=0.7; total time=   0.1s
# [CV] END learning_rate=0.3, max_depth=5, min_child_weight=3, n_estimators=100, subsample=0.7; total time=   0.1s
# [CV] END learning_rate=0.5, max_depth=5, min_child_weight=3, n_estimators=200, subsample=0.7; total time=   0.2s
# [CV] END learning_rate=0.5, max_depth=5, min_child_weight=3, n_estimators=200, subsample=0.7; total time=   0.2s
# [CV] END learning_rate=0.5, max_depth=5, min_child_weight=3, n_estimators=200, subsample=0.7; total time=   0.2s
# [CV] END learning_rate=0.5, max_depth=5, min_child_weight=3, n_estimators=200, subsample=0.7; total time=   0.1s
# [CV] END learning_rate=0.5, max_depth=5, min_child_weight=3, n_estimators=200, subsample=0.7; total time=   0.3s
# [CV] END learning_rate=0.05, max_depth=30, min_child_weight=3, n_estimators=900, subsample=0.8; total time=   4.7s
# [CV] END learning_rate=0.05, max_depth=30, min_child_weight=3, n_estimators=900, subsample=0.8; total time=   1.7s
# [CV] END learning_rate=0.05, max_depth=30, min_child_weight=3, n_estimators=900, subsample=0.8; total time=   1.8s
# [CV] END learning_rate=0.05, max_depth=30, min_child_weight=3, n_estimators=900, subsample=0.8; total time=   1.6s
# [CV] END learning_rate=0.05, max_depth=30, min_child_weight=3, n_estimators=900, subsample=0.8; total time=   1.8s
# [CV] END learning_rate=0.5, max_depth=30, min_child_weight=7, n_estimators=500, subsample=0.8; total time=   0.6s
# [CV] END learning_rate=0.5, max_depth=30, min_child_weight=7, n_estimators=500, subsample=0.8; total time=   0.5s
# [CV] END learning_rate=0.5, max_depth=30, min_child_weight=7, n_estimators=500, subsample=0.8; total time=   0.6s
# [CV] END learning_rate=0.5, max_depth=30, min_child_weight=7, n_estimators=500, subsample=0.8; total time=   3.4s
# [CV] END learning_rate=0.5, max_depth=30, min_child_weight=7, n_estimators=500, subsample=0.8; total time=   0.5s
# [CV] END learning_rate=0.2, max_depth=15, min_child_weight=6, n_estimators=500, subsample=0.7; total time=   0.7s
# [CV] END learning_rate=0.2, max_depth=15, min_child_weight=6, n_estimators=500, subsample=0.7; total time=   0.7s
# [CV] END learning_rate=0.2, max_depth=15, min_child_weight=6, n_estimators=500, subsample=0.7; total time=   0.6s
# [CV] END learning_rate=0.2, max_depth=15, min_child_weight=6, n_estimators=500, subsample=0.7; total time=   0.7s
# [CV] END learning_rate=0.2, max_depth=15, min_child_weight=6, n_estimators=500, subsample=0.7; total time=   0.7s
# [CV] END learning_rate=0.5, max_depth=25, min_child_weight=3, n_estimators=400, subsample=0.6; total time=   0.4s
# [CV] END learning_rate=0.5, max_depth=25, min_child_weight=3, n_estimators=400, subsample=0.6; total time=   0.3s
# [CV] END learning_rate=0.5, max_depth=25, min_child_weight=3, n_estimators=400, subsample=0.6; total time=   0.5s
# [CV] END learning_rate=0.5, max_depth=25, min_child_weight=3, n_estimators=400, subsample=0.6; total time=   0.5s
# [CV] END learning_rate=0.5, max_depth=25, min_child_weight=3, n_estimators=400, subsample=0.6; total time=   0.5s
# [CV] END learning_rate=0.5, max_depth=30, min_child_weight=3, n_estimators=900, subsample=0.7; total time=   0.4s
# [CV] END learning_rate=0.5, max_depth=30, min_child_weight=3, n_estimators=900, subsample=0.7; total time=   0.5s
# [CV] END learning_rate=0.5, max_depth=30, min_child_weight=3, n_estimators=900, subsample=0.7; total time=   0.4s
# [CV] END learning_rate=0.5, max_depth=30, min_child_weight=3, n_estimators=900, subsample=0.7; total time=   0.5s
# [CV] END learning_rate=0.5, max_depth=30, min_child_weight=3, n_estimators=900, subsample=0.7; total time=   0.6s
# [CV] END learning_rate=0.6, max_depth=25, min_child_weight=6, n_estimators=600, subsample=0.6; total time=   0.5s
# [CV] END learning_rate=0.6, max_depth=25, min_child_weight=6, n_estimators=600, subsample=0.6; total time=   0.5s
# [CV] END learning_rate=0.6, max_depth=25, min_child_weight=6, n_estimators=600, subsample=0.6; total time=   0.4s
# [CV] END learning_rate=0.6, max_depth=25, min_child_weight=6, n_estimators=600, subsample=0.6; total time=   3.7s
# [CV] END learning_rate=0.6, max_depth=25, min_child_weight=6, n_estimators=600, subsample=0.6; total time=   0.7s
# [CV] END learning_rate=0.05, max_depth=10, min_child_weight=4, n_estimators=100, subsample=0.6; total time=   0.1s
# [CV] END learning_rate=0.05, max_depth=10, min_child_weight=4, n_estimators=100, subsample=0.6; total time=   0.1s
# [CV] END learning_rate=0.05, max_depth=10, min_child_weight=4, n_estimators=100, subsample=0.6; total time=   0.1s
# [CV] END learning_rate=0.05, max_depth=10, min_child_weight=4, n_estimators=100, subsample=0.6; total time=   0.1s
# [CV] END learning_rate=0.05, max_depth=10, min_child_weight=4, n_estimators=100, subsample=0.6; total time=   0.1s
# [CV] END learning_rate=0.2, max_depth=5, min_child_weight=7, n_estimators=700, subsample=0.6; total time=   0.5s
# [CV] END learning_rate=0.2, max_depth=5, min_child_weight=7, n_estimators=700, subsample=0.6; total time=   0.4s
# [CV] END learning_rate=0.2, max_depth=5, min_child_weight=7, n_estimators=700, subsample=0.6; total time=   0.4s
# [CV] END learning_rate=0.2, max_depth=5, min_child_weight=7, n_estimators=700, subsample=0.6; total time=   0.4s
# [CV] END learning_rate=0.2, max_depth=5, min_child_weight=7, n_estimators=700, subsample=0.6; total time=   0.4s
# [CV] END learning_rate=0.6, max_depth=30, min_child_weight=4, n_estimators=100, subsample=0.7; total time=   0.2s
# [CV] END learning_rate=0.6, max_depth=30, min_child_weight=4, n_estimators=100, subsample=0.7; total time=   0.2s
# [CV] END learning_rate=0.6, max_depth=30, min_child_weight=4, n_estimators=100, subsample=0.7; total time=   0.2s
# [CV] END learning_rate=0.6, max_depth=30, min_child_weight=4, n_estimators=100, subsample=0.7; total time=   0.2s
# [CV] END learning_rate=0.6, max_depth=30, min_child_weight=4, n_estimators=100, subsample=0.7; total time=   0.2s
# [CV] END learning_rate=0.05, max_depth=25, min_child_weight=4, n_estimators=100, subsample=0.7; total time=   0.1s
# [CV] END learning_rate=0.05, max_depth=25, min_child_weight=4, n_estimators=100, subsample=0.7; total time=   0.2s
# [CV] END learning_rate=0.05, max_depth=25, min_child_weight=4, n_estimators=100, subsample=0.7; total time=   0.1s
# [CV] END learning_rate=0.05, max_depth=25, min_child_weight=4, n_estimators=100, subsample=0.7; total time=   0.1s
# [CV] END learning_rate=0.05, max_depth=25, min_child_weight=4, n_estimators=100, subsample=0.7; total time=   0.1s
# [CV] END learning_rate=0.05, max_depth=5, min_child_weight=5, n_estimators=900, subsample=0.7; total time=   0.6s
# [CV] END learning_rate=0.05, max_depth=5, min_child_weight=5, n_estimators=900, subsample=0.7; total time=   0.6s
# [CV] END learning_rate=0.05, max_depth=5, min_child_weight=5, n_estimators=900, subsample=0.7; total time=   0.6s
# [CV] END learning_rate=0.05, max_depth=5, min_child_weight=5, n_estimators=900, subsample=0.7; total time=   0.6s
# [CV] END learning_rate=0.05, max_depth=5, min_child_weight=5, n_estimators=900, subsample=0.7; total time=   0.6s
# [CV] END learning_rate=0.6, max_depth=25, min_child_weight=5, n_estimators=800, subsample=0.6; total time=   0.5s
# [CV] END learning_rate=0.6, max_depth=25, min_child_weight=5, n_estimators=800, subsample=0.6; total time=   0.6s
# [CV] END learning_rate=0.6, max_depth=25, min_child_weight=5, n_estimators=800, subsample=0.6; total time=   0.5s
# [CV] END learning_rate=0.6, max_depth=25, min_child_weight=5, n_estimators=800, subsample=0.6; total time=   3.7s
# [CV] END learning_rate=0.6, max_depth=25, min_child_weight=5, n_estimators=800, subsample=0.6; total time=   0.8s
# [CV] END learning_rate=0.1, max_depth=15, min_child_weight=4, n_estimators=400, subsample=0.8; total time=   0.7s
# [CV] END learning_rate=0.1, max_depth=15, min_child_weight=4, n_estimators=400, subsample=0.8; total time=   0.7s
# [CV] END learning_rate=0.1, max_depth=15, min_child_weight=4, n_estimators=400, subsample=0.8; total time=   0.7s
# [CV] END learning_rate=0.1, max_depth=15, min_child_weight=4, n_estimators=400, subsample=0.8; total time=   0.6s
# [CV] END learning_rate=0.1, max_depth=15, min_child_weight=4, n_estimators=400, subsample=0.8; total time=   0.7s
# [CV] END learning_rate=0.05, max_depth=30, min_child_weight=5, n_estimators=400, subsample=0.6; total time=   0.6s
# [CV] END learning_rate=0.05, max_depth=30, min_child_weight=5, n_estimators=400, subsample=0.6; total time=   0.6s
# [CV] END learning_rate=0.05, max_depth=30, min_child_weight=5, n_estimators=400, subsample=0.6; total time=   0.6s
# [CV] END learning_rate=0.05, max_depth=30, min_child_weight=5, n_estimators=400, subsample=0.6; total time=   0.5s
# [CV] END learning_rate=0.05, max_depth=30, min_child_weight=5, n_estimators=400, subsample=0.6; total time=   0.5s
# [CV] END learning_rate=0.1, max_depth=10, min_child_weight=6, n_estimators=300, subsample=0.6; total time=   0.3s
# [CV] END learning_rate=0.1, max_depth=10, min_child_weight=6, n_estimators=300, subsample=0.6; total time=   0.3s
# [CV] END learning_rate=0.1, max_depth=10, min_child_weight=6, n_estimators=300, subsample=0.6; total time=   0.3s
# [CV] END learning_rate=0.1, max_depth=10, min_child_weight=6, n_estimators=300, subsample=0.6; total time=   0.3s
# [CV] END learning_rate=0.1, max_depth=10, min_child_weight=6, n_estimators=300, subsample=0.6; total time=   0.3s
# [CV] END learning_rate=0.6, max_depth=25, min_child_weight=5, n_estimators=1100, subsample=0.8; total time=   0.7s
# [CV] END learning_rate=0.6, max_depth=25, min_child_weight=5, n_estimators=1100, subsample=0.8; total time=   0.6s
# [CV] END learning_rate=0.6, max_depth=25, min_child_weight=5, n_estimators=1100, subsample=0.8; total time=   3.8s
# [CV] END learning_rate=0.6, max_depth=25, min_child_weight=5, n_estimators=1100, subsample=0.8; total time=   0.5s
# [CV] END learning_rate=0.6, max_depth=25, min_child_weight=5, n_estimators=1100, subsample=0.8; total time=   0.6s
# [CV] END learning_rate=0.2, max_depth=20, min_child_weight=5, n_estimators=800, subsample=0.8; total time=   0.9s
# [CV] END learning_rate=0.2, max_depth=20, min_child_weight=5, n_estimators=800, subsample=0.8; total time=   1.1s
# [CV] END learning_rate=0.2, max_depth=20, min_child_weight=5, n_estimators=800, subsample=0.8; total time=   0.9s
# [CV] END learning_rate=0.2, max_depth=20, min_child_weight=5, n_estimators=800, subsample=0.8; total time=   1.0s
# [CV] END learning_rate=0.2, max_depth=20, min_child_weight=5, n_estimators=800, subsample=0.8; total time=   0.8s
# [CV] END learning_rate=0.3, max_depth=5, min_child_weight=4, n_estimators=100, subsample=0.6; total time=   0.1s
# [CV] END learning_rate=0.3, max_depth=5, min_child_weight=4, n_estimators=100, subsample=0.6; total time=   0.1s
# [CV] END learning_rate=0.3, max_depth=5, min_child_weight=4, n_estimators=100, subsample=0.6; total time=   0.1s
# [CV] END learning_rate=0.3, max_depth=5, min_child_weight=4, n_estimators=100, subsample=0.6; total time=   0.1s
# [CV] END learning_rate=0.3, max_depth=5, min_child_weight=4, n_estimators=100, subsample=0.6; total time=   0.1s
# [CV] END learning_rate=0.5, max_depth=20, min_child_weight=3, n_estimators=800, subsample=0.8; total time=   0.4s
# [CV] END learning_rate=0.5, max_depth=20, min_child_weight=3, n_estimators=800, subsample=0.8; total time=   0.5s
# [CV] END learning_rate=0.5, max_depth=20, min_child_weight=3, n_estimators=800, subsample=0.8; total time=   0.4s
# [CV] END learning_rate=0.5, max_depth=20, min_child_weight=3, n_estimators=800, subsample=0.8; total time=   0.4s
# [CV] END learning_rate=0.5, max_depth=20, min_child_weight=3, n_estimators=800, subsample=0.8; total time=   0.4s
# [CV] END learning_rate=0.5, max_depth=5, min_child_weight=6, n_estimators=900, subsample=0.6; total time=   0.5s
# [CV] END learning_rate=0.5, max_depth=5, min_child_weight=6, n_estimators=900, subsample=0.6; total time=   0.5s
# [CV] END learning_rate=0.5, max_depth=5, min_child_weight=6, n_estimators=900, subsample=0.6; total time=   0.5s
# [CV] END learning_rate=0.5, max_depth=5, min_child_weight=6, n_estimators=900, subsample=0.6; total time=   3.6s
# [CV] END learning_rate=0.5, max_depth=5, min_child_weight=6, n_estimators=900, subsample=0.6; total time=   0.4s
# [CV] END learning_rate=0.6, max_depth=5, min_child_weight=7, n_estimators=100, subsample=0.6; total time=   0.1s
# [CV] END learning_rate=0.6, max_depth=5, min_child_weight=7, n_estimators=100, subsample=0.6; total time=   0.1s
# [CV] END learning_rate=0.6, max_depth=5, min_child_weight=7, n_estimators=100, subsample=0.6; total time=   0.1s
# [CV] END learning_rate=0.6, max_depth=5, min_child_weight=7, n_estimators=100, subsample=0.6; total time=   0.1s
# [CV] END learning_rate=0.6, max_depth=5, min_child_weight=7, n_estimators=100, subsample=0.6; total time=   0.1s
# [CV] END learning_rate=0.2, max_depth=10, min_child_weight=6, n_estimators=200, subsample=0.8; total time=   0.2s
# [CV] END learning_rate=0.2, max_depth=10, min_child_weight=6, n_estimators=200, subsample=0.8; total time=   0.2s
# [CV] END learning_rate=0.2, max_depth=10, min_child_weight=6, n_estimators=200, subsample=0.8; total time=   0.2s
# [CV] END learning_rate=0.2, max_depth=10, min_child_weight=6, n_estimators=200, subsample=0.8; total time=   0.3s
# [CV] END learning_rate=0.2, max_depth=10, min_child_weight=6, n_estimators=200, subsample=0.8; total time=   0.2s
# [CV] END learning_rate=0.1, max_depth=15, min_child_weight=7, n_estimators=1200, subsample=0.7; total time=   1.5s
# [CV] END learning_rate=0.1, max_depth=15, min_child_weight=7, n_estimators=1200, subsample=0.7; total time=   1.5s
# [CV] END learning_rate=0.1, max_depth=15, min_child_weight=7, n_estimators=1200, subsample=0.7; total time=   1.5s
# [CV] END learning_rate=0.1, max_depth=15, min_child_weight=7, n_estimators=1200, subsample=0.7; total time=   1.5s
# [CV] END learning_rate=0.1, max_depth=15, min_child_weight=7, n_estimators=1200, subsample=0.7; total time=   1.4s
# [CV] END learning_rate=0.2, max_depth=25, min_child_weight=3, n_estimators=200, subsample=0.7; total time=   0.4s
# [CV] END learning_rate=0.2, max_depth=25, min_child_weight=3, n_estimators=200, subsample=0.7; total time=   3.4s
# [CV] END learning_rate=0.2, max_depth=25, min_child_weight=3, n_estimators=200, subsample=0.7; total time=   0.4s
# [CV] END learning_rate=0.2, max_depth=25, min_child_weight=3, n_estimators=200, subsample=0.7; total time=   0.4s
# [CV] END learning_rate=0.2, max_depth=25, min_child_weight=3, n_estimators=200, subsample=0.7; total time=   0.4s
# [CV] END learning_rate=0.3, max_depth=25, min_child_weight=5, n_estimators=400, subsample=0.7; total time=   0.6s
# [CV] END learning_rate=0.3, max_depth=25, min_child_weight=5, n_estimators=400, subsample=0.7; total time=   0.6s
# [CV] END learning_rate=0.3, max_depth=25, min_child_weight=5, n_estimators=400, subsample=0.7; total time=   0.6s
# [CV] END learning_rate=0.3, max_depth=25, min_child_weight=5, n_estimators=400, subsample=0.7; total time=   0.5s
# [CV] END learning_rate=0.3, max_depth=25, min_child_weight=5, n_estimators=400, subsample=0.7; total time=   0.6s
# [CV] END learning_rate=0.1, max_depth=10, min_child_weight=4, n_estimators=1100, subsample=0.8; total time=   0.9s
# [CV] END learning_rate=0.1, max_depth=10, min_child_weight=4, n_estimators=1100, subsample=0.8; total time=   1.1s
# [CV] END learning_rate=0.1, max_depth=10, min_child_weight=4, n_estimators=1100, subsample=0.8; total time=   1.1s
# [CV] END learning_rate=0.1, max_depth=10, min_child_weight=4, n_estimators=1100, subsample=0.8; total time=   1.0s
# [CV] END learning_rate=0.1, max_depth=10, min_child_weight=4, n_estimators=1100, subsample=0.8; total time=   1.0s
# [CV] END learning_rate=0.5, max_depth=20, min_child_weight=6, n_estimators=600, subsample=0.6; total time=   0.6s
# [CV] END learning_rate=0.5, max_depth=20, min_child_weight=6, n_estimators=600, subsample=0.6; total time=   3.5s
# [CV] END learning_rate=0.5, max_depth=20, min_child_weight=6, n_estimators=600, subsample=0.6; total time=   0.5s
# [CV] END learning_rate=0.5, max_depth=20, min_child_weight=6, n_estimators=600, subsample=0.6; total time=   0.5s
# [CV] END learning_rate=0.5, max_depth=20, min_child_weight=6, n_estimators=600, subsample=0.6; total time=   0.7s
# [CV] END learning_rate=0.2, max_depth=25, min_child_weight=7, n_estimators=800, subsample=0.7; total time=   1.1s
# [CV] END learning_rate=0.2, max_depth=25, min_child_weight=7, n_estimators=800, subsample=0.7; total time=   1.0s
# [CV] END learning_rate=0.2, max_depth=25, min_child_weight=7, n_estimators=800, subsample=0.7; total time=   1.1s
# [CV] END learning_rate=0.2, max_depth=25, min_child_weight=7, n_estimators=800, subsample=0.7; total time=   0.9s
# [CV] END learning_rate=0.2, max_depth=25, min_child_weight=7, n_estimators=800, subsample=0.7; total time=   0.9s
# [CV] END learning_rate=0.1, max_depth=15, min_child_weight=4, n_estimators=1200, subsample=0.7; total time=   1.4s
# [CV] END learning_rate=0.1, max_depth=15, min_child_weight=4, n_estimators=1200, subsample=0.7; total time=   1.5s
# [CV] END learning_rate=0.1, max_depth=15, min_child_weight=4, n_estimators=1200, subsample=0.7; total time=   4.5s
# [CV] END learning_rate=0.1, max_depth=15, min_child_weight=4, n_estimators=1200, subsample=0.7; total time=   1.3s
# [CV] END learning_rate=0.1, max_depth=15, min_child_weight=4, n_estimators=1200, subsample=0.7; total time=   1.6s
# [CV] END learning_rate=0.6, max_depth=20, min_child_weight=3, n_estimators=400, subsample=0.8; total time=   0.4s
# [CV] END learning_rate=0.6, max_depth=20, min_child_weight=3, n_estimators=400, subsample=0.8; total time=   0.3s
# [CV] END learning_rate=0.6, max_depth=20, min_child_weight=3, n_estimators=400, subsample=0.8; total time=   0.3s
# [CV] END learning_rate=0.6, max_depth=20, min_child_weight=3, n_estimators=400, subsample=0.8; total time=   0.3s
# [CV] END learning_rate=0.6, max_depth=20, min_child_weight=3, n_estimators=400, subsample=0.8; total time=   0.3s
# [CV] END learning_rate=0.05, max_depth=10, min_child_weight=3, n_estimators=700, subsample=0.7; total time=   0.8s
# [CV] END learning_rate=0.05, max_depth=10, min_child_weight=3, n_estimators=700, subsample=0.7; total time=   0.9s
# [CV] END learning_rate=0.05, max_depth=10, min_child_weight=3, n_estimators=700, subsample=0.7; total time=   0.8s
# [CV] END learning_rate=0.05, max_depth=10, min_child_weight=3, n_estimators=700, subsample=0.7; total time=   0.9s
# [CV] END learning_rate=0.05, max_depth=10, min_child_weight=3, n_estimators=700, subsample=0.7; total time=   0.9s
# RandomizedSearchCV(cv=5,
#                    estimator=XGBRegressor(base_score=None, booster=None,
#                                           callbacks=None,
#                                           colsample_bylevel=None,
#                                           colsample_bynode=None,
#                                           colsample_bytree=None,
#                                           early_stopping_rounds=None,
#                                           enable_categorical=False,
#                                           eval_metric=None, feature_types=None,
#                                           gamma=None, gpu_id=None,
#                                           grow_policy=None,
#                                           importance_type=None,
#                                           interaction_constraints=None,
#                                           learning_rate=...
#                                           predictor=None, random_state=None, ...),
#                    n_iter=100, n_jobs=1,
#                    param_distributions={'learning_rate': ['0.05', '0.1', '0.2',
#                                                           '0.3', '0.5', '0.6'],
#                                         'max_depth': [5, 10, 15, 20, 25, 30],
#                                         'min_child_weight': [3, 4, 5, 6, 7],
#                                         'n_estimators': [100, 200, 300, 400,
#                                                          500, 600, 700, 800,
#                                                          900, 1000, 1100,
#                                                          1200],
#                                         'subsample': [0.7, 0.6, 0.8]},
#                    random_state=42, scoring='neg_mean_squared_error',
#                    verbose=2)

# %%
xg_random.best_params_
# Out:
# {'subsample': 0.6,
#  'n_estimators': 100,
#  'min_child_weight': 4,
#  'max_depth': 10,
#  'learning_rate': '0.05'}

# %%
xg_random.best_params_
# Out:
# {'subsample': 0.6,
#  'n_estimators': 100,
#  'min_child_weight': 4,
#  'max_depth': 10,
#  'learning_rate': '0.05'}

# %%
xg_random.best_score_
# Out:
# -2641.43566254388

# %%
rf_random.best_score_
# Out:
# -2565.3667799315394

# %%
predictions=xg_random.predict(X_test)

# %%
sns.displot(y_test-predictions)

# %%
plt.scatter(y_test,predictions)

# %%
from sklearn import metrics
print('MAE:', metrics.mean_absolute_error(y_test, predictions))
print('MSE:', metrics.mean_squared_error(y_test, predictions))
print('RMSE:', np.sqrt(metrics.mean_squared_error(y_test, predictions)))
# Out:
# MAE: 31.900516810482497
# MSE: 2118.728943566487
# RMSE: 46.029652872539536

# %%
print('MAE:', metrics.mean_absolute_error(y_test, predictions))
print('MSE:', metrics.mean_squared_error(y_test, predictions))
print('RMSE:', np.sqrt(metrics.mean_squared_error(y_test, predictions)))
# Out:
# MAE: 31.900516810482497
# MSE: 2118.728943566487
# RMSE: 46.029652872539536

# %% [markdown]
# ##Regression Evaluation Metrics

# %%
from sklearn import metrics

# %%
print('MAE:', metrics.mean_absolute_error(y_test, prediction))
print('MSE:', metrics.mean_squared_error(y_test, prediction))
print('RMSE:', np.sqrt(metrics.mean_squared_error(y_test, prediction)))
# Out:
# MAE: 35.6498071368608
# MSE: 2543.3530376550766
# RMSE: 50.431667012454355

# %%
import pickle

file = open('/content/drive/MyDrive/Airnode/XbB.pkl', 'wb')


pickle.dump(xg_random, file)

# %% [markdown]
# ##Artificial Neural Network

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=0)

# %%
import keras
from keras.models import Sequential
from keras.layers import Dense
from keras.layers import LeakyReLU,PReLU,ELU
from keras.layers import Dropout

# %%
NN_model = Sequential()

# The Input Layer :
NN_model.add(Dense(128, kernel_initializer='normal',input_dim = X_train.shape[1], activation='relu'))

# The Hidden Layers :
NN_model.add(Dense(256, kernel_initializer='normal',activation='relu'))
NN_model.add(Dense(256, kernel_initializer='normal',activation='relu'))
NN_model.add(Dense(256, kernel_initializer='normal',activation='relu'))

# The Output Layer :
NN_model.add(Dense(1, kernel_initializer='normal',activation='linear'))

# Compile the network :
NN_model.compile(loss='mean_absolute_error', optimizer='adam', metrics=['mean_absolute_error'])
NN_model.summary()

# Fitting the ANN to the Training set
model_history=NN_model.fit(X_train, y_train,validation_split=0.33, batch_size = 10, epochs = 100)
# Out:
# Model: "sequential_2"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense_10 (Dense)            (None, 128)               1152
#
#  dense_11 (Dense)            (None, 256)               33024
#
#  dense_12 (Dense)            (None, 256)               65792
#
#  dense_13 (Dense)            (None, 256)               65792
#
#  dense_14 (Dense)            (None, 1)                 257
#
# =================================================================
# Total params: 166,017
# Trainable params: 166,017
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/100
# 35/35 [==============================] - 3s 15ms/step - loss: 72.8579 - mean_absolute_error: 72.8579 - val_loss: 62.0837 - val_mean_absolute_error: 62.0837
# Epoch 2/100
# 35/35 [==============================] - 0s 8ms/step - loss: 68.4720 - mean_absolute_error: 68.4720 - val_loss: 61.4979 - val_mean_absolute_error: 61.4979
# Epoch 3/100
# 35/35 [==============================] - 0s 9ms/step - loss: 65.7527 - mean_absolute_error: 65.7527 - val_loss: 61.5377 - val_mean_absolute_error: 61.5377
# Epoch 4/100
# 35/35 [==============================] - 0s 9ms/step - loss: 65.2252 - mean_absolute_error: 65.2252 - val_loss: 58.8340 - val_mean_absolute_error: 58.8340
# Epoch 5/100
# 35/35 [==============================] - 0s 9ms/step - loss: 63.5234 - mean_absolute_error: 63.5234 - val_loss: 57.2301 - val_mean_absolute_error: 57.2301
# Epoch 6/100
# 35/35 [==============================] - 0s 8ms/step - loss: 59.5054 - mean_absolute_error: 59.5054 - val_loss: 61.8949 - val_mean_absolute_error: 61.8949
# Epoch 7/100
# 35/35 [==============================] - 0s 7ms/step - loss: 53.7991 - mean_absolute_error: 53.7991 - val_loss: 54.6539 - val_mean_absolute_error: 54.6539
# Epoch 8/100
# 35/35 [==============================] - 0s 10ms/step - loss: 53.7825 - mean_absolute_error: 53.7825 - val_loss: 43.2662 - val_mean_absolute_error: 43.2662
# Epoch 9/100
# 35/35 [==============================] - 0s 12ms/step - loss: 45.5106 - mean_absolute_error: 45.5106 - val_loss: 47.6330 - val_mean_absolute_error: 47.6330
# Epoch 10/100
# 35/35 [==============================] - 0s 8ms/step - loss: 42.9814 - mean_absolute_error: 42.9814 - val_loss: 47.2804 - val_mean_absolute_error: 47.2804
# Epoch 11/100
# 35/35 [==============================] - 0s 5ms/step - loss: 44.6423 - mean_absolute_error: 44.6423 - val_loss: 45.9388 - val_mean_absolute_error: 45.9388
# Epoch 12/100
# 35/35 [==============================] - 0s 6ms/step - loss: 42.0422 - mean_absolute_error: 42.0422 - val_loss: 42.6253 - val_mean_absolute_error: 42.6253
# Epoch 13/100
# 35/35 [==============================] - 0s 13ms/step - loss: 45.1090 - mean_absolute_error: 45.1090 - val_loss: 45.7297 - val_mean_absolute_error: 45.7297
# Epoch 14/100
# 35/35 [==============================] - 0s 12ms/step - loss: 44.6342 - mean_absolute_error: 44.6342 - val_loss: 47.6648 - val_mean_absolute_error: 47.6648
# Epoch 15/100
# 35/35 [==============================] - 0s 13ms/step - loss: 42.6344 - mean_absolute_error: 42.6344 - val_loss: 41.4983 - val_mean_absolute_error: 41.4983
# Epoch 16/100
# 35/35 [==============================] - 1s 18ms/step - loss: 42.9662 - mean_absolute_error: 42.9662 - val_loss: 42.5066 - val_mean_absolute_error: 42.5066
# Epoch 17/100
# 35/35 [==============================] - 0s 10ms/step - loss: 43.0807 - mean_absolute_error: 43.0807 - val_loss: 47.4226 - val_mean_absolute_error: 47.4226
# Epoch 18/100
# 35/35 [==============================] - 0s 14ms/step - loss: 42.7640 - mean_absolute_error: 42.7640 - val_loss: 45.4772 - val_mean_absolute_error: 45.4772
# Epoch 19/100
# 35/35 [==============================] - 1s 19ms/step - loss: 43.7626 - mean_absolute_error: 43.7626 - val_loss: 40.9418 - val_mean_absolute_error: 40.9418
# Epoch 20/100
# 35/35 [==============================] - 0s 10ms/step - loss: 43.2012 - mean_absolute_error: 43.2012 - val_loss: 40.7431 - val_mean_absolute_error: 40.7431
# Epoch 21/100
# 35/35 [==============================] - 0s 11ms/step - loss: 41.1401 - mean_absolute_error: 41.1401 - val_loss: 42.3630 - val_mean_absolute_error: 42.3630
# Epoch 22/100
# 35/35 [==============================] - 0s 8ms/step - loss: 42.2448 - mean_absolute_error: 42.2448 - val_loss: 41.1292 - val_mean_absolute_error: 41.1292
# Epoch 23/100
# 35/35 [==============================] - 0s 7ms/step - loss: 41.1206 - mean_absolute_error: 41.1206 - val_loss: 44.5515 - val_mean_absolute_error: 44.5515
# Epoch 24/100
# 35/35 [==============================] - 0s 9ms/step - loss: 41.2201 - mean_absolute_error: 41.2201 - val_loss: 40.1422 - val_mean_absolute_error: 40.1422
# Epoch 25/100
# 35/35 [==============================] - 0s 9ms/step - loss: 39.8166 - mean_absolute_error: 39.8166 - val_loss: 40.5452 - val_mean_absolute_error: 40.5452
# Epoch 26/100
# 35/35 [==============================] - 0s 7ms/step - loss: 38.7167 - mean_absolute_error: 38.7167 - val_loss: 42.1256 - val_mean_absolute_error: 42.1256
# Epoch 27/100
# 35/35 [==============================] - 0s 7ms/step - loss: 40.2444 - mean_absolute_error: 40.2444 - val_loss: 43.7182 - val_mean_absolute_error: 43.7182
# Epoch 28/100
# 35/35 [==============================] - 0s 8ms/step - loss: 40.6007 - mean_absolute_error: 40.6007 - val_loss: 46.7810 - val_mean_absolute_error: 46.7810
# Epoch 29/100
# 35/35 [==============================] - 0s 8ms/step - loss: 41.0686 - mean_absolute_error: 41.0686 - val_loss: 51.5371 - val_mean_absolute_error: 51.5371
# Epoch 30/100
# 35/35 [==============================] - 0s 5ms/step - loss: 40.1960 - mean_absolute_error: 40.1960 - val_loss: 42.6520 - val_mean_absolute_error: 42.6520
# Epoch 31/100
# 35/35 [==============================] - 0s 4ms/step - loss: 40.2312 - mean_absolute_error: 40.2312 - val_loss: 44.7740 - val_mean_absolute_error: 44.7740
# Epoch 32/100
# 35/35 [==============================] - 0s 5ms/step - loss: 42.1248 - mean_absolute_error: 42.1248 - val_loss: 42.9932 - val_mean_absolute_error: 42.9932
# Epoch 33/100
# 35/35 [==============================] - 0s 5ms/step - loss: 41.5514 - mean_absolute_error: 41.5514 - val_loss: 57.6709 - val_mean_absolute_error: 57.6709
# Epoch 34/100
# 35/35 [==============================] - 0s 5ms/step - loss: 43.0429 - mean_absolute_error: 43.0429 - val_loss: 39.4948 - val_mean_absolute_error: 39.4948
# Epoch 35/100
# 35/35 [==============================] - 0s 5ms/step - loss: 39.6073 - mean_absolute_error: 39.6073 - val_loss: 39.3397 - val_mean_absolute_error: 39.3397
# Epoch 36/100
# 35/35 [==============================] - 0s 4ms/step - loss: 42.7254 - mean_absolute_error: 42.7254 - val_loss: 39.2804 - val_mean_absolute_error: 39.2804
# Epoch 37/100
# 35/35 [==============================] - 0s 6ms/step - loss: 39.3440 - mean_absolute_error: 39.3440 - val_loss: 40.7874 - val_mean_absolute_error: 40.7874
# Epoch 38/100
# 35/35 [==============================] - 0s 5ms/step - loss: 38.8418 - mean_absolute_error: 38.8418 - val_loss: 42.0719 - val_mean_absolute_error: 42.0719
# Epoch 39/100
# 35/35 [==============================] - 0s 4ms/step - loss: 38.0658 - mean_absolute_error: 38.0658 - val_loss: 39.5513 - val_mean_absolute_error: 39.5513
# Epoch 40/100
# 35/35 [==============================] - 0s 4ms/step - loss: 38.2123 - mean_absolute_error: 38.2123 - val_loss: 38.9703 - val_mean_absolute_error: 38.9703
# Epoch 41/100
# 35/35 [==============================] - 0s 4ms/step - loss: 37.8237 - mean_absolute_error: 37.8237 - val_loss: 41.0999 - val_mean_absolute_error: 41.0999
# Epoch 42/100
# 35/35 [==============================] - 0s 4ms/step - loss: 38.9312 - mean_absolute_error: 38.9312 - val_loss: 42.3185 - val_mean_absolute_error: 42.3185
# Epoch 43/100
# 35/35 [==============================] - 0s 5ms/step - loss: 38.9034 - mean_absolute_error: 38.9034 - val_loss: 38.9746 - val_mean_absolute_error: 38.9746
# Epoch 44/100
# 35/35 [==============================] - 0s 5ms/step - loss: 39.7487 - mean_absolute_error: 39.7487 - val_loss: 42.5453 - val_mean_absolute_error: 42.5453
# Epoch 45/100
# 35/35 [==============================] - 0s 4ms/step - loss: 41.6503 - mean_absolute_error: 41.6503 - val_loss: 40.6159 - val_mean_absolute_error: 40.6159
# Epoch 46/100
# 35/35 [==============================] - 0s 4ms/step - loss: 39.4139 - mean_absolute_error: 39.4139 - val_loss: 39.9755 - val_mean_absolute_error: 39.9755
# Epoch 47/100
# 35/35 [==============================] - 0s 4ms/step - loss: 41.7931 - mean_absolute_error: 41.7931 - val_loss: 47.2092 - val_mean_absolute_error: 47.2092
# Epoch 48/100
# 35/35 [==============================] - 0s 5ms/step - loss: 40.3611 - mean_absolute_error: 40.3611 - val_loss: 39.2198 - val_mean_absolute_error: 39.2198
# Epoch 49/100
# 35/35 [==============================] - 0s 5ms/step - loss: 39.6454 - mean_absolute_error: 39.6454 - val_loss: 45.8834 - val_mean_absolute_error: 45.8834
# Epoch 50/100
# 35/35 [==============================] - 0s 5ms/step - loss: 39.3300 - mean_absolute_error: 39.3300 - val_loss: 38.6535 - val_mean_absolute_error: 38.6535
# Epoch 51/100
# 35/35 [==============================] - 0s 5ms/step - loss: 38.7581 - mean_absolute_error: 38.7581 - val_loss: 39.3320 - val_mean_absolute_error: 39.3320
# Epoch 52/100
# 35/35 [==============================] - 0s 4ms/step - loss: 39.8901 - mean_absolute_error: 39.8901 - val_loss: 41.8099 - val_mean_absolute_error: 41.8099
# Epoch 53/100
# 35/35 [==============================] - 0s 6ms/step - loss: 39.2937 - mean_absolute_error: 39.2937 - val_loss: 40.5916 - val_mean_absolute_error: 40.5916
# Epoch 54/100
# 35/35 [==============================] - 0s 4ms/step - loss: 38.1958 - mean_absolute_error: 38.1958 - val_loss: 43.1419 - val_mean_absolute_error: 43.1419
# Epoch 55/100
# 35/35 [==============================] - 0s 5ms/step - loss: 41.1344 - mean_absolute_error: 41.1344 - val_loss: 46.9366 - val_mean_absolute_error: 46.9366
# Epoch 56/100
# 35/35 [==============================] - 0s 5ms/step - loss: 37.9990 - mean_absolute_error: 37.9990 - val_loss: 40.3552 - val_mean_absolute_error: 40.3552
# Epoch 57/100
# 35/35 [==============================] - 0s 4ms/step - loss: 37.9485 - mean_absolute_error: 37.9485 - val_loss: 39.6564 - val_mean_absolute_error: 39.6564
# Epoch 58/100
# 35/35 [==============================] - 0s 4ms/step - loss: 41.8445 - mean_absolute_error: 41.8445 - val_loss: 41.6427 - val_mean_absolute_error: 41.6427
# Epoch 59/100
# 35/35 [==============================] - 0s 4ms/step - loss: 39.9373 - mean_absolute_error: 39.9373 - val_loss: 40.1751 - val_mean_absolute_error: 40.1751
# Epoch 60/100
# 35/35 [==============================] - 0s 5ms/step - loss: 38.0796 - mean_absolute_error: 38.0796 - val_loss: 38.7901 - val_mean_absolute_error: 38.7901
# Epoch 61/100
# 35/35 [==============================] - 0s 4ms/step - loss: 37.5649 - mean_absolute_error: 37.5649 - val_loss: 41.5699 - val_mean_absolute_error: 41.5699
# Epoch 62/100
# 35/35 [==============================] - 0s 5ms/step - loss: 37.3352 - mean_absolute_error: 37.3352 - val_loss: 40.6736 - val_mean_absolute_error: 40.6736
# Epoch 63/100
# 35/35 [==============================] - 0s 4ms/step - loss: 40.1590 - mean_absolute_error: 40.1590 - val_loss: 52.3360 - val_mean_absolute_error: 52.3360
# Epoch 64/100
# 35/35 [==============================] - 0s 4ms/step - loss: 39.1098 - mean_absolute_error: 39.1098 - val_loss: 39.6147 - val_mean_absolute_error: 39.6147
# Epoch 65/100
# 35/35 [==============================] - 0s 4ms/step - loss: 38.7716 - mean_absolute_error: 38.7716 - val_loss: 40.3045 - val_mean_absolute_error: 40.3045
# Epoch 66/100
# 35/35 [==============================] - 0s 5ms/step - loss: 39.4071 - mean_absolute_error: 39.4071 - val_loss: 40.1622 - val_mean_absolute_error: 40.1622
# Epoch 67/100
# 35/35 [==============================] - 0s 4ms/step - loss: 38.9169 - mean_absolute_error: 38.9169 - val_loss: 41.1190 - val_mean_absolute_error: 41.1190
# Epoch 68/100
# 35/35 [==============================] - 0s 5ms/step - loss: 40.1321 - mean_absolute_error: 40.1321 - val_loss: 39.2127 - val_mean_absolute_error: 39.2127
# Epoch 69/100
# 35/35 [==============================] - 0s 5ms/step - loss: 38.9457 - mean_absolute_error: 38.9457 - val_loss: 38.7708 - val_mean_absolute_error: 38.7708
# Epoch 70/100
# 35/35 [==============================] - 0s 6ms/step - loss: 38.3223 - mean_absolute_error: 38.3223 - val_loss: 39.8820 - val_mean_absolute_error: 39.8820
# Epoch 71/100
# 35/35 [==============================] - 0s 6ms/step - loss: 38.9528 - mean_absolute_error: 38.9528 - val_loss: 39.6097 - val_mean_absolute_error: 39.6097
# Epoch 72/100
# 35/35 [==============================] - 0s 7ms/step - loss: 41.2126 - mean_absolute_error: 41.2126 - val_loss: 43.0537 - val_mean_absolute_error: 43.0537
# Epoch 73/100
# 35/35 [==============================] - 0s 7ms/step - loss: 39.9001 - mean_absolute_error: 39.9001 - val_loss: 43.3267 - val_mean_absolute_error: 43.3267
# Epoch 74/100
# 35/35 [==============================] - 0s 7ms/step - loss: 38.3139 - mean_absolute_error: 38.3139 - val_loss: 38.6223 - val_mean_absolute_error: 38.6223
# Epoch 75/100
# 35/35 [==============================] - 0s 7ms/step - loss: 37.9466 - mean_absolute_error: 37.9466 - val_loss: 38.8231 - val_mean_absolute_error: 38.8231
# Epoch 76/100
# 35/35 [==============================] - 0s 8ms/step - loss: 36.9348 - mean_absolute_error: 36.9348 - val_loss: 38.6141 - val_mean_absolute_error: 38.6141
# Epoch 77/100
# 35/35 [==============================] - 0s 6ms/step - loss: 39.7068 - mean_absolute_error: 39.7068 - val_loss: 41.7158 - val_mean_absolute_error: 41.7158
# Epoch 78/100
# 35/35 [==============================] - 0s 7ms/step - loss: 37.3233 - mean_absolute_error: 37.3233 - val_loss: 40.3685 - val_mean_absolute_error: 40.3685
# Epoch 79/100
# 35/35 [==============================] - 0s 7ms/step - loss: 38.5272 - mean_absolute_error: 38.5272 - val_loss: 45.6697 - val_mean_absolute_error: 45.6697
# Epoch 80/100
# 35/35 [==============================] - 0s 6ms/step - loss: 43.0535 - mean_absolute_error: 43.0535 - val_loss: 38.6053 - val_mean_absolute_error: 38.6053
# Epoch 81/100
# 35/35 [==============================] - 0s 7ms/step - loss: 38.1585 - mean_absolute_error: 38.1585 - val_loss: 38.5695 - val_mean_absolute_error: 38.5695
# Epoch 82/100
# 35/35 [==============================] - 0s 6ms/step - loss: 37.6039 - mean_absolute_error: 37.6039 - val_loss: 38.9611 - val_mean_absolute_error: 38.9611
# Epoch 83/100
# 35/35 [==============================] - 0s 5ms/step - loss: 37.1332 - mean_absolute_error: 37.1332 - val_loss: 45.5833 - val_mean_absolute_error: 45.5833
# Epoch 84/100
# 35/35 [==============================] - 0s 4ms/step - loss: 37.5828 - mean_absolute_error: 37.5828 - val_loss: 39.8914 - val_mean_absolute_error: 39.8914
# Epoch 85/100
# 35/35 [==============================] - 0s 5ms/step - loss: 38.1720 - mean_absolute_error: 38.1720 - val_loss: 38.7559 - val_mean_absolute_error: 38.7559
# Epoch 86/100
# 35/35 [==============================] - 0s 5ms/step - loss: 37.3730 - mean_absolute_error: 37.3730 - val_loss: 43.3167 - val_mean_absolute_error: 43.3167
# Epoch 87/100
# 35/35 [==============================] - 0s 5ms/step - loss: 38.4433 - mean_absolute_error: 38.4433 - val_loss: 38.9882 - val_mean_absolute_error: 38.9882
# Epoch 88/100
# 35/35 [==============================] - 0s 4ms/step - loss: 37.6416 - mean_absolute_error: 37.6416 - val_loss: 38.7773 - val_mean_absolute_error: 38.7773
# Epoch 89/100
# 35/35 [==============================] - 0s 5ms/step - loss: 36.5203 - mean_absolute_error: 36.5203 - val_loss: 42.0825 - val_mean_absolute_error: 42.0825
# Epoch 90/100
# 35/35 [==============================] - 0s 5ms/step - loss: 37.8260 - mean_absolute_error: 37.8260 - val_loss: 39.2132 - val_mean_absolute_error: 39.2132
# Epoch 91/100
# 35/35 [==============================] - 0s 4ms/step - loss: 37.9528 - mean_absolute_error: 37.9528 - val_loss: 41.5611 - val_mean_absolute_error: 41.5611
# Epoch 92/100
# 35/35 [==============================] - 0s 6ms/step - loss: 36.6439 - mean_absolute_error: 36.6439 - val_loss: 38.7969 - val_mean_absolute_error: 38.7969
# Epoch 93/100
# 35/35 [==============================] - 0s 4ms/step - loss: 37.7666 - mean_absolute_error: 37.7666 - val_loss: 42.6267 - val_mean_absolute_error: 42.6267
# Epoch 94/100
# 35/35 [==============================] - 0s 4ms/step - loss: 36.8543 - mean_absolute_error: 36.8543 - val_loss: 39.4613 - val_mean_absolute_error: 39.4613
# Epoch 95/100
# 35/35 [==============================] - 0s 4ms/step - loss: 36.3865 - mean_absolute_error: 36.3865 - val_loss: 40.5291 - val_mean_absolute_error: 40.5291
# Epoch 96/100
# 35/35 [==============================] - 0s 5ms/step - loss: 37.7800 - mean_absolute_error: 37.7800 - val_loss: 38.0816 - val_mean_absolute_error: 38.0816
# Epoch 97/100
# 35/35 [==============================] - 0s 5ms/step - loss: 38.6969 - mean_absolute_error: 38.6969 - val_loss: 39.0445 - val_mean_absolute_error: 39.0445
# Epoch 98/100
# 35/35 [==============================] - 0s 5ms/step - loss: 37.5608 - mean_absolute_error: 37.5608 - val_loss: 38.0551 - val_mean_absolute_error: 38.0551
# Epoch 99/100
# 35/35 [==============================] - 0s 6ms/step - loss: 37.6118 - mean_absolute_error: 37.6118 - val_loss: 38.0221 - val_mean_absolute_error: 38.0221
# Epoch 100/100
# 35/35 [==============================] - 0s 5ms/step - loss: 36.4734 - mean_absolute_error: 36.4734 - val_loss: 41.8577 - val_mean_absolute_error: 41.8577

# %% [markdown]
# ##Model Evaluation

# %%
prediction=NN_model.predict(X_test)
# Out:
# 7/7 [==============================] - 0s 3ms/step

# %%
y_test
# Out:
# 197    205.125000
# 188    264.916667
# 14     319.737500
# 31       1.916667
# 391    137.125000
#           ...
# 155     99.708333
# 392    197.083333
# 572    132.208333
# 307     38.416667
# 201    246.041667
# Name: PM 2.5, Length: 219, dtype: float64

# %%
sns.displot(y_test.values.reshape(-1,1)-prediction)

# %%
plt.scatter(y_test,prediction)

# %%
from sklearn import metrics
print('MAE:', metrics.mean_absolute_error(y_test, prediction))
print('MSE:', metrics.mean_squared_error(y_test, prediction))
print('RMSE:', np.sqrt(metrics.mean_squared_error(y_test, prediction)))
# Out:
# MAE: 43.176012580325796
# MSE: 3727.2199114491173
# RMSE: 61.050961593156885

# %%
print('MAE:', metrics.mean_absolute_error(y_test, predictions))
print('MSE:', metrics.mean_squared_error(y_test, predictions))
print('RMSE:', np.sqrt(metrics.mean_squared_error(y_test, predictions)))
# Out:
# MAE: 43.176012580325796
# MSE: 3727.2199114491173
# RMSE: 61.050961593156885

# %% [markdown]
# ##Regression Evaluation Metrics

# %%
from sklearn import metrics

# %%
print('MAE:', metrics.mean_absolute_error(y_test, prediction))
print('MSE:', metrics.mean_squared_error(y_test, prediction))
print('RMSE:', np.sqrt(metrics.mean_squared_error(y_test, prediction)))
# Out:
# MAE: 43.176012580325796
# MSE: 3727.2199114491173
# RMSE: 61.050961593156885

# %%
import pickle

# %%
file = open('/content/drive/MyDrive/Airnode/ann.pkl', 'wb')

pickle.dump(model_history, file)

# %% [markdown]
# #KNN Regressor

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=0)

# %%
from sklearn.neighbors import KNeighborsRegressor

# %%
regressor=KNeighborsRegressor(n_neighbors=1)
regressor.fit(X_train,y_train)
# Out:
# KNeighborsRegressor(n_neighbors=1)

# %%
print("Coefficient of determination R^2 <-- on train set: {}".format(regressor.score(X_train, y_train)))
# Out:
# Coefficient of determination R^2 <-- on train set: 1.0

# %%
print("Coefficient of determination R^2 <-- on train set: {}".format(regressor.score(X_test, y_test)))
# Out:
# Coefficient of determination R^2 <-- on train set: -0.08045200427243504

# %%
from sklearn.model_selection import cross_val_score
score=cross_val_score(regressor,X,y,cv=5)

# %%
score.mean()
# Out:
# -0.12260548546487755

# %% [markdown]
# ##Model Evaluation

# %%
prediction=regressor.predict(X_test)

# %%
sns.displot(y_test-prediction)

# %%
plt.scatter(y_test,prediction)

# %% [markdown]
# ##Hyperparameter Tuning

# %%
accuracy_rate = []

for i in range(1,40):

    knn = KNeighborsRegressor(n_neighbors=i)
    score=cross_val_score(knn,X,y,cv=10,scoring="neg_mean_squared_error")
    accuracy_rate.append(score.mean())

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(10,6))
plt.plot(range(1,40),accuracy_rate,color='blue', linestyle='dashed', marker='o',
         markerfacecolor='red', markersize=10)
#plt.plot(range(1,40),accuracy_rate,color='blue', linestyle='dashed', marker='o',
 #        markerfacecolor='red', markersize=10)
plt.title('Accuracy Rate vs. K Value')
plt.xlabel('K')
plt.ylabel('Accuracy Rate')
# Out:
# Text(0, 0.5, 'Accuracy Rate')

# %%
knn = KNeighborsRegressor(n_neighbors=1)

knn.fit(X_train,y_train)
predictions = knn.predict(X_test)

# %%
sns.displot(y_test-predictions)

# %%
plt.scatter(y_test,predictions)

# %%
from sklearn import metrics
print('MAE:', metrics.mean_absolute_error(y_test, predictions))
print('MSE:', metrics.mean_squared_error(y_test, predictions))
print('RMSE:', np.sqrt(metrics.mean_squared_error(y_test, predictions)))
# Out:
# MAE: 57.635540334855406
# MSE: 7053.356899257989
# RMSE: 83.98426578388353

# %%
knn = KNeighborsRegressor(n_neighbors=3)

knn.fit(X_train,y_train)
predictions = knn.predict(X_test)

# %%
sns.displot(y_test-predictions)

# %%
plt.scatter(y_test,predictions)

# %%
from sklearn import metrics
print('MAE:', metrics.mean_absolute_error(y_test, predictions))
print('MSE:', metrics.mean_squared_error(y_test, predictions))
print('RMSE:', np.sqrt(metrics.mean_squared_error(y_test, predictions)))
# Out:
# MAE: 45.32886225266362
# MSE: 4232.47184930626
# RMSE: 65.05745037508203

# %%
import pickle

# %%
file = open('/content/drive/MyDrive/Airnode/knn.pkl', 'wb')

pickle.dump(knn, file)
